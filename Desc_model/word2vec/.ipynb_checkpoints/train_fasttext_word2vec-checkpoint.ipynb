# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.8.3.tar.gz (73kB)
#     100% |################################| 81kB 1.3MB/s ta 0:00:011
# Requirement already satisfied: numpy>=1 in /home/nbcommon/anaconda3_420/lib/python3.5/site-packages (from fasttext)
# Collecting future (from fasttext)
#   Downloading future-0.16.0.tar.gz (824kB)
#     100% |################################| 829kB 1.7MB/s eta 0:00:01
# Building wheels for collected packages: fasttext, future
#   Running setup.py bdist_wheel for fasttext ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/55/0a/95/e23f773666d3487ee7456b220f7e8d37e99b74833b20dd06a0
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/c2/50/7c/0d83b4baac4f63ff7a765bd16390d2ab43c93587fac9d6017a
# Successfully built fasttext future
# Installing collected packages: future, fasttext
# Successfully installed fasttext-0.8.3 future-0.16.0

# %%
import numpy as np
import pandas as pd
from gensim.models.wrappers import FastText
from gensim.models import Phrases
from gensim.corpora import Dictionary
from nltk.tokenize import sent_tokenize
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential, Model, load_model, save_model
from keras.layers import Dense
from keras.layers import LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.layers import GaussianNoise, BatchNormalization, Dropout
from keras.layers import Activation, Input, concatenate, Reshape, merge, dot
from keras.optimizers import Adam, RMSprop, SGD
from keras.regularizers import l1, l2
from keras.layers.embeddings import Embedding
from keras.preprocessing.sequence import skipgrams, make_sampling_table
from keras.callbacks import Callback, LambdaCallback, TensorBoard, ReduceLROnPlateau, EarlyStopping
from keras.utils import np_utils
from random import shuffle
import time
import pylab as pl
from ipywidgets import FloatProgress
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# set backends of keras
sess = tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=8))
K.set_session(sess)

# %%
def is_desired_letter(char):
    order = ord(char)
    return order >= 97 and order < 123 or order >= 48 and order < 58 or order == ord(" ") or order == ord("'")


def get_text_data():
    # load the dataset but only keep the top n words, zero the rest
    train_data = pd.read_csv("input/kickstarter_train.csv")
    # segment all sentences
    sent_list = [sent.lower() for text in train_data["desc"] if type(text) is str for sent in sent_tokenize(text)]
    # remove symbols in each description
    sent_list = [[char for char in sent if is_desired_letter(char)] for sent in sent_list]
    sent_list = [''.join(sent).split() for sent in sent_list]
    # remove too short desc
    train_texts = [sent for sent in sent_list if len(sent) > 3]
    train_data = pd.read_csv("input/kickstarter_test.csv")
    # segment all sentences
    sent_list = [sent.lower() for text in train_data["desc"] if type(text) is str for sent in sent_tokenize(text)]
    # remove symbols in each description
    sent_list = [[char for char in sent if is_desired_letter(char)] for sent in sent_list]
    sent_list = [''.join(sent).split() for sent in sent_list]
    # remove too short desc
    train_texts.extend([sent for sent in sent_list if len(sent) > 3])

    return train_texts

# %%
# get training texts from disk
train_texts = get_text_data()
print("data of length {} grabbed".format(len(train_texts)))
train_texts
# Out:
# data of length 239151 grabbed
# [['i', 'like', 'drawing', 'pictures'],
#  ['and', 'then', 'i', 'color', 'them', 'too'],
#  ['so',
#   'i',
#   'thought',
#   'i',
#   'would',
#   'suggest',
#   'something',
#   'for',
#   'me',
#   'to',
#   'draw',
#   'and',
#   'then',
#   'if',
#   'someone',
#   'wants'],
#  ['i',
#   'dereck',
#   'blackburn',
#   'will',
#   'be',
#   'taking',
#   'upon',
#   'an',
#   'incredible',
#   'journey',
#   'in',
#   'the',
#   'month',
#   'of',
#   'may',
#   '2009'],
#  ['i', 'will', 'be', 'traveling', 'to', 'my', 'hometown', 'of', 'kankakee'],
#  ['so',
#   'i',
#   'saw',
#   "darkpony's",
#   'successfully',
#   'funded',
#   'drawing',
#   'for',
#   'dollars',
#   'project',
#   'and',
#   'i',
#   'thought',
#   "that's",
#   'fun'],
#  ['i', 'drew', 'this', 'guy', 'who', "i'm", 'calling'],
#  ['do',
#   'your',
#   'part',
#   'to',
#   'help',
#   'out',
#   'starving',
#   'artists',
#   'and',
#   'help',
#   'me',
#   'write',
#   'my',
#   'second',
#   'novel'],
#  ['i', 'have', 'just', 'finished', 'writing', 'my', 'first', 'novel', 'and'],
#  ["i'm",
#   'nearing',
#   'completion',
#   'on',
#   'a',
#   'sculpture',
#   'currently',
#   'titled',
#   'unnamed',
#   'man',
#   '2009',
#   'which',
#   'stands',
#   'approximately',
#   '13inches',
#   'tall',
#   'and',
#   'is'],
#  ["i'm", 'a', 'fledgling', 'videoblogger', 'living', 'in', 'brooklyn', 'ny'],
#  ['the',
#   'webcast',
#   "i'm",
#   'making',
#   'which',
#   'you',
#   'can',
#   'check',
#   'out',
#   'at',
#   'httpwwwyoudigestcom'],
#  ['i',
#   'am',
#   'an',
#   'independent',
#   'iphone',
#   'developer',
#   'that',
#   'believes',
#   'in',
#   'free',
#   'software'],
#  ['recently',
#   'i',
#   'released',
#   'an',
#   'iphone',
#   'app',
#   'that',
#   'assists',
#   'users',
#   'of',
#   'goozex'],
#  ['drive',
#   'a',
#   'faster',
#   'car',
#   'httpwwwdriveafastercarcom',
#   'has',
#   'been',
#   'a',
#   'personal',
#   'project',
#   'and',
#   'love',
#   'of',
#   'mine',
#   'for',
#   'the',
#   'past',
#   'eight',
#   'years',
#   'blogging'],
#  ['opening',
#   'friday',
#   'june',
#   '5',
#   '2009',
#   'on',
#   'view',
#   'through',
#   'september',
#   '2009'],
#  ['tinys',
#   'giant',
#   'sandwich',
#   'shop',
#   '129',
#   'rivington',
#   'st',
#   'nyc',
#   '10002'],
#  ['this',
#   'project',
#   'is',
#   'for',
#   'a',
#   'choose',
#   'your',
#   'own',
#   'adventure',
#   'painting',
#   'series'],
#  ['here', 'is', 'how', 'it', 'works'],
#  ['you', 'pledge', '35', 'and', 'you', 'are', 'put', 'in', 'line'],
#  ['i',
#   'am',
#   'an',
#   'independent',
#   'pr',
#   'practitioner',
#   'with',
#   'a',
#   'longtime',
#   'interest',
#   'in',
#   'voting',
#   'machines'],
#  ['with',
#   'your',
#   'help',
#   'i',
#   'can',
#   'write',
#   'a',
#   'book',
#   'that',
#   'chronicles'],
#  ['i',
#   'want',
#   'to',
#   'create',
#   'an',
#   'artist',
#   'book',
#   'of',
#   'drawings',
#   'inspired',
#   'by',
#   'digital',
#   'pixels'],
#  ["what's", 'an', 'artist', 'book'],
#  ["it's",
#   'a',
#   'work',
#   'of',
#   'art',
#   'in',
#   'the',
#   'form',
#   'of',
#   'a',
#   'book',
#   'of',
#   'course'],
#  ['pictured',
#   'here',
#   'is',
#   'the',
#   'character',
#   'we',
#   'would',
#   'like',
#   'to',
#   'sculpt',
#   'as',
#   'a',
#   'high',
#   'quality',
#   'game',
#   'miniature',
#   'the',
#   'forsaker',
#   'a',
#   'man',
#   'that',
#   'has',
#   'abandoned',
#   'his',
#   'sanity',
#   'to',
#   'face'],
#  ['i',
#   'make',
#   'cool',
#   'icons',
#   'for',
#   'iphone',
#   'developers',
#   'at',
#   'httpglyphishcom',
#   'and',
#   'if',
#   'i',
#   'can',
#   'collect',
#   '500',
#   'in',
#   'donations',
#   "i'll",
#   'release',
#   'the',
#   'whole',
#   'set'],
#  ['i',
#   'am',
#   'a',
#   'professional',
#   'creator',
#   'and',
#   'producer',
#   'of',
#   'web',
#   'video',
#   'series',
#   'the',
#   'burg',
#   'the',
#   'allfornots',
#   'and',
#   "all's",
#   'faire'],
#  ['i', 'am', 'putting', 'together', 'a'],
#  ['project',
#   'pedal',
#   'is',
#   'an',
#   'independent',
#   'documentary',
#   'about',
#   'the',
#   'shift',
#   'in',
#   'perspective',
#   'after',
#   'traveling',
#   'alone',
#   'for',
#   'thousands',
#   'of',
#   'mihellip'],
#  ['we',
#   'are',
#   'throwing',
#   'a',
#   'party',
#   'to',
#   'celebrate',
#   'the',
#   'release',
#   'of',
#   'the',
#   'frank',
#   '151',
#   'erotica',
#   'issue',
#   'hosted',
#   'by',
#   'mos',
#   'def',
#   'francesco',
#   'clemente'],
#  ['i', 'create', 'crosswords', 'and', 'other', 'puzzles'],
#  ['these',
#   'have',
#   'appeared',
#   'among',
#   'other',
#   'places',
#   'in',
#   'the',
#   'new',
#   'york',
#   'times',
#   'the',
#   'wall',
#   'street',
#   'journal',
#   'and',
#   'games',
#   'magazine'],
#  ['a',
#   '3day',
#   'popup',
#   'art',
#   'gallery',
#   'of',
#   'work',
#   'depicting',
#   'exgovernor',
#   'rod',
#   'blagojevich',
#   'aka',
#   'blago'],
#  ['we',
#   'are',
#   'broke',
#   'film',
#   'students',
#   'who',
#   'have',
#   'created',
#   'a',
#   'campaign',
#   'called',
#   'it',
#   'might',
#   'become',
#   'a',
#   'movie',
#   'which',
#   'is',
#   'destined',
#   'to',
#   'help',
#   'us',
#   'raise',
#   'funds',
#   'for',
#   'a',
#   'short',
#   'film'],
#  ['postcards',
#   'are',
#   'fun',
#   'to',
#   'make',
#   'fun',
#   'to',
#   'send',
#   'and',
#   'fun',
#   'to',
#   'receive'],
#  ['i',
#   'want',
#   'to',
#   'send',
#   'a',
#   'postcard',
#   'every',
#   'day',
#   'for',
#   'one',
#   'year',
#   'starting',
#   'june',
#   '1st'],
#  ['three',
#   'years',
#   'ago',
#   'i',
#   'moved',
#   'to',
#   'texas',
#   'after',
#   'spending',
#   'my',
#   'entire',
#   'life',
#   'in',
#   'the',
#   'midwest'],
#  ['this',
#   'summer',
#   'i',
#   'will',
#   'been',
#   'spending',
#   '6',
#   'weeks',
#   'traveling'],
#  ['hi',
#   'there',
#   'i',
#   'am',
#   'fundraising',
#   'for',
#   'a',
#   'quality',
#   'watercolor',
#   'brush',
#   'set',
#   'so',
#   'that',
#   'i',
#   'can',
#   'do',
#   'my',
#   'homeland',
#   'of',
#   'bosnia',
#   'justice',
#   'this',
#   'summer'],
#  ['check', 'out', 'my', 'project'],
#  ['my',
#   'most',
#   'recent',
#   'painting',
#   'show',
#   'decorative',
#   'nihilism',
#   'just',
#   'closed',
#   'in',
#   'new',
#   'york',
#   'city'],
#  ['now',
#   'that',
#   'the',
#   'show',
#   'is',
#   'down',
#   'i',
#   'want',
#   'to',
#   'share',
#   'my',
#   'work'],
#  ['a',
#   'documentary',
#   'that',
#   'explores',
#   'unschooling',
#   'homeschooling',
#   'without',
#   'the',
#   'artificial',
#   'structure',
#   'of',
#   'formal',
#   'education'],
#  ['advice', 'and', 'answers', 'from', 'kids', 'parents'],
#  ['athens',
#   'needs',
#   'your',
#   'help',
#   'to',
#   'launch',
#   'its',
#   'first',
#   'camp',
#   'this',
#   'july'],
#  ['money',
#   'will',
#   'go',
#   'to',
#   'equipment',
#   'scholarships',
#   'for',
#   'the',
#   'kids',
#   'and',
#   'hiring',
#   'experts'],
#  ['help',
#   'me',
#   'interview',
#   'people',
#   'for',
#   'my',
#   'designfocused',
#   'podcast'],
#  ['this', 'year', 'due', 'the', 'economic', 'troubles', 'great', 'recession'],
#  ['one',
#   'of',
#   'my',
#   'favorite',
#   'albums',
#   'of',
#   'all',
#   'time',
#   'was',
#   'put',
#   'out',
#   'by',
#   'a',
#   'tiny',
#   'littleknown',
#   'label',
#   'out',
#   'of',
#   'portsmouth',
#   'new',
#   'hampshire',
#   'in',
#   'the',
#   'fall',
#   'of'],
#  ['flying',
#   'kebab',
#   'is',
#   'an',
#   'independent',
#   'internet',
#   'video',
#   'serie',
#   'featuring',
#   'nando',
#   'a',
#   'photographer',
#   'who',
#   'passes',
#   'one',
#   'year',
#   'searching',
#   'for',
#   'his',
#   'inheritance',
#   'in',
#   'lebanon'],
#  ['help',
#   'us',
#   'complete',
#   'a',
#   'featurelength',
#   'documentary',
#   'about',
#   'the',
#   'future',
#   'of',
#   'the',
#   'independent',
#   'music',
#   'industry'],
#  ["we're",
#   'trying',
#   'to',
#   'raise',
#   '1000',
#   'to',
#   'print',
#   'our',
#   'new',
#   'album'],
#  ['this',
#   'is',
#   'a',
#   'project',
#   'to',
#   'create',
#   'a',
#   'free',
#   'iphone',
#   'app',
#   'for',
#   'browsing',
#   'wikipedia',
#   'offline'],
#  ['the',
#   'code',
#   'will',
#   'be',
#   'open',
#   'source',
#   'and',
#   "i'll",
#   'launch',
#   'it',
#   'with'],
#  ["i'm",
#   'drawing',
#   '127',
#   'composite',
#   'faces',
#   'from',
#   'photos',
#   'of',
#   'friends',
#   'then',
#   'drawing',
#   'a',
#   'series',
#   'of',
#   'combinations',
#   'until',
#   'finally',
#   'there',
#   'is',
#   'one',
#   'face',
#   'derived',
#   'from',
#   'them',
#   'all'],
#  ['the',
#   'objective',
#   'is',
#   'to',
#   'create',
#   'a',
#   'method',
#   'of',
#   'using',
#   'social',
#   'media',
#   'networks',
#   'ie',
#   'twitter',
#   'facebook',
#   'and',
#   'future',
#   'incarnations',
#   'that',
#   'have',
#   'yet',
#   'to'],
#  ['help',
#   'us',
#   'create',
#   'a',
#   'wacky',
#   '2d',
#   'sidescrolling',
#   'actionadventure',
#   'game',
#   'with',
#   '16bit',
#   'graphics',
#   'and',
#   'hand',
#   'painted',
#   'backgrounds',
#   'for',
#   'xbox',
#   'live',
#   'arcade',
#   'and',
#   'pc'],
#  ['it', 'just', 'makes', 'you', 'want', 'to', 'cry'],
#  ['well', 'what', 'if', 'we', 'could', 'change', 'all', 'that'],
#  ['make', 'it', 'into', 'a', 'fun', 'game'],
#  ['polyvinyl', 'needs', 'your', 'help'],
#  ['some',
#   'of',
#   'our',
#   'distributors',
#   'warehouses',
#   'are',
#   'being',
#   'downsized',
#   'or',
#   'consolidated',
#   'and',
#   'we',
#   'either',
#   'need',
#   'to',
#   'destroy',
#   'over',
#   '10000'],
#  ["they're", 'a', 'problem', 'that', 'no', 'one', 'wants', 'to', 'address'],
#  ['when',
#   'is',
#   'the',
#   'zombpocalypse',
#   'going',
#   'to',
#   'be',
#   'upon',
#   'us',
#   'and',
#   'more',
#   'importantly',
#   'will'],
#  ['a', 'content', 'aggregator', 'with', 'personality'],
#  ['gnash',
#   'is',
#   'an',
#   'open',
#   'source',
#   'framework',
#   'in',
#   'phpmysql',
#   'for',
#   'application',
#   'development'],
#  ['it', 'is', 'part', 'cms', 'part', 'framework', 'part', 'form', 'editor'],
#  ['the',
#   'dawn',
#   'of',
#   'quixote',
#   'chapter',
#   'the',
#   'first',
#   'has',
#   'been',
#   'invited',
#   'to',
#   'the',
#   'edinburgh',
#   'fringe',
#   'festival',
#   'in',
#   'scotland'],
#  ['two', 'solid', 'weeks', 'of', 'shows', 'running', 'from'],
#  ['for',
#   'any',
#   'band',
#   'the',
#   'ability',
#   'to',
#   'stay',
#   'on',
#   'the',
#   'road',
#   'is',
#   'vital'],
#  ["that's", 'hard', 'to', 'do', 'with', '4', 'guys', 'and', 'a', 'truck'],
#  ['i',
#   'have',
#   'recorded',
#   'a',
#   'new',
#   'record',
#   'this',
#   'summer',
#   'but',
#   'i',
#   "can't",
#   'get',
#   'on',
#   'the',
#   'road',
#   'again',
#   'without',
#   'your',
#   'love'],
#  ['meeting',
#   'andrei',
#   'tarkovsky',
#   'a',
#   'documentary',
#   'about',
#   'the',
#   'death',
#   'and',
#   'legacy',
#   'of',
#   'one',
#   'of',
#   "russia's",
#   'most',
#   'famous',
#   'directors',
#   'needs',
#   'your',
#   'help'],
#  ['independent',
#   'feature',
#   'film',
#   'is',
#   'in',
#   'need',
#   'of',
#   '6000',
#   'to',
#   'assist',
#   'production',
#   'costs'],
#  ['it',
#   'is',
#   'a',
#   'big',
#   'art',
#   'project',
#   'i',
#   'only',
#   'began',
#   'to',
#   'createit',
#   'is',
#   'number',
#   'of',
#   'paintings',
#   'some',
#   'of',
#   'them',
#   'you',
#   'may',
#   'see',
#   'at',
#   'httpwwwznenterprises'],
#  ['a',
#   '35',
#   'city',
#   'design',
#   'promotion',
#   'tour',
#   'that',
#   'is',
#   'shared',
#   'online',
#   'and',
#   'will',
#   'later',
#   'be',
#   'compiled',
#   'into',
#   'a',
#   'hardcover',
#   'book'],
#  ['it', 'seeks', 'to', 'understand', 'how', 'creativity', 'is'],
#  ["i've",
#   'begun',
#   'prototyping',
#   'a',
#   'lowcost',
#   'led',
#   'light',
#   'for',
#   'the',
#   'kindle'],
#  ["i'd",
#   'like',
#   'the',
#   'finished',
#   'product',
#   'to',
#   'be',
#   'something',
#   'that',
#   'i',
#   'can',
#   'offer',
#   'as',
#   'a'],
#  ["i've",
#   'been',
#   'working',
#   'on',
#   'my',
#   'novel',
#   'down',
#   'the',
#   'cape',
#   'for',
#   '5',
#   'years'],
#  ['now',
#   "it's",
#   'time',
#   'to',
#   'finish',
#   'it',
#   'and',
#   'share',
#   'it',
#   'with',
#   'the',
#   'world'],
#  ['skeletons',
#   "don't",
#   'sleep',
#   'is',
#   'the',
#   'true',
#   'heartbreaking',
#   'and',
#   'triumphant',
#   'story',
#   'of',
#   'adoption',
#   'betrayal',
#   'abuse',
#   'and',
#   'finally',
#   'justice'],
#  ['help',
#   'me',
#   'record',
#   'and',
#   'produce',
#   'a',
#   'new',
#   'rockfusion',
#   'album',
#   'and',
#   'get',
#   'thanked',
#   'in',
#   'a',
#   'big',
#   'way'],
#  ['get',
#   'in',
#   'early',
#   'and',
#   'get',
#   'rewarded',
#   'for',
#   'being',
#   'an',
#   'insider'],
#  ["we're",
#   'looking',
#   'for',
#   'friends',
#   'and',
#   'fans',
#   'who',
#   'want',
#   'to',
#   'join',
#   'the',
#   'team'],
#  ['my',
#   'name',
#   'is',
#   'allison',
#   'weiss',
#   'and',
#   "i'm",
#   'recording',
#   'a',
#   'new',
#   'ep',
#   'this',
#   'summer'],
#  ["it'll",
#   'be',
#   'eight',
#   'songs',
#   'long',
#   'and',
#   'packed',
#   'with',
#   'all',
#   'kinds',
#   'of',
#   'awesome'],
#  ['we',
#   'have',
#   'been',
#   'working',
#   'on',
#   'our',
#   'debut',
#   'album',
#   'for',
#   'the',
#   'past',
#   '7',
#   'months'],
#  ['now', 'we', 'need', 'some', 'help', 'to', 'print', 'the', 'album'],
#  ['help', 'out', 'and', 'receive', 'cool', 'stuff'],
#  ['uncle', 'is', 'a', 'humor', 'culture', 'magazine'],
#  ["we're",
#   'writers',
#   'and',
#   'media',
#   'people',
#   'who',
#   'want',
#   'to',
#   'fund',
#   'a',
#   'limited',
#   'print',
#   'run',
#   'of',
#   'our',
#   'third',
#   'issue',
#   'themed',
#   'summertime'],
#  ['i',
#   'want',
#   'to',
#   'offer',
#   'affordable',
#   'prints',
#   'of',
#   'my',
#   'paintings',
#   'which',
#   'are',
#   'kinda',
#   'pricey'],
#  ['but',
#   'i',
#   'need',
#   'to',
#   'have',
#   'physical',
#   'paper',
#   'objects',
#   'to',
#   'sell',
#   'and',
#   'ship'],
#  ['bring',
#   'together',
#   'youth',
#   'from',
#   'albania',
#   'kosovo',
#   'and',
#   'montenegro',
#   'to',
#   'climb',
#   'tripeak',
#   'in',
#   'the',
#   'balkans',
#   'peace',
#   'park',
#   'where',
#   'all',
#   '3',
#   'countries',
#   'meet',
#   'on',
#   'the',
#   'summit'],
#  ['last',
#   'may',
#   'i',
#   'created',
#   'my',
#   'mission',
#   'to',
#   'reunite',
#   'the',
#   'brilliant',
#   'but',
#   'in',
#   'my',
#   'opinion',
#   'underappreciated',
#   'band',
#   'the',
#   'kinks'],
#  ['i', 'decided', 'to', 'make'],
#  ['i',
#   'have',
#   'been',
#   'working',
#   'on',
#   'this',
#   'book',
#   'for',
#   'quite',
#   'some',
#   'time',
#   'now',
#   'and',
#   'i',
#   'am',
#   'ready',
#   'to',
#   'make',
#   'a',
#   'few',
#   'copies',
#   'from',
#   'the',
#   'master',
#   'to',
#   'shop',
#   'around',
#   'various'],
#  ['imagine',
#   'if',
#   'the',
#   'worlds',
#   'of',
#   'hollywood',
#   'and',
#   'sesame',
#   'street',
#   'collide'],
#  ['puppets',
#   'live',
#   'in',
#   'the',
#   'real',
#   'world',
#   'and',
#   'yearn',
#   'for',
#   'mainstream',
#   'acceptance'],
#  ['the',
#   'basic',
#   'idea',
#   'one',
#   'million',
#   'square',
#   'inches',
#   'in',
#   'detroit',
#   'michigan',
#   'that',
#   'you',
#   'can',
#   'own',
#   'and',
#   'create',
#   'on',
#   'for',
#   '1',
#   'an',
#   'inch'],
#  ['call', 'jerry', 'at', '9083431981', 'to', 'discuss'],
#  ['hello',
#   'kickstartersrvng',
#   'a',
#   'small',
#   'brooklynbased',
#   'record',
#   'label',
#   'focused',
#   'on',
#   'releasing',
#   'limited',
#   'runs',
#   'of',
#   'electronic',
#   'music',
#   'mixes',
#   'edits'],
#  ['we',
#   'want',
#   'to',
#   'give',
#   'out',
#   'hundreds',
#   'of',
#   'multicolored',
#   'led',
#   'filled',
#   'balloons',
#   'floaties'],
#  ['at',
#   'the',
#   'hoosac',
#   'river',
#   'lights',
#   'festival',
#   'in',
#   'north',
#   'adams',
#   'ma',
#   'on',
#   'august',
#   '22'],
#  ['help',
#   'an',
#   'independent',
#   'game',
#   'developer',
#   'promote',
#   'his',
#   'free',
#   'gaming',
#   'platform',
#   'playground',
#   'and',
#   'game',
#   'title',
#   'beatz'],
#  ['see', 'video', 'for', 'more', 'details'],
#  ['a',
#   'series',
#   'of',
#   'three',
#   'political',
#   'ads',
#   'that',
#   'address',
#   'important',
#   'political',
#   'and',
#   'current',
#   'affairs',
#   'issues',
#   'that',
#   'effect',
#   'the',
#   'nation'],
#  ['they', 'will', 'also', 'be', 'funny'],
#  ['five',
#   'times',
#   'august',
#   'needs',
#   'your',
#   'support',
#   'releasing',
#   'the',
#   'next',
#   'album'],
#  ['preorder',
#   'your',
#   'copy',
#   'and',
#   'get',
#   'cool',
#   'prizes',
#   'the',
#   'more',
#   'you',
#   'give',
#   'the',
#   'more',
#   'you',
#   'get'],
#  ['a',
#   'video',
#   'game',
#   'about',
#   'crystal',
#   'skulls',
#   'shadow',
#   'people',
#   'flash',
#   'light',
#   'wielding',
#   'teenagers',
#   'string',
#   'theory',
#   'chaos',
#   'theory',
#   'multiverses',
#   'and',
#   'a',
#   'talking',
#   'cat'],
#  ['from',
#   '18000',
#   'portraits',
#   'discovered',
#   'in',
#   'a',
#   'midwestern',
#   'diner',
#   'we',
#   'share',
#   'the',
#   'vivid',
#   'stories',
#   'which',
#   'create',
#   'this',
#   'tightknit',
#   'community'],
#  ['synttofs',
#   'httpwwwmyspacecomtophsynt',
#   'lpormolycka',
#   'project',
#   'oo1httpwwwormolyckacomoo1'],
#  ['my', 'first', 'solo', 'album'],
#  ['on',
#   'monday',
#   'august',
#   '24th',
#   'i',
#   'spend',
#   'one',
#   'day',
#   'in',
#   'the',
#   'studio',
#   'with',
#   'the',
#   'wonderful',
#   'sean',
#   'slade',
#   'to',
#   'get',
#   'the',
#   'album',
#   'started'],
#  ['greenlighted',
#   'buy',
#   'the',
#   'change',
#   'you',
#   'wish',
#   'to',
#   'see',
#   'in',
#   'the',
#   'world'],
#  ['for',
#   'guys',
#   'who',
#   'agree',
#   'to',
#   'go',
#   'shopping',
#   'with',
#   'their',
#   'better',
#   'halves',
#   'and',
#   'regret',
#   'it'],
#  ['the',
#   'man',
#   'chair',
#   'app',
#   'will',
#   'offer',
#   'a',
#   'digital',
#   'oasis',
#   'to',
#   'fight',
#   'off',
#   'boredom'],
#  ['selfsigned',
#   'independent',
#   'artist',
#   'state',
#   'of',
#   'man',
#   'are',
#   'turning',
#   'to',
#   'the',
#   'public',
#   'to',
#   'help',
#   'save',
#   'their',
#   'national',
#   'release',
#   'in',
#   'this',
#   'place',
#   'and',
#   'service2humanity',
#   'tour'],
#  ['follow',
#   'along',
#   'as',
#   'we',
#   'explore',
#   'new',
#   'york',
#   'city',
#   'tattoo',
#   'culture'],
#  ['a', 'zombie', 'short', 'film', 'shot', 'in', '3d'],
#  ['it', 'will', 'be', 'filmed', 'in', 'savannah', 'ga', 'in', 'midoctober'],
#  ['this',
#   'is',
#   'my',
#   'senior',
#   'film',
#   'and',
#   'the',
#   'start',
#   'of',
#   'a',
#   'franchise'],
#  ['my', 'name', 'is', 'shwa', 'and', "i'm", 'an', 'independent', 'songwriter'],
#  ["i'm",
#   'working',
#   'on',
#   'a',
#   'new',
#   'album',
#   'that',
#   'i',
#   'think',
#   'is',
#   'really',
#   'great',
#   'but',
#   'i',
#   'need',
#   'some',
#   'help',
#   'finishing',
#   'it'],
#  ['yearly',
#   'festival',
#   'designed',
#   'to',
#   'transform',
#   'katrina',
#   'related',
#   'publicity',
#   'around',
#   'its',
#   'anniversaries',
#   'into',
#   'exposure',
#   'and',
#   'donations',
#   'for',
#   'nonprofits',
#   'and',
#   'artists'],
#  ["i've", 'got', 'the', 'boat', 'and', "i've", 'got', 'the', 'plan'],
#  ['help',
#   'me',
#   'get',
#   'sv',
#   'bobbie',
#   'ready',
#   'to',
#   'go',
#   'around',
#   'the',
#   'world'],
#  ['sponsor',
#   'this',
#   'brooklyn',
#   'punk',
#   "band's",
#   'debut',
#   'seveninch',
#   'mr',
#   'dream',
#   'goes',
#   'to',
#   'jail'],
#  ['help',
#   'a',
#   'little',
#   'writing',
#   'community',
#   'with',
#   'big',
#   'ideals',
#   'pay',
#   'for',
#   'hosting',
#   'for',
#   'a',
#   'year'],
#  ['create',
#   'the',
#   "world's",
#   'first',
#   'crowdsourced',
#   'customer',
#   'voice',
#   'platform'],
#  ['facilitation',
#   'and',
#   'creation',
#   'of',
#   'a',
#   'community',
#   'mosaic',
#   'mural',
#   'with',
#   'kenyan',
#   'youth',
#   'at',
#   'a',
#   'rudolph',
#   'steiner',
#   'school',
#   'outside',
#   'of',
#   'nairobi',
#   'as',
#   'part',
#   'of',
#   'an',
#   'artist',
#   'residency'],
#  ['it',
#   'offers',
#   'a',
#   'unique',
#   'look',
#   'and',
#   'study',
#   'of',
#   'texas',
#   'early',
#   'history'],
#  ['raising',
#   'funds',
#   'to',
#   'publish',
#   'a',
#   "children's",
#   'book',
#   'that',
#   'will',
#   'give',
#   'families',
#   'a',
#   'positive',
#   'introduction',
#   'to',
#   'animal',
#   'shelters',
#   'with',
#   'proceeds',
#   'donating',
#   'the',
#   'pspca'],
#  ["i'm", 'chris', 'mckay', 'from', 'the', 'critical', 'darlings'],
#  ["we've",
#   'come',
#   'in',
#   'the',
#   'hope',
#   'that',
#   'together',
#   'we',
#   'can',
#   'make',
#   'some',
#   'great',
#   'music',
#   'and',
#   'get',
#   'you',
#   'tons',
#   'of',
#   'cool',
#   'stuff'],
#  ['ozy', 'reigns', 'is', 'the', 'future', 'of', 'music'],
#  ['people', 'familiar', 'with', 'his', 'sound', 'know'],
#  ['help',
#   'ozy',
#   'reigns',
#   'complete',
#   'his',
#   'ep',
#   'in',
#   'la',
#   'upport',
#   'the',
#   'renaissance'],
#  ['no',
#   'scroll',
#   'email',
#   'is',
#   'a',
#   'custom',
#   'email',
#   'application',
#   'that',
#   'only',
#   'accepts',
#   'email',
#   'messages',
#   'which',
#   'can',
#   'be',
#   'read',
#   'without',
#   'having',
#   'to',
#   'use',
#   'a',
#   'scroll',
#   'bar'],
#  ['the',
#   'redeemers',
#   'is',
#   'a',
#   'comic',
#   'book',
#   'about',
#   'rock',
#   "'n'",
#   'roll',
#   "'n'",
#   'redemption',
#   'looking',
#   'to',
#   'independently',
#   'publish',
#   'four',
#   'issues'],
#  ['this',
#   'will',
#   'be',
#   'one',
#   'of',
#   'the',
#   'best',
#   'debut',
#   'albums',
#   'from',
#   'a',
#   'young',
#   'independent',
#   'artist'],
#  ["i'm",
#   'making',
#   'the',
#   'album',
#   'of',
#   'my',
#   'dreams',
#   'and',
#   'perhaps',
#   'your',
#   'dreams',
#   'too'],
#  ['as',
#   'dylan',
#   'says',
#   "i'll",
#   'let',
#   'you',
#   'be',
#   'in',
#   'my',
#   'dreams',
#   'if',
#   'i',
#   'can',
#   'be',
#   'in',
#   'yours'],
#  ['a',
#   'series',
#   'of',
#   'videos',
#   'to',
#   'educate',
#   'the',
#   'public',
#   'about',
#   'health',
#   'care',
#   'reform'],
#  ['the',
#   'videos',
#   'will',
#   'be',
#   'available',
#   'for',
#   'public',
#   'private',
#   'and',
#   'viral',
#   'use'],
#  ['my',
#   'name',
#   'is',
#   'april',
#   'smith',
#   'and',
#   "i'm",
#   'working',
#   'on',
#   'a',
#   'new',
#   'album'],
#  ["i'm",
#   'looking',
#   'for',
#   'help',
#   'from',
#   'my',
#   'fans',
#   'to',
#   'get',
#   'funding',
#   'together',
#   'and',
#   'start',
#   'it',
#   'off',
#   'right'],
#  ['this',
#   'project',
#   'is',
#   'to',
#   'assist',
#   'the',
#   'start',
#   'of',
#   'an',
#   'art',
#   'design',
#   'studio',
#   'in',
#   'chicago'],
#  ['this',
#   'is',
#   'located',
#   'in',
#   'logan',
#   'square',
#   'an',
#   'upcoming',
#   'art',
#   'community'],
#  ['we',
#   'are',
#   'trying',
#   'to',
#   'raise',
#   '3500',
#   'so',
#   'that',
#   'we',
#   'can',
#   'market',
#   'promote',
#   'our',
#   'new',
#   'record',
#   "livin'",
#   'the',
#   'dream'],
#  ['get', 'exclusive', 'rewards', 'and', 'opportunities'],
#  ['flying',
#   'kebab',
#   'is',
#   'an',
#   'communityfunded',
#   'internet',
#   'video',
#   'serie',
#   'featuring',
#   'nando',
#   'a',
#   'photographer',
#   'who',
#   'passes',
#   'one',
#   'year',
#   'searching',
#   'for',
#   'his',
#   'inheritance',
#   'in',
#   'lebanon'],
#  ['the',
#   'underground',
#   'library',
#   'is',
#   'a',
#   'bookmaking',
#   'and',
#   'distributing',
#   'community',
#   'project',
#   'circulating',
#   'nonestablished',
#   'words',
#   'films',
#   'and',
#   'music',
#   'mysteriously'],
#  ["i'm",
#   'hosting',
#   'a',
#   'knitting',
#   'lounge',
#   'and',
#   'media',
#   'center',
#   'at',
#   'the',
#   'bryant',
#   'park',
#   'hotel',
#   'during',
#   'fashion',
#   'week',
#   'to',
#   'merge',
#   'the',
#   'craft',
#   'of',
#   'knitting',
#   'and',
#   'art',
#   'of',
#   'fashion'],
#  ['recording',
#   'a',
#   'malian',
#   "'mande'",
#   'music',
#   'album',
#   'in',
#   'bamako',
#   'mali',
#   'w',
#   'some',
#   'of',
#   'the',
#   'finest',
#   'musicians',
#   'in',
#   'the',
#   'land'],
#  ['bambara', 'songs', 'from', 'a', 'us', 'folk', 'singer'],
#  ['in',
#   'may',
#   'of',
#   '2008',
#   'we',
#   'recorded',
#   'an',
#   'album',
#   'at',
#   'the',
#   'georgia',
#   'theatre'],
#  ['the', 'georgia', 'theatre', 'was', 'destroyed', 'in', 'a', 'fire'],
#  ["let's", 'make', 'the', 'record', 'and', 'save', 'the', 'theatre'],
#  ['i',
#   'got',
#   'next',
#   'is',
#   'a',
#   'documentary',
#   'on',
#   'the',
#   'fighting',
#   'game',
#   'scene',
#   'that',
#   'follows',
#   'the',
#   'lives',
#   'of',
#   '4',
#   'players',
#   'and',
#   'the',
#   'eastwest',
#   'rivalry',
#   'with',
#   'street',
#   'fighter',
#   "4's",
#   'release'],
#  ['william',
#   "brittelle's",
#   'television',
#   'landscape',
#   'is',
#   'a',
#   'genrebashing',
#   'fullycomposed',
#   'chamber',
#   'pop',
#   'concept',
#   'album',
#   'dubbed',
#   'invigorating',
#   'by',
#   'the',
#   'new',
#   'york',
#   'times'],
#  ['the',
#   'project',
#   'will',
#   'document',
#   'children',
#   'born',
#   'in',
#   'rwanda',
#   'postgenocide',
#   'through',
#   'photographs',
#   'and',
#   'interviews'],
#  ["i'm",
#   'recording',
#   'my',
#   'first',
#   'fulllength',
#   'worship',
#   'album',
#   'of',
#   'original',
#   'songs',
#   'and',
#   'i',
#   'want',
#   'to',
#   'invite',
#   'you',
#   'to',
#   'be',
#   'a',
#   'part',
#   'of',
#   'it'],
#  ['finally', 'a', 'book', 'about', "chicago's", 'music', 'scene'],
#  ['this',
#   'longawaited',
#   'chronicle',
#   'of',
#   'the',
#   'windy',
#   "city's",
#   'most',
#   'memorable',
#   'decade',
#   'in',
#   'music',
#   'is',
#   'ready',
#   'to',
#   'go'],
#  ['pesipop', 'makes', 'awesome', 'stuff', 'for', 'awesome', 'people'],
#  ['help',
#   'get',
#   'the',
#   'joy',
#   'of',
#   'pesipop',
#   'into',
#   'the',
#   'hands',
#   'and',
#   'onto',
#   'the',
#   'bodies',
#   'of',
#   'more',
#   'people'],
#  ['fundraising',
#   'to',
#   'support',
#   'indie',
#   'rock',
#   'artist',
#   'musician',
#   'playing',
#   'guitar',
#   'in',
#   'london',
#   'october',
#   '2009',
#   'to',
#   'promote',
#   'music',
#   'for',
#   'new',
#   'cd'],
#  ['adventures',
#   'of',
#   'power',
#   'a',
#   'new',
#   'movie',
#   'and',
#   'the',
#   'bill',
#   'graham',
#   'foundation',
#   'are',
#   'holding',
#   'a',
#   'fundraiser',
#   'to',
#   'empower',
#   'children',
#   'with',
#   'music'],
#  ['we',
#   'would',
#   'like',
#   'to',
#   'build',
#   'a',
#   'giant',
#   'theremin',
#   'a',
#   'room',
#   'with',
#   '16',
#   'theremin',
#   'antennas',
#   'suspended',
#   'to',
#   'the',
#   'ceiling',
#   'so',
#   'people',
#   'can',
#   'play',
#   'music',
#   'with',
#   'their',
#   'bodies'],
#  ['back',
#   'us',
#   'to',
#   'own',
#   'wear',
#   'or',
#   'see',
#   'a',
#   'show',
#   'of',
#   'great',
#   'student',
#   'art',
#   "we've",
#   'collected',
#   'from',
#   'artloop',
#   'partner',
#   'schools',
#   'in',
#   'nyc'],
#  ['the', 'goes', 'right', 'back', 'to', 'art', 'programs'],
#  ['i', 'am', 'craving', 'my', 'creative', 'outlet'],
#  ['my', 'promise', 'is', 'in', 'front', 'of', 'me'],
#  ['my', 'excuses', 'behind', 'me'],
#  ['a',
#   "filmmaker's",
#   'journey',
#   'into',
#   'the',
#   'truth',
#   'behind',
#   'the',
#   'american',
#   'dream',
#   'reveals',
#   'life',
#   'long',
#   'lessons',
#   'taught',
#   'by',
#   "america's",
#   'greatest',
#   'innovators',
#   'and',
#   'entrepreneurs'],
#  ['a',
#   'new',
#   'feature',
#   'film',
#   'by',
#   'reid',
#   'gershbein',
#   'starring',
#   'brian',
#   'spaeth',
#   'and',
#   'kevin',
#   'r',
#   'wright'],
#  ['this',
#   'project',
#   'is',
#   'a',
#   'cross',
#   'between',
#   'do',
#   'you',
#   'believe',
#   'in',
#   'miracles'],
#  ['and', 'better', 'late', 'than', 'never'],
#  ['a',
#   '2d',
#   'wacky',
#   'actioncomedy',
#   'extravaganza',
#   'featuring',
#   'zombies',
#   'ninjas',
#   'jet',
#   'packwearing',
#   'pirates',
#   '17',
#   'weapons',
#   'online',
#   'coop',
#   'achievements',
#   'and',
#   'tons',
#   'more'],
#  ['in',
#   '1989',
#   'two',
#   'university',
#   'of',
#   'utah',
#   'chemists',
#   'announced',
#   'that',
#   'they',
#   'had',
#   'solved',
#   'all',
#   'of',
#   'the',
#   "world's",
#   'energy',
#   'problems',
#   'with',
#   'some',
#   'electricity',
#   'and',
#   'seawater',
#   'in',
#   'a',
#   'jar'],
#  ['a',
#   'bookcd',
#   'by',
#   'michael',
#   'hearst',
#   'featuring',
#   'songs',
#   'and',
#   'factoids',
#   'that',
#   'celebrate',
#   'some',
#   'of',
#   'the',
#   'most',
#   'bizarre',
#   'and',
#   'underappreciated',
#   'animals',
#   'that',
#   'roam',
#   'the',
#   'planet'],
#  ["we've",
#   'crossed',
#   'oceans',
#   'to',
#   'arrive',
#   'safely',
#   'on',
#   'home',
#   'shores',
#   'now',
#   'our',
#   'magnificent',
#   'set',
#   'awaits',
#   'us'],
#  ['we',
#   'only',
#   'have',
#   'till',
#   'sept',
#   '28th',
#   'to',
#   'reach',
#   'our',
#   'goal',
#   'of',
#   '2325'],
#  ['jesse',
#   'thorn',
#   'and',
#   'adam',
#   'lisagor',
#   'want',
#   'to',
#   'make',
#   'a',
#   'web',
#   'video',
#   'series',
#   'to',
#   'help',
#   'men',
#   'get',
#   'dressed'],
#  ['and', 'you', 'can', 'be', 'a', 'producer'],
#  ['raising',
#   'funds',
#   'in',
#   'order',
#   'to',
#   'finish',
#   'production',
#   'and',
#   'to',
#   'promote',
#   'my',
#   'new',
#   'album',
#   'this',
#   'devil',
#   'storm'],
#  ['help',
#   'me',
#   'raise',
#   'money',
#   'to',
#   'travel',
#   'to',
#   'oregon',
#   'and',
#   'record',
#   'my',
#   'new',
#   'album'],
#  ['the',
#   'falcon',
#   'lords',
#   'made',
#   'the',
#   'ultimate',
#   'party',
#   'record',
#   'about',
#   'fighting',
#   'crime',
#   'and',
#   'saving',
#   'the',
#   'city',
#   'they',
#   'love'],
#  ['back', 'this', 'project', 'now', 'to', 'receive', 'sweet', 'prizes'],
#  ['the',
#   'undergrad',
#   'records',
#   'webseries',
#   'documents',
#   'the',
#   'journey',
#   'of',
#   'a',
#   'college',
#   'grad',
#   'that',
#   'starts',
#   'an',
#   'independent',
#   'record',
#   'label'],
#  ['you', 'can', 'watch', 'five', 'episodes', 'right', 'here', 'now'],
#  ['help',
#   'us',
#   'make',
#   'the',
#   '31',
#   'remaining',
#   'episodes',
#   'of',
#   'our',
#   '1st',
#   'and',
#   '2nd',
#   'season'],
#  ['for', 'the', 'love', 'of', 'god'],
#  ['bring',
#   'historical',
#   'thinking',
#   'and',
#   'creative',
#   'fun',
#   'to',
#   'kids',
#   'in',
#   'rural',
#   'georgia',
#   'through',
#   'makebelieve',
#   'music',
#   'and',
#   'games',
#   'and',
#   'get',
#   'a',
#   'signed',
#   'copy',
#   'of',
#   "annette's",
#   'book'],
#  ['miro',
#   'is',
#   'a',
#   'free',
#   'nonprofit',
#   'and',
#   'opensource',
#   'video',
#   'player',
#   'used',
#   'by',
#   'millions',
#   'of',
#   'people'],
#  ['help',
#   'us',
#   'connect',
#   'video',
#   'makers',
#   'to',
#   'the',
#   'world',
#   'with',
#   'subtitle',
#   'support'],
#  ['faces',
#   'expressions',
#   'on',
#   'a',
#   'mask',
#   'is',
#   'a',
#   'one',
#   'man',
#   'exhibition',
#   'of',
#   'the',
#   'creative',
#   'works',
#   'of',
#   'christopher',
#   'mack'],
#  ['aux',
#   'has',
#   'invited',
#   'german',
#   'experimental',
#   'music',
#   'group',
#   'faust',
#   'for',
#   'a',
#   'performance',
#   'and',
#   'workshop',
#   'october',
#   '1011',
#   'in',
#   'athens',
#   'georgia'],
#  ['please', 'help', 'us', 'make', 'it', 'happen'],
#  ['this',
#   'fall',
#   'a',
#   'historic',
#   'photographic',
#   'project',
#   'will',
#   'be',
#   'staged',
#   'in',
#   'cambodia'],
#  ['the',
#   'reestablishment',
#   'of',
#   'art',
#   'and',
#   'culture',
#   'over',
#   'the',
#   'memory',
#   'of',
#   'genocide',
#   'is',
#   'the',
#   'goal'],
#  ['sending',
#   'americas',
#   'most',
#   'famous',
#   'graffiti',
#   'street',
#   'artists',
#   'to',
#   'sderot',
#   'on',
#   'the',
#   'border',
#   'of',
#   'gaza',
#   'to',
#   'battle',
#   'terror',
#   'rockets',
#   'with',
#   'art',
#   'messages',
#   'of',
#   'unity'],
#  ['panda',
#   'is',
#   'an',
#   'art',
#   'cafpub',
#   'which',
#   'will',
#   'feature',
#   'an',
#   'eclectic',
#   'gallery',
#   'experience',
#   'set',
#   'to',
#   'be',
#   'located',
#   'in',
#   'downtown',
#   'nyc',
#   'in',
#   'fall',
#   '2009'],
#  ['performing', 'editions', 'of', 'unpublished', 'baroque', 'music'],
#  ['my', 'dogwalker', 'has', 'been', 'missing', 'for', 'weeks'],
#  ['with',
#   'the',
#   'help',
#   'of',
#   'private',
#   'investigator',
#   'jerry',
#   'palace',
#   'i',
#   'hope',
#   'to',
#   'track',
#   'her',
#   'down',
#   'write',
#   'a',
#   'book'],
#  ['a',
#   'road',
#   'trip',
#   'film',
#   'from',
#   'lower',
#   'manhattan',
#   'into',
#   'brooklyn',
#   'reveals',
#   'how',
#   'far',
#   'some',
#   'will',
#   'go',
#   'for',
#   'personal',
#   'and',
#   'professional',
#   'glory'],
#  ['showpaper',
#   'is',
#   'an',
#   'all',
#   'ages',
#   'newsprint',
#   'listing',
#   'with',
#   'beautiful',
#   'postersize',
#   'artwork'],
#  ['please',
#   'donate',
#   'to',
#   'the',
#   'next',
#   'issue',
#   'so',
#   'we',
#   'can',
#   'keep',
#   'printing'],
#  ['music',
#   'reaches',
#   'children',
#   'with',
#   'autism',
#   'in',
#   'a',
#   'way',
#   'that',
#   'little',
#   'else',
#   'can'],
#  ['listen',
#   'learn',
#   'is',
#   'a',
#   'song',
#   'collection',
#   'for',
#   'this',
#   'special',
#   'audiencehelp',
#   'them',
#   'hear',
#   'it'],
#  ['a',
#   'largescale',
#   'meditative',
#   'painting',
#   'has',
#   'been',
#   'created',
#   'for',
#   'the',
#   'against',
#   'the',
#   'stream',
#   'buddhist',
#   'meditation',
#   'society',
#   'a',
#   'public',
#   'meditation',
#   'center',
#   'in',
#   'los',
#   'angeles'],
#  ['drawing',
#   'inspiration',
#   'from',
#   'shakespeares',
#   'sonnets',
#   'the',
#   'red',
#   'book',
#   'of',
#   'sonnets',
#   'captures',
#   'the',
#   'beautiful',
#   'brilliance',
#   'of',
#   'reflective',
#   'yet',
#   'sensuously',
#   'intimate',
#   'poetry'],
#  ['las',
#   'rubias',
#   'del',
#   'norte',
#   'need',
#   'help',
#   'to',
#   'finish',
#   'their',
#   'third',
#   'album'],
#  ['the',
#   'tracks',
#   'are',
#   'mostly',
#   'recorded',
#   'but',
#   'we',
#   'need',
#   'to',
#   'mix',
#   'and',
#   'master',
#   'by',
#   'mid',
#   'november'],
#  ['it',
#   'would',
#   'be',
#   'really',
#   'fantastic',
#   'to',
#   'see',
#   'the',
#   'florine',
#   'ep',
#   'put',
#   'on',
#   'vinyl',
#   'especially',
#   'with',
#   'the',
#   'help',
#   'of',
#   'friends'],
#  ['i',
#   'wanna',
#   'keep',
#   'my',
#   'awesome',
#   'little',
#   'label',
#   'rocking',
#   'to',
#   'release',
#   'blasted'],
#  ['order',
#   'a',
#   'copy',
#   'now',
#   'and',
#   'help',
#   'duct',
#   'tape',
#   'it',
#   'all',
#   'together'],
#  ['teaching',
#   'our',
#   'children',
#   'second',
#   'and',
#   'third',
#   'languages',
#   'is',
#   'a',
#   'must',
#   'they',
#   'are',
#   'to',
#   'compete',
#   'in',
#   'the',
#   'global',
#   'economy'],
#  ['internet',
#   'video',
#   'documentary',
#   'series',
#   'following',
#   'modernday',
#   'new',
#   'orleans',
#   'blacksmith',
#   'joe',
#   'strain',
#   'as',
#   'he',
#   'struggles',
#   'to',
#   'maintain',
#   'balance',
#   'in',
#   'his',
#   'life',
#   'and',
#   'work'],
#  ['we', 'make', 'movies', 'we', 'being', 'coldhand', 'productions'],
#  ['our',
#   'biggest',
#   'budgeting',
#   'expense',
#   'is',
#   'camera',
#   'rental',
#   'so',
#   'we',
#   'want',
#   'to',
#   'buy',
#   'a',
#   'good',
#   'one'],
#  ['giving', 'receiving', 'a', 'harmonious', 'matrimony'],
#  ['help',
#   'me',
#   'finish',
#   'recording',
#   'the',
#   'first',
#   'monahan',
#   'ep',
#   'and',
#   'receive',
#   'merchandise',
#   'and',
#   'perks',
#   'in',
#   'return'],
#  ['a',
#   'feature',
#   'length',
#   'animated',
#   'film',
#   'noir',
#   'musical',
#   'with',
#   'a',
#   'modern',
#   'twist'],
#  ['animation',
#   'and',
#   'music',
#   'melded',
#   'into',
#   'edgeofyourseat',
#   'entertainment'],
#  ['eu', 'records', 'needs', 'your', 'help'],
#  ['our',
#   'warehouses',
#   'are',
#   'overcrowded',
#   'with',
#   "cd's",
#   'and',
#   "lp's",
#   'and',
#   'we',
#   'need',
#   'to',
#   'clear',
#   'them',
#   'out',
#   'before',
#   'they',
#   'get',
#   'destroyed'],
#  ['playing',
#   'with',
#   'language',
#   'poetry',
#   'and',
#   'type',
#   'this',
#   'illustrated',
#   'story',
#   'is',
#   'about',
#   'a',
#   'dictionary',
#   'that',
#   'brings',
#   'her',
#   'words',
#   'to',
#   'life'],
#  ['we',
#   'are',
#   'building',
#   'a',
#   'mt',
#   'rushmore',
#   'style',
#   'monument',
#   'to',
#   'the',
#   'city',
#   'mayors',
#   'whose',
#   'four',
#   'jurisdictions',
#   'border',
#   'at',
#   'this',
#   'pretty',
#   'suburban',
#   'intersection'],
#  ['i',
#   'recorded',
#   'an',
#   'album',
#   'of',
#   'rock',
#   'cello',
#   'songs',
#   'six',
#   'originals',
#   'and',
#   'five',
#   'covers'],
#  ["it's", 'ready', 'to', 'be', 'mastered', 'printed', 'and', 'released'],
#  ["let's",
#   'help',
#   'freelancers',
#   'and',
#   'small',
#   'businesses',
#   'collect',
#   'money',
#   'they',
#   'are',
#   'owed',
#   'by',
#   'exposing',
#   'the',
#   'businesses',
#   'that',
#   'have',
#   'stiffed',
#   'them',
#   'on',
#   'payment',
#   'and',
#   "don't",
#   'pay'],
#  ['an',
#   'exploration',
#   'into',
#   'statistical',
#   'displays',
#   'on',
#   'kickstartercom'],
#  ['for',
#   'this',
#   'endeavor',
#   "we're",
#   'pulling',
#   'in',
#   'nicholas',
#   'felton',
#   'famed',
#   'information',
#   'graphic',
#   'designer'],
#  ['a',
#   'positive',
#   'feedback',
#   'mechanism',
#   'for',
#   'wasting',
#   'company',
#   'time',
#   'on',
#   'the',
#   'internet'],
#  ['exploring',
#   'a',
#   'classic',
#   'style',
#   'of',
#   'portraiture',
#   'and',
#   'figurative',
#   'painting',
#   'inspired',
#   'by',
#   'social',
#   'networking',
#   'and',
#   'crowd',
#   'participation'],
#  ['this',
#   'project',
#   'is',
#   'to',
#   'help',
#   'a',
#   'communtiy',
#   'concert',
#   'series',
#   'that',
#   'has',
#   'been',
#   'taking',
#   'place',
#   'for',
#   'the',
#   'past',
#   'three',
#   'years',
#   'in',
#   'are',
#   'community',
#   'of',
#   'muncie',
#   'indiana'],
#  ['dream',
#   'with',
#   'mea',
#   'documentary',
#   'that',
#   'will',
#   'change',
#   'the',
#   'face',
#   'of',
#   'public',
#   'education',
#   'in',
#   'america'],
#  ['telegraph21',
#   'is',
#   'a',
#   'curated',
#   'video',
#   'space',
#   'with',
#   'a',
#   'focus',
#   'on',
#   'nonfiction',
#   'storytelling',
#   'and',
#   'art',
#   'from',
#   'around',
#   'the',
#   'world'],
#  ['we', 'help', 'filmmakers', 'to', 'promote', 'their', 'work'],
#  ["lucia'stories",
#   'is',
#   'a',
#   'dominican',
#   'bilingual',
#   'collection',
#   'of',
#   'illustrated',
#   'children',
#   'books'],
#  ['created',
#   'by',
#   'anya',
#   'damirn',
#   'and',
#   'illustrated',
#   'by',
#   'pablo',
#   'pino'],
#  ['first',
#   'time',
#   'is',
#   'a',
#   'short',
#   'film',
#   'that',
#   'needs',
#   'funding',
#   'to',
#   'be',
#   'completed'],
#  ['it', 'will', 'then', 'be', 'sent', 'to', 'festivals'],
#  ['help',
#   'produce',
#   '5000',
#   'or',
#   'be',
#   'a',
#   'part',
#   'of',
#   'our',
#   'production'],
#  ['my',
#   'goal',
#   'is',
#   'to',
#   'create',
#   'an',
#   'album',
#   'that',
#   'will',
#   'bring',
#   'inspiration',
#   'to',
#   'all'],
#  ['concerned',
#   'for',
#   'the',
#   'future',
#   'of',
#   'the',
#   'arts',
#   'i',
#   'began',
#   'bone',
#   'for',
#   'a',
#   'brush',
#   'to',
#   'help',
#   'the',
#   'nyc',
#   'public',
#   'school',
#   'system',
#   'improve',
#   'their',
#   'art',
#   'and',
#   'music',
#   'programs'],
#  ['translating',
#   'moby',
#   'dick',
#   'into',
#   'japanese',
#   'emoji',
#   'icons',
#   'using',
#   "amazon's",
#   'mechanical',
#   'turk'],
#  ['to',
#   'raise',
#   '3000',
#   'to',
#   'make',
#   'the',
#   'first',
#   'thousand',
#   'copies',
#   'of',
#   'my',
#   'first',
#   'album',
#   'beautifully',
#   'damaged'],
#  ['the',
#   'physical',
#   'copies',
#   'are',
#   'much',
#   'needed',
#   'to',
#   'promote',
#   'the',
#   'music'],
#  ['turba',
#   'is',
#   'a',
#   'puzzle',
#   'game',
#   'that',
#   'lets',
#   'you',
#   'use',
#   'any',
#   'music',
#   'on',
#   'your',
#   'computer',
#   'to',
#   'shape',
#   'how',
#   'the',
#   'game',
#   'is',
#   'played'],
#  ['it', 'is', 'being', 'developed', 'by', '2', 'recent', 'college', 'grads'],
#  ['you',
#   'can',
#   'help',
#   'put',
#   'indierootsrock',
#   'band',
#   'back',
#   'on',
#   'track',
#   'and',
#   'on',
#   'tour'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'make',
#   'a',
#   'film',
#   'in',
#   'nepal',
#   'and',
#   'have',
#   'an',
#   'amazing',
#   'costeffective',
#   'opportunity',
#   'to',
#   'do',
#   'so'],
#  ['please', 'visit', 'the', 'website', 'for', 'details'],
#  ['jen',
#   'woodhouse',
#   'is',
#   'hitting',
#   'the',
#   'road',
#   'this',
#   'fall',
#   'but',
#   'she',
#   "can't",
#   'do',
#   'it',
#   'without',
#   'your',
#   'help'],
#  ['back',
#   'her',
#   'project',
#   'and',
#   'get',
#   'cool',
#   'exclusive',
#   'stuff',
#   'in',
#   'return'],
#  ['2500',
#   'princeton',
#   'graduate',
#   'alumni',
#   'saw',
#   'this',
#   'watercolor',
#   'on',
#   'their',
#   '2007',
#   'school',
#   'holiday',
#   'card'],
#  ['get', 'your', 'signed', 'and', 'numbered', 'prints', 'and', 'cards'],
#  ['is', 'it', 'the', 'erector', 'set', 'of', 'the', 'internet', 'age'],
#  ['or',
#   'is',
#   'it',
#   'the',
#   'bones',
#   'and',
#   'gristle',
#   'of',
#   'an',
#   'open',
#   'source',
#   'revolution'],
#  ['minit', 'by', 'makerbeam', 'is', 'both'],
#  ['mof',
#   'is',
#   'a',
#   'multiscreen',
#   'video',
#   'piece',
#   'projected',
#   'onto',
#   'the',
#   'water',
#   'and',
#   'concrete',
#   'wall',
#   'of',
#   'a',
#   'shallow',
#   'river',
#   'in',
#   'north',
#   'adams',
#   'made',
#   'for',
#   'the',
#   'hoosac',
#   'river',
#   'lights',
#   'iia'],
#  ['11', 'andy', 'warhol', 'paintings', 'were', 'just', 'stolen', 'in', 'la'],
#  ['help',
#   'get',
#   'the',
#   'wordand',
#   'imagesout',
#   'with',
#   'these',
#   'giant',
#   'crime',
#   'alert',
#   'posters'],
#  ['also', "there's", 'a', '1mm', 'reward'],
#  ['my',
#   'ukulele',
#   'act',
#   'helen',
#   "keller's",
#   'ukulele',
#   'is',
#   'going',
#   'to',
#   'berlin',
#   'in',
#   'nov',
#   'dec'],
#  ['in',
#   'short',
#   'i',
#   'must',
#   'have',
#   "cd's",
#   'printed',
#   'to',
#   'take',
#   'with',
#   'me',
#   'as',
#   'well',
#   'as',
#   'travel',
#   'expenses'],
#  ['your',
#   'donation',
#   'will',
#   'go',
#   'directly',
#   'to',
#   'the',
#   'purchase',
#   'of',
#   'art',
#   'supplies',
#   'books',
#   'and',
#   'education',
#   'for',
#   'the',
#   'children',
#   'in',
#   'the',
#   'isithumba',
#   'village',
#   'in',
#   'south',
#   'africa'],
#  ['am1610',
#   'the',
#   'station',
#   'a',
#   'noncommercial',
#   'low',
#   'power',
#   'am',
#   'radio',
#   'station',
#   'broadcasting',
#   'in',
#   'hamtramck',
#   'mi'],
#  ["i'd",
#   'like',
#   'to',
#   'build',
#   'a',
#   'studio',
#   'and',
#   'play',
#   'local',
#   'vinyl'],
#  ['a',
#   'photoessay',
#   'book',
#   'about',
#   'managing',
#   'living',
#   'well',
#   'with',
#   'bipolar',
#   'disorder'],
#  ['we',
#   'are',
#   'clare',
#   'and',
#   'the',
#   'reasons',
#   'a',
#   'brooklyn',
#   'based',
#   'band'],
#  ['our',
#   'second',
#   'album',
#   'arrow',
#   'comes',
#   'out',
#   'oct',
#   '20thwe',
#   'just',
#   'want',
#   'to',
#   'play',
#   'for',
#   'you'],
#  ['help', 'us', 'finish', 'our', 'cd', 'and', 'promote', 'it', 'correctly'],
#  ['master',
#   'print',
#   'up',
#   'promotional',
#   'materials',
#   'manufacture',
#   'discs',
#   'etc'],
#  ['make',
#   'an',
#   'awardwinning',
#   'short',
#   'story',
#   'available',
#   'on',
#   'the',
#   'net',
#   'in',
#   'perpetuity',
#   'under',
#   'a',
#   'creative',
#   'commons',
#   'license'],
#  ['a',
#   'road',
#   'movie',
#   'following',
#   'the',
#   'chinese',
#   'reconstruction',
#   'of',
#   'the',
#   'benguela',
#   'railway',
#   'in',
#   'angola'],
#  ["it's",
#   'the',
#   'epicenter',
#   'of',
#   "china's",
#   'ascent',
#   'as',
#   'the',
#   'next',
#   'superpower'],
#  ["i'm",
#   'replacing',
#   'this',
#   'project',
#   'with',
#   'another',
#   'one',
#   'for',
#   'the',
#   'same',
#   'watercolor',
#   'httpwwwkickstartercomprojectsdavidliaochristmaswatercolorforsale'],
#  ['i',
#   'painted',
#   'this',
#   'art',
#   'as',
#   'a',
#   'commission',
#   'for',
#   'a',
#   'card',
#   'princeton',
#   'sent',
#   '2500',
#   'alumni',
#   'in',
#   '2007'],
#  ['if',
#   'pledges',
#   'meet',
#   'my',
#   'bounty',
#   'i',
#   'release',
#   'the',
#   'art',
#   'to',
#   'the',
#   'public',
#   'domain'],
#  ['3d',
#   'fabrication',
#   'is',
#   'all',
#   'the',
#   'rage',
#   'but',
#   'costly',
#   'machines',
#   'and',
#   'slow',
#   'turn',
#   'around',
#   'times',
#   'hinder',
#   'innovation'],
#  ['help',
#   'us',
#   'start',
#   'up',
#   'the',
#   'first',
#   'free',
#   '3d',
#   'printing',
#   'service'],
#  ['what',
#   'if',
#   'the',
#   'stories',
#   'in',
#   'the',
#   'bible',
#   'especially',
#   'those',
#   'about',
#   'strong',
#   'women',
#   'were',
#   'retuld',
#   'by',
#   'their',
#   'own',
#   'characters'],
#  ["i've", 'completed', '5', 'and', 'am', 'ready', 'to', 'publish'],
#  ['the',
#   'finney',
#   'brothers',
#   'mike',
#   'and',
#   'scott',
#   'are',
#   'going',
#   'to',
#   'release',
#   'a',
#   'cd',
#   'of',
#   'their',
#   'original',
#   'classical',
#   'music'],
#  ['a',
#   'documentary',
#   'of',
#   'a',
#   "woman's",
#   'quest',
#   'to',
#   'understand',
#   'the',
#   'roots',
#   'of',
#   'her',
#   "family's",
#   'poverty',
#   'and',
#   'homelessness',
#   'reveals',
#   'a',
#   'national',
#   'history',
#   'of',
#   'displacement',
#   'and',
#   'loss'],
#  ['a',
#   'late',
#   'night',
#   'talk',
#   'show',
#   'along',
#   'the',
#   'lines',
#   'of',
#   'the',
#   'tonight',
#   'showcharlie',
#   'rose',
#   'only',
#   "it's",
#   'going',
#   'to',
#   'be',
#   'entertaining'],
#  ['dadaists',
#   'gone',
#   'wild',
#   '2a',
#   'dadaistsurrealist',
#   'platformer',
#   'game',
#   'for',
#   'the',
#   'pc',
#   'that',
#   'is',
#   'a',
#   'much',
#   'larger',
#   'sequel',
#   'to',
#   'the',
#   'freeware',
#   'game',
#   'dadaists',
#   'gone',
#   'wild'],
#  ['flywrench',
#   'is',
#   'a',
#   'game',
#   'that',
#   "i've",
#   'been',
#   'working',
#   'on',
#   'for',
#   'the',
#   'past',
#   'two',
#   'years',
#   'and',
#   'it',
#   'needs',
#   'funding'],
#  ['we',
#   'started',
#   'with',
#   'a',
#   'story',
#   'that',
#   'brings',
#   'visceral',
#   'magic',
#   'back',
#   'to',
#   'the',
#   'world',
#   'and',
#   'now',
#   "we're",
#   'ready',
#   'to',
#   'bring',
#   'it',
#   'to',
#   'you'],
#  ['texas',
#   'is',
#   'south',
#   'is',
#   'our',
#   'project',
#   'to',
#   'bring',
#   'local',
#   'bands',
#   'from',
#   'all',
#   'over',
#   'the',
#   'state',
#   'of',
#   'texas',
#   'to',
#   'one',
#   'community'],
#  ['we',
#   'are',
#   'attempting',
#   'to',
#   'build',
#   'the',
#   'first',
#   'underground',
#   'musicianartist',
#   'directory',
#   'by',
#   'incorporating',
#   'their',
#   'works',
#   'into',
#   'an',
#   'ongoing',
#   'animated',
#   'web',
#   'series'],
#  ['resonance',
#   'is',
#   'an',
#   'ambitious',
#   'retrostyled',
#   'pointandclick',
#   'adventure',
#   'game',
#   'that',
#   'brings',
#   'a',
#   'mature',
#   'storyline',
#   'and',
#   'some',
#   'innovative',
#   'new',
#   'gameplay',
#   'to',
#   'the',
#   'genre'],
#  ['hollie',
#   'la',
#   'needs',
#   'your',
#   'support',
#   'to',
#   'make',
#   'her',
#   'very',
#   'first',
#   'music',
#   'video'],
#  ['she',
#   'is',
#   'an',
#   'indie',
#   'pop',
#   'artist',
#   'who',
#   'needs',
#   'a',
#   'hot',
#   'video',
#   'for',
#   'her',
#   'hot',
#   'new',
#   'single',
#   'poison'],
#  ['home', 'base', 'is', 'an', 'independent', 'puzzle', 'game'],
#  ["it's",
#   'nearing',
#   'completion',
#   'and',
#   'i',
#   'could',
#   'use',
#   'your',
#   'support',
#   'in',
#   'my',
#   'effort',
#   'to',
#   'sell',
#   'the',
#   'game'],
#  ["i'm",
#   'writing',
#   'a',
#   'detective',
#   'story',
#   'set',
#   'halfway',
#   'between',
#   'san',
#   'francisco',
#   'and',
#   'the',
#   'internet'],
#  ['and',
#   'the',
#   'more',
#   'people',
#   'who',
#   'reserve',
#   'a',
#   'copy',
#   'the',
#   'better',
#   'each',
#   'one',
#   'will',
#   'be'],
#  ['a', 'short', 'film', 'about', 'caring', 'for', 'people'],
#  ['the', 'film', 'was', 'shot', 'for', 'nothing'],
#  ['sadly', 'festivals', 'need', 'fees'],
#  ['we',
#   'hope',
#   'to',
#   'record',
#   'our',
#   'next',
#   'full',
#   'length',
#   'album',
#   'to',
#   'vinyl',
#   'with',
#   'the',
#   'help',
#   'of',
#   'those',
#   'who',
#   'believe',
#   'in',
#   'us'],
#  ['its',
#   'been',
#   'a',
#   'dream',
#   'of',
#   'ours',
#   'to',
#   'have',
#   'a',
#   'great',
#   'lp',
#   'on',
#   'vinyl'],
#  ['i',
#   'want',
#   'to',
#   'construct',
#   'some',
#   'original',
#   'interconnected',
#   'holidaythemed',
#   'crosswords',
#   'for',
#   'you',
#   'to',
#   'solve',
#   'pencilpaper',
#   'not',
#   'included'],
#  ['citizen',
#   'icon',
#   'seeking',
#   'team',
#   'members',
#   'to',
#   'invest',
#   'in',
#   'our',
#   'new',
#   'ep'],
#  ['needing',
#   'funding',
#   'for',
#   'the',
#   'gay',
#   'bigfoot',
#   'show',
#   'animation',
#   'pilot',
#   'which',
#   'is',
#   'a',
#   'cross',
#   'between',
#   'space',
#   'ghost',
#   'coast',
#   'to',
#   'coast',
#   'celebrity',
#   'interviews',
#   'and',
#   'queer',
#   'duck'],
#  ['the',
#   'foundsound',
#   'beat',
#   'manglers',
#   'ken',
#   'rei',
#   'are',
#   'putting',
#   'out',
#   'an',
#   'lp'],
#  ["don't",
#   'miss',
#   'your',
#   'chance',
#   'to',
#   'get',
#   'in',
#   'on',
#   'the',
#   'space',
#   'crunk',
#   'thrash',
#   'and',
#   'custom',
#   'gear',
#   'gameboys'],
#  ['dr',
#   'bonesaw',
#   'is',
#   'like',
#   "grey's",
#   'anatomy',
#   'with',
#   'a',
#   'serial',
#   'murderer',
#   'on',
#   'the',
#   'loose',
#   'and',
#   'we',
#   'plan',
#   'to',
#   'go',
#   'a',
#   'little',
#   'crazy',
#   'and',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'fun',
#   'making',
#   'it'],
#  ['help',
#   'us',
#   'pay',
#   'for',
#   'the',
#   'entry',
#   'fee',
#   'to',
#   'the',
#   'independent',
#   'games',
#   'festival',
#   'for',
#   'saturated',
#   'dreamers',
#   'for',
#   'its',
#   'use',
#   'of',
#   'the',
#   'fmod',
#   'sound',
#   'engine',
#   'and',
#   'other',
#   'misc'],
#  ['three',
#   'of',
#   'us',
#   'are',
#   'composers',
#   'and',
#   'all',
#   'of',
#   'us',
#   'are',
#   'performers'],
#  ['we',
#   'have',
#   'a',
#   '90minute',
#   'program',
#   'featuring',
#   'new',
#   'chamber',
#   'works',
#   'and',
#   "we're",
#   'taking',
#   'it',
#   'on',
#   'the',
#   'road'],
#  ['the', 'loom', 'is', 'recording', 'our', 'first', 'fulllength', 'album'],
#  ['help',
#   'us',
#   'make',
#   'it',
#   'happen',
#   'and',
#   'get',
#   'rewards',
#   'in',
#   'return'],
#  ['i',
#   'need',
#   'more',
#   'is',
#   'a',
#   'new',
#   'project',
#   'by',
#   'brooklyn',
#   'ny',
#   'based',
#   'choreographermusicianartist',
#   'nancy',
#   'garcia'],
#  ['hi',
#   'i',
#   'made',
#   'a',
#   'music',
#   'video',
#   'the',
#   'video',
#   'needs',
#   'promotion',
#   'so',
#   'i',
#   'can',
#   'get',
#   'airplay',
#   'on',
#   'shows',
#   'like',
#   'mtvbet',
#   'etc'],
#  ['i', 'appreciate', 'every', 'fan', 'and', 'supporters', 'help'],
#  ['get',
#   'original',
#   'art',
#   'and',
#   'help',
#   'restore',
#   '400',
#   'of',
#   '500',
#   'oil',
#   'paintings',
#   'on',
#   'paper',
#   'that',
#   'are',
#   'partially',
#   'stuck',
#   'to',
#   'their',
#   'archival',
#   'interleaving'],
#  ['be', 'a', 'part', 'of', 'it'],
#  ['we',
#   'are',
#   'starting',
#   'up',
#   'an',
#   'etsy',
#   'store',
#   'to',
#   'sell',
#   'our',
#   'artwork',
#   'and',
#   'raise',
#   'funds',
#   'for',
#   'medical',
#   'and',
#   'mission',
#   'work',
#   'around',
#   'the',
#   'globe'],
#  ['help', 'us', 'buy', 'equipment'],
#  ['derek',
#   'james',
#   'is',
#   'pregnant',
#   'with',
#   'a',
#   'new',
#   'album',
#   'and',
#   'needs',
#   'you',
#   'to',
#   'deliver'],
#  ['you', 'be', 'the', 'label', "i'll", 'make', 'the', 'record'],
#  ['like', 'manga', 'or', 'art', 'work'],
#  ['i', 'have', '5', 'mangas', 'and', 'plenty', 'of', 'art', 'work'],
#  ["i'm",
#   'recording',
#   'a',
#   'fivesong',
#   'album',
#   'and',
#   'i',
#   'have',
#   'to',
#   'get',
#   '3000',
#   'before',
#   'i',
#   'can',
#   'start',
#   'making',
#   'the',
#   'cd'],
#  ['help',
#   'the',
#   'tristates',
#   'only',
#   'allages',
#   'music',
#   'listing',
#   'print',
#   'our',
#   'next',
#   'issue'],
#  ['move',
#   'to',
#   'detroit',
#   'for',
#   '1',
#   'a',
#   'square',
#   'inch',
#   'and',
#   'join',
#   'the',
#   'adventures',
#   'of',
#   'loveland'],
# ...
#   'out'],
#  ['lumi',
#   'co',
#   'creates',
#   'prints',
#   'that',
#   'were',
#   'previously',
#   'impossible'],
#  ['using',
#   'their',
#   'new',
#   'technology',
#   'two',
#   'young',
#   'designers',
#   'want',
#   'to',
#   'turn',
#   'the',
#   'fashion',
#   'world',
#   'upside',
#   'down'],
#  ['calmplex',
#   'of',
#   'shadow',
#   'of',
#   'the',
#   'locust',
#   'is',
#   'putting',
#   'out',
#   'his',
#   'first',
#   'full',
#   'length',
#   'solo',
#   'album',
#   'solar',
#   'wind',
#   'theory',
#   'in',
#   'july',
#   '2010',
#   'and',
#   'he',
#   'needs',
#   'your',
#   'help'],
#  ['see',
#   'us',
#   'marines',
#   'make',
#   'counterinsurgency',
#   'work',
#   'in',
#   'helmand',
#   'provincethe',
#   "taliban's",
#   'stronghold',
#   'in',
#   'afghanistan'],
#  ['deathless',
#   'is',
#   'a',
#   'work',
#   'of',
#   'anthropomorphic',
#   'fiction',
#   'where',
#   'each',
#   'page',
#   'is',
#   '500',
#   'words'],
#  ["it's",
#   'inspired',
#   'by',
#   'works',
#   'from',
#   'such',
#   'authors',
#   'as',
#   'stephen',
#   'king',
#   'and',
#   'dean',
#   'koontz'],
#  ['10',
#   'people',
#   'from',
#   'around',
#   'the',
#   'world',
#   'that',
#   'were',
#   'sexually',
#   'abused',
#   'by',
#   'a',
#   'family',
#   'member',
#   'and',
#   'are',
#   'thriving',
#   'today'],
#  ['this',
#   'project',
#   'is',
#   'to',
#   'help',
#   'get',
#   'our',
#   'recently',
#   'recorded',
#   'material',
#   'mixed',
#   'mastered',
#   'and',
#   'released'],
#  ['a',
#   'book',
#   'about',
#   'silicon',
#   'valley',
#   'startups',
#   'oriented',
#   'towards',
#   'and',
#   'for',
#   'engineers'],
#  ['why',
#   'to',
#   'join',
#   'a',
#   'startup',
#   'what',
#   'to',
#   'do',
#   'to',
#   'maximize',
#   'financial',
#   'advantages'],
#  ["ian's", 'finally', 'going', 'to', 'record', 'an', 'album'],
#  ["he's",
#   'selfproducing',
#   'and',
#   'selfrecording',
#   'the',
#   'album',
#   'but',
#   'he',
#   'needs',
#   'help',
#   'paying',
#   'for',
#   'artwork',
#   'and',
#   'getting',
#   'discs',
#   'made'],
#  ['musicians',
#   'carolina',
#   'story',
#   'and',
#   'whiskey',
#   'king',
#   'coalition',
#   'will',
#   'be',
#   'playing',
#   'over',
#   '10',
#   'shows',
#   'in',
#   '10',
#   'cities',
#   'to',
#   'the',
#   'west',
#   'coast'],
#  ["we're",
#   'three',
#   'students',
#   'from',
#   'new',
#   'york',
#   'who',
#   'want',
#   'to',
#   'make',
#   'a',
#   'documentary',
#   'as',
#   'we',
#   'travel',
#   'across',
#   'the',
#   'country'],
#  ['got',
#   'an',
#   'old',
#   'bomb',
#   'filling',
#   'it',
#   'with',
#   'poetry',
#   'taking',
#   'it',
#   'on',
#   'the',
#   'road'],
#  ['the',
#   'poetry',
#   'bomb',
#   'is',
#   'global',
#   'community',
#   'literacy',
#   'outreach'],
#  ['poetry', 'is', 'the', 'bomb', 'submit'],
#  ['atlanta',
#   'rock',
#   'band',
#   'trances',
#   'arc',
#   'embarks',
#   'on',
#   'its',
#   'second',
#   'full',
#   'length',
#   'recording',
#   'project',
#   'and',
#   'needs',
#   'your',
#   'help',
#   'to',
#   'release',
#   'it',
#   'into',
#   'the',
#   'wild'],
#  ['the', 'somewhat', 'comical', 'adventures', 'of', 'prickley', 'pete'],
#  ['zoop', 'to', 'the', 'future'],
#  ['is',
#   'a',
#   'new',
#   'pointnclick',
#   'adventure',
#   'game',
#   'starring',
#   'prickley',
#   'pete'],
#  ['my',
#   'new',
#   'cd',
#   'is',
#   'in',
#   'the',
#   'works',
#   'but',
#   'a',
#   'packaging',
#   'tweak',
#   'might',
#   'push',
#   'me',
#   'over',
#   'budget'],
#  ['justin',
#   "dicenzo's",
#   'first',
#   'album',
#   'in',
#   'japanese',
#   'and',
#   'about',
#   'one',
#   'of',
#   'his',
#   'passions',
#   'food'],
#  ['a', "'zine", 'to', 'instigate', 'art', 'conspiracies'],
#  ['an', 'audio', 'collage', 'to', 'reverberate', 'the', 'renaissance'],
#  ['an', 'online', 'game', 'to', 'make', 'your', 'art', 'zing'],
#  ['victory',
#   'and',
#   'associates',
#   'is',
#   'a',
#   'new',
#   'band',
#   'from',
#   'sf',
#   'formed',
#   'from',
#   'people',
#   'in',
#   'other',
#   'bands'],
#  ['you',
#   'probably',
#   "don't",
#   'know',
#   'them',
#   'this',
#   'is',
#   'their',
#   'debut',
#   'double',
#   'aside',
#   '7'],
#  ['working', 'on', 'an', 'ep', 'of', '4', 'songs'],
#  ['looking',
#   'forward',
#   'to',
#   'recording',
#   'and',
#   'releasing',
#   'this',
#   'new',
#   'music'],
#  ['thanks', 'for', 'your', 'support'],
#  ['candle', 'holders', 'in', 'polished', 'aluminum', 'and', 'bronze'],
#  ['aluminum',
#   'holds',
#   'a',
#   'taper',
#   'on',
#   'one',
#   'side',
#   'and',
#   'a',
#   'tea',
#   'light',
#   'on',
#   'the',
#   'other'],
#  ['the', 'bronze', 'holds', 'tapers', 'only'],
#  ['photographer',
#   'j',
#   'koons',
#   'travels',
#   'to',
#   'peru',
#   'to',
#   'teach',
#   'locals',
#   'how',
#   'to',
#   'capture',
#   'images',
#   'of',
#   'surfing'],
#  ['we',
#   'document',
#   'his',
#   'experience',
#   'that',
#   'will',
#   'transform',
#   'his',
#   'world',
#   'view'],
#  ["we're",
#   'working',
#   'on',
#   'our',
#   'debut',
#   'album',
#   'and',
#   'we',
#   'want',
#   'you',
#   'to',
#   'be',
#   'a',
#   'part',
#   'of',
#   'it'],
#  ['of',
#   'course',
#   "there's",
#   'something',
#   'in',
#   'it',
#   'for',
#   'you',
#   'if',
#   'you',
#   'can',
#   'give',
#   'us',
#   'a',
#   'little',
#   'kickstart'],
#  ['meet',
#   'talented',
#   'songwriters',
#   'as',
#   'they',
#   'perform',
#   'their',
#   'works',
#   'and',
#   'discuss',
#   'the',
#   'craft',
#   'of',
#   'songwriting',
#   'as',
#   'well',
#   'as',
#   'their',
#   'life',
#   'as',
#   'an',
#   'artist'],
#  ['a',
#   'soaring',
#   'cohesive',
#   'collection',
#   'of',
#   'rock',
#   'songs',
#   'that',
#   'inspires',
#   'fearless',
#   'living',
#   'through',
#   'fearless',
#   'music'],
#  ['help',
#   'us',
#   'fund',
#   'a',
#   'great',
#   'local',
#   'band',
#   'show',
#   'in',
#   'lowell',
#   'ma'],
#  ['the',
#   'city',
#   'and',
#   'the',
#   'people',
#   'who',
#   'live',
#   'there',
#   'really',
#   'deserve',
#   'to',
#   'have',
#   'this',
#   'happen'],
#  ['the',
#   'portal',
#   'project',
#   'asks',
#   'can',
#   'artists',
#   'support',
#   'themselves',
#   'through',
#   'their',
#   'work',
#   'outside',
#   'of',
#   'the',
#   'traditional',
#   'topdown',
#   'structures',
#   'of',
#   'arts',
#   'administration'],
#  ['the',
#   'gopher',
#   'is',
#   'a',
#   'limitededition',
#   'magazine',
#   'that',
#   'is',
#   'customizable',
#   'by',
#   'the',
#   'reader'],
#  ['it',
#   'features',
#   'arts',
#   'literature',
#   'journalism',
#   'with',
#   'meticulous',
#   'production'],
#  ['timber',
#   'is',
#   'raising',
#   'money',
#   'for',
#   'the',
#   'release',
#   'of',
#   'scrawled',
#   'on',
#   'cowboy',
#   'angel',
#   'records',
#   'in',
#   '2010'],
#  ['donations', 'will', 'be', 'met', 'with', 'handsome', 'rewards'],
#  ['in',
#   'march',
#   '2010',
#   'sxsw',
#   'hosts',
#   'its',
#   'first',
#   'showcase',
#   'of',
#   'oldschool',
#   'new',
#   'orleans',
#   'bounce',
#   'straight',
#   'up',
#   'hiphop',
#   'party',
#   'music'],
#  ['help', 'send', 'us', 'to', 'austin'],
#  ['with',
#   'all',
#   'of',
#   'the',
#   'promising',
#   'developments',
#   'of',
#   'caitlin',
#   'krisko',
#   'the',
#   'broadcast',
#   'the',
#   'band',
#   'is',
#   'in',
#   'need',
#   'of',
#   'safe',
#   'transporation',
#   'to',
#   'spread',
#   'their',
#   'music',
#   'nationally'],
#  ['a',
#   'book',
#   'of',
#   'stories',
#   'photos',
#   'about',
#   'sex',
#   'as',
#   'it',
#   'really',
#   'is',
#   'messy',
#   'awkward',
#   'hilarious',
#   'painful',
#   'true'],
#  ['pledge', 'and', 'get', 'a', 'copy', 'of', 'our', 'upcoming', 'album'],
#  ['cubicide',
#   'is',
#   'a',
#   'dark',
#   'comedy',
#   'novel',
#   'by',
#   'former',
#   'la',
#   'times',
#   'writer',
#   'and',
#   'professional',
#   'comedian',
#   'katie',
#   'love'],
#  ['funding', 'will', 'be', 'used', 'to', 'promoteadvertise', 'cubicide'],
#  ['this',
#   'book',
#   'surveys',
#   'recent',
#   'research',
#   'into',
#   'the',
#   'medical',
#   'properties',
#   'of',
#   'cannabis',
#   'particularly',
#   'for',
#   'treatment',
#   'of',
#   'cancer',
#   'and',
#   'other',
#   'serious',
#   'illnesses'],
#  ['support',
#   'the',
#   'research',
#   'development',
#   'of',
#   'a',
#   'land',
#   'walker',
#   'prototype',
#   'for',
#   'disabled',
#   'wheelchair',
#   'users'],
#  ['all', 'humans', 'have', 'the', 'right', 'to', 'walk', 'upright'],
#  ['held',
#   'in',
#   'austin',
#   'tx',
#   'during',
#   'the',
#   'week',
#   'of',
#   'sxsw',
#   'datapop',
#   'is',
#   'one',
#   'of',
#   'the',
#   'top',
#   '8bit',
#   'music',
#   'events',
#   'in',
#   'the',
#   'country',
#   'we',
#   'need',
#   'your',
#   'help',
#   'with',
#   'artist',
#   'travel',
#   'costs'],
#  ['aspiring', 'photojournalist', 'seeks', 'dslr'],
#  ['must',
#   'love',
#   'travel',
#   'organic',
#   'farming',
#   'and',
#   'community',
#   'journalism'],
#  ['san',
#   'diegianmexican',
#   'artist',
#   'improvises',
#   'studio',
#   'space',
#   'and',
#   'finds',
#   'inspiration',
#   'in',
#   'the',
#   'subways',
#   'and',
#   'cafes',
#   'of',
#   'nyc'],
#  ['and', 'then', 'he', 'publishes', 'a', 'book', 'about', 'it'],
#  ['6',
#   'months',
#   'ago',
#   'an',
#   'azeri',
#   'filmmaker',
#   'turkish',
#   'poet',
#   'maine',
#   'philosopher',
#   'began',
#   'collaboration',
#   'on',
#   'a',
#   'radical',
#   'short',
#   'film',
#   'but',
#   'they',
#   'need',
#   'your',
#   'help',
#   'to',
#   'finish',
#   'it'],
#  ['bright',
#   'bike',
#   'diy',
#   'kits',
#   'make',
#   'riding',
#   'a',
#   'bike',
#   'at',
#   'night',
#   'safer'],
#  ['scale', 'this', 'project', 'up', 'to', 'make', 'riding', 'safer'],
#  ['i',
#   'published',
#   'a',
#   'young',
#   'adultteen',
#   'fiction',
#   'book',
#   'that',
#   'answers',
#   'the',
#   'question',
#   'what',
#   'is',
#   'my',
#   'purpose'],
#  ['through',
#   'the',
#   'story',
#   'of',
#   'a',
#   'teen',
#   'orphan',
#   'girl',
#   'in',
#   'the',
#   'inner',
#   'city'],
#  ['national',
#   'underground',
#   'films',
#   'and',
#   'records',
#   'live',
#   'sets',
#   'of',
#   'your',
#   'favorite',
#   'bands',
#   'and',
#   'posts',
#   'them',
#   'for',
#   'free',
#   'online'],
#  ['backers', 'will', 'receive', 'unreleased', 'material'],
#  ["we're",
#   'taking',
#   'a',
#   'train',
#   'from',
#   'nyc',
#   'to',
#   'cleveland',
#   'bringing',
#   'our',
#   'digital',
#   'cameras'],
#  ['a',
#   'new',
#   'film',
#   'directed',
#   'by',
#   'gina',
#   'telaroli',
#   'wmeerkat',
#   'media',
#   'the',
#   'goddamn',
#   'cobras'],
#  ['sgt',
#   'dunbar',
#   'the',
#   'hobo',
#   'banned',
#   'got',
#   'accepted',
#   'to',
#   'showcase',
#   'at',
#   'this',
#   'years',
#   'sxsw',
#   'festival',
#   'but',
#   'its',
#   '1843',
#   'miles',
#   'from',
#   'home',
#   'our',
#   'van',
#   'needs',
#   'help',
#   'and',
#   'we',
#   'are',
#   'broke'],
#  ['fund',
#   'the',
#   'release',
#   'of',
#   'a',
#   '4000',
#   'word',
#   'comic',
#   'science',
#   'fiction',
#   'story'],
#  ["it's",
#   'about',
#   'crossspecies',
#   'exploitation',
#   'and',
#   'the',
#   'last',
#   'survivor',
#   'of',
#   'a',
#   'proud',
#   'warrior',
#   'race'],
#  ['the',
#   'chordials',
#   'would',
#   'like',
#   'to',
#   'record',
#   'a',
#   'new',
#   'cd',
#   'with',
#   'tons',
#   'of',
#   'fancy',
#   'solos',
#   'but',
#   'our',
#   'bank',
#   'account',
#   'is',
#   'empty'],
#  ['support', 'a', 'capella', 'and', 'help', 'us', 'sing'],
#  ["we're",
#   'midnight',
#   'hour',
#   'from',
#   'orange',
#   'county',
#   'ca',
#   'and',
#   'we',
#   'need',
#   'your',
#   'help',
#   'to',
#   'finally',
#   'record',
#   'our',
#   'debut',
#   'record',
#   'after',
#   '4',
#   'years'],
#  ['plus', "you'll", 'get', 'cool', 'stuff'],
#  ['help',
#   'fund',
#   'development',
#   'of',
#   'this',
#   'coming',
#   'of',
#   'age',
#   'drama',
#   'as',
#   'it',
#   'heads',
#   'to',
#   'los',
#   'angeles',
#   'for',
#   'full',
#   'blown',
#   'casting',
#   'sessions',
#   'that',
#   'will',
#   'bring',
#   'the',
#   'film',
#   'full',
#   'financing'],
#  ['hank',
#   'in',
#   'time',
#   'is',
#   'a',
#   'buddy',
#   'movie',
#   'about',
#   'four',
#   'guy',
#   'friends',
#   'who',
#   'pull',
#   'together',
#   'to',
#   'help',
#   'their',
#   'friend',
#   'heal',
#   'after',
#   'his',
#   "wife's",
#   'death',
#   'by',
#   'building',
#   'a',
#   'time',
#   'machine'],
#  ['an',
#   'awards',
#   'show',
#   'to',
#   'celebrate',
#   'the',
#   'comedic',
#   'performing',
#   'arts',
#   'in',
#   'new',
#   'york',
#   'city'],
#  ['san',
#   'francisco',
#   'noise',
#   'pop',
#   'musician',
#   'seeking',
#   'funding',
#   'to',
#   'recreate',
#   'and',
#   'breathe',
#   'new',
#   'life',
#   'into',
#   'the',
#   'album',
#   'hounds',
#   'of',
#   'love',
#   'by',
#   'kate',
#   'bush',
#   'from',
#   'beginning',
#   'to',
#   'end'],
#  ['exploring',
#   'the',
#   'human',
#   'journey',
#   'delighting',
#   'in',
#   'the',
#   'human',
#   'instrument',
#   'expanding',
#   'the',
#   'human',
#   'perspective',
#   'flutewalker',
#   'story',
#   'concerts',
#   'by',
#   'werner',
#   'john'],
#  ['live',
#   'professional',
#   'wrestling',
#   'event',
#   'to',
#   'raise',
#   'money',
#   'for',
#   'muscular',
#   'dystrophy',
#   'research',
#   'and',
#   'treatment',
#   'seeking',
#   'support'],
#  ['a',
#   'film',
#   'about',
#   'conservationists',
#   'inventing',
#   'innovative',
#   'strategies',
#   'to',
#   'alleviate',
#   'the',
#   'pressure',
#   'of',
#   'human',
#   'elephant',
#   'conflict',
#   'in',
#   'sri',
#   'lanka'],
#  ["minneapolis'",
#   'favorite',
#   'naughtybilly',
#   'band',
#   'courtney',
#   'mcclean',
#   'the',
#   'dirty',
#   'curls',
#   'are',
#   "lookin'",
#   'to',
#   'record',
#   'their',
#   'sexpositive',
#   'ditties',
#   'on',
#   'an',
#   'ep',
#   'for',
#   'everyone'],
#  ['similo',
#   'is',
#   'a',
#   'scifi',
#   'love',
#   'story',
#   'shortfilm',
#   'set',
#   'in',
#   '2064'],
#  ['busy',
#   'making',
#   'their',
#   'debut',
#   'fulllength',
#   'record',
#   'curse',
#   'the',
#   'mariner',
#   'needs',
#   'some',
#   'help',
#   'to',
#   'finish',
#   'recording'],
#  ['more', 'money', 'more', 'problems'],
#  ['kokoromi',
#   'is',
#   'offering',
#   'rare',
#   'indie',
#   'game',
#   'rewards',
#   'game',
#   'download',
#   'keys',
#   'and',
#   'three',
#   'allaccess',
#   'gdc',
#   'passes',
#   'to',
#   'kickstart',
#   'the',
#   'gamma4',
#   'event',
#   'in',
#   'san',
#   'francisco'],
#  ['born',
#   'of',
#   'two',
#   'paths',
#   'crossing',
#   'comfortable',
#   'cowboy',
#   'cooking',
#   'is',
#   'the',
#   'tastes',
#   'images',
#   'and',
#   'stories',
#   'of',
#   'two',
#   "artists'",
#   'after',
#   'three',
#   'years',
#   'of',
#   'unconventional',
#   'living'],
#  ['the',
#   'pink',
#   'hotel',
#   'is',
#   'chicago',
#   'artist',
#   'chris',
#   "hefner's",
#   'first',
#   'feature',
#   'film',
#   'and',
#   'is',
#   'slated',
#   'for',
#   'completion',
#   'in',
#   'march',
#   '2010'],
#  ['help',
#   'me',
#   'finish',
#   'my',
#   'short',
#   'film',
#   'how',
#   'mata',
#   'hari',
#   'lost',
#   'her',
#   'head',
#   'and',
#   'found',
#   'her',
#   'body'],
#  ['leisurely',
#   'is',
#   'a',
#   'brooklyn',
#   'based',
#   'band',
#   'that',
#   'wants',
#   'help',
#   'pressing',
#   'their',
#   'first',
#   'ep',
#   'to',
#   'vinyl'],
#  ['this', 'will', 'be', 'a', 'short', 'run', 'kickstarter', 'only', 'edition'],
#  ['if',
#   'artists',
#   'ruled',
#   'the',
#   'world',
#   'reminds',
#   'me',
#   'of',
#   'times',
#   'better',
#   'lived',
#   'memories',
#   'better',
#   'spent',
#   'peace',
#   'creating',
#   'prosperity',
#   'and',
#   'a',
#   'much',
#   'cleaner',
#   'more',
#   'colorful',
#   'earth'],
#  ['with',
#   'your',
#   'help',
#   'the',
#   'candler',
#   'blog',
#   'a',
#   'film',
#   'review',
#   'and',
#   'theory',
#   'website',
#   'is',
#   'going',
#   'to',
#   'sxsw',
#   '2010',
#   'in',
#   'austin',
#   'tx',
#   'to',
#   'bring',
#   'you',
#   'news',
#   'and',
#   'reviews',
#   'from',
#   'the',
#   'fest'],
#  ['outpost',
#   '731',
#   'is',
#   'a',
#   'sci',
#   'fi',
#   'action',
#   'space',
#   'adventure',
#   'film',
#   'about',
#   'a',
#   'remote',
#   'distant',
#   'military',
#   'outpost',
#   'that',
#   'is',
#   'the',
#   'focus',
#   'point',
#   'of',
#   'an',
#   'alien',
#   'invasion'],
#  ['hear',
#   'us',
#   'roar',
#   'is',
#   'a',
#   'literary',
#   "news'paper'",
#   'that',
#   'will',
#   'consist',
#   'of',
#   'all',
#   'firstperson',
#   'narrative',
#   'fictional',
#   'and',
#   'nonfictional',
#   'along',
#   'with',
#   'images'],
#  ['there',
#   'have',
#   'been',
#   'reports',
#   'of',
#   'strange',
#   'phenomenon',
#   'in',
#   'the',
#   'greater',
#   'detroit',
#   'metro',
#   'complex'],
#  ['ghost', 'inch', 'threat', 'level', 'rainbow'],
#  ['catch', 'these', '1', 'inches'],
#  ['i',
#   'will',
#   'be',
#   'making',
#   'my',
#   'debut',
#   'on',
#   'the',
#   'international',
#   'art',
#   'scene',
#   'at',
#   'next',
#   'part',
#   'of',
#   'art',
#   'chicago',
#   'but',
#   'to',
#   'do',
#   'this',
#   'i',
#   'need',
#   'your',
#   'help'],
#  ['balthrop',
#   'alabama',
#   'is',
#   'a',
#   'small',
#   'town',
#   'band',
#   'hoping',
#   'to',
#   'go',
#   'on',
#   'tour'],
#  ["we're",
#   'going',
#   'to',
#   'austin',
#   'tx',
#   'during',
#   'sxsw',
#   'from',
#   'new',
#   'york',
#   'and',
#   'need',
#   'your',
#   'help',
#   'to',
#   'make',
#   'it',
#   'there'],
#  ['i', 'wrote', 'a', 'novel'],
#  ['and',
#   'i',
#   'wanted',
#   'to',
#   'try',
#   'a',
#   'fun',
#   'way',
#   'to',
#   'distribute',
#   'it'],
#  ['the', 'book', 'is', 'called', 'the', 'collective'],
#  ['this', 'is', 'andrew', 'vs'],
#  ...]

# %%
with open("input/all_sentences.txt", "w") as text_file:
    for sent in train_texts:
        joint_sent = ' '.join(sent)
        text_file.write(joint_sent + '\n ')

# %%
# train word2vec wtih fasttext wrapper
skipgram_fasttext_model = FastText.train(corpus_file="input/all_sentences.txt",
                                        ft_path="/home/nbcommon/anaconda3_420/lib/python3.5/site-packages/fastText/fasttext"
                                         , min_count=10, sample=1e-5, model="skipgram", sorted_vocab=1, )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-246be85baf74> in <module>()
#       2 skipgram_fasttext_model = FastText.train(corpus_file="input/all_sentences.txt",
#       3                                         ft_path="/home/nbcommon/anaconda3_420/lib/python3.5/site-packages/fastText/fasttext"
# ----> 4                                          , min_count=10, sample=1e-5, model="skipgram", sorted_vocab=1, )
#
# ~/anaconda3_420/lib/python3.5/site-packages/gensim/models/wrappers/fasttext.py in train(cls, ft_path, corpus_file, output_file, model, size, alpha, window, min_count, word_ngrams, loss, sample, negative, iter, min_n, max_n, sorted_vocab, threads)
#     220             cmd.append(str(value))
#     221
# --> 222         utils.check_output(args=cmd)
#     223         model = cls.load_fasttext_format(output_file)
#     224         cls.delete_training_files(output_file)
#
# ~/anaconda3_420/lib/python3.5/site-packages/gensim/utils.py in check_output(stdout, *popenargs, **kwargs)
#    1161     try:
#    1162         logger.debug("COMMAND: %s %s", popenargs, kwargs)
# -> 1163         process = subprocess.Popen(stdout=stdout, *popenargs, **kwargs)
#    1164         output, unused_err = process.communicate()
#    1165         retcode = process.poll()
#
# ~/anaconda3_420/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# ~/anaconda3_420/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nbcommon/anaconda3_420/lib/python3.5/site-packages/fastText/fasttext'
