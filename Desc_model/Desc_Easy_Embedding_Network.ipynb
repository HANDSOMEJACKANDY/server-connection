# %% [markdown]
# # This is a document that tries keras on jupyter notebook

# %% [markdown]
# ## Several notes for 11.17
# 1. Normalizing input data is essential
# 2. for categorical result, even though there are only two categories, use multi output and softmax. This is necessary as for calculating output in real cases, there are more variables to compare to, thus higher security of a good result.
# 3. it is high time to redo the training with __class reweighting__.!!!!

# %%
import numpy as np
import pandas as pd
import gensim
from gensim.models import Phrases
from gensim.corpora import Dictionary
import re
from gensim.models.wrappers.fasttext import FastText as FT_wrapper
from gensim.models.keyedvectors import KeyedVectors
from keras.models import Sequential, Model, load_model
from keras.layers import Bidirectional
from keras.layers import Dense, LSTM, GRU, Conv1D, MaxPooling1D, Flatten
from keras.layers import GaussianNoise, BatchNormalization, Dropout, AlphaDropout
from keras.layers import Activation, merge, Input, concatenate, Reshape, add, subtract
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from keras.initializers import VarianceScaling, RandomUniform
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.callbacks import Callback, LambdaCallback, TensorBoard, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model 
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
from kerastoolbox.visu import plot_weights
import time
# %matplotlib notebook

# %%
# visualization tool
class RealTimeVisualizer(Callback):
    def on_train_begin(self, logs={}):
        self.fig, (self.ax1, self.ax2) = plt.subplots(2,1, sharex=True)
        self.fig.suptitle(self.title, fontsize=24)
        self.fig.set_size_inches(20, 8)
        self.index_graph = []
        self.loss_graph = []
        self.val_loss_graph = []
        self.acc_graph = []
        self.val_acc_graph = []
 
    def on_epoch_end(self, epoch, logs={}):
        interval = self.interval
        loss = logs['loss']
        val_loss = logs['val_loss']
        try:
            val_acc = logs['val_acc']
        except:
            val_acc = logs['val_mean_squared_error']    
        try:
            acc = logs['acc']
        except:
            acc = logs['mean_squared_error']
        if epoch%interval == 0:
            self.loss_graph.append(loss)
            self.val_loss_graph.append(val_loss)
            self.val_acc_graph.append(val_acc)
            self.acc_graph.append(acc)
            self.index_graph.append(epoch)
            if interval == 1:
                self.ax1.set_title("loss is:{} val_loss is:{}".format(loss, val_loss))
                self.ax1.plot(self.index_graph, self.loss_graph, '-r')
                self.ax1.plot(self.index_graph, self.val_loss_graph, '-xb')
                self.ax2.set_title("acc is:{} val_acc is:{}".format(acc, val_acc))
                self.ax2.plot(self.index_graph, self.acc_graph, '-r')
                self.ax2.plot(self.index_graph, self.val_acc_graph, '-xb')
                self.ax2.plot(self.index_graph, [self.acc_graph[0]]*len(self.index_graph), '-p')
                self.fig.canvas.draw()
                time.sleep(0.05)
        elif epoch%interval == interval-1:
            self.loss_graph[int(epoch/interval)] += loss
            self.val_loss_graph[int(epoch/interval)] += val_loss
            self.val_acc_graph[int(epoch/interval)] += val_acc
            self.acc_graph[int(epoch/interval)] += acc
            self.loss_graph[int(epoch/interval)] /= interval
            self.val_loss_graph[int(epoch/interval)] /= interval
            self.val_acc_graph[int(epoch/interval)] /= interval
            self.acc_graph[int(epoch/interval)] /= interval
            self.ax1.set_title("loss is:{} val_loss is:{}".format(loss, val_loss))
            self.ax1.plot(self.index_graph, self.loss_graph, '-r')
            self.ax1.plot(self.index_graph, self.val_loss_graph, '-xb')
            self.ax2.set_title("acc is:{} val_acc is:{}".format(acc, val_acc))
            self.ax2.plot(self.index_graph, self.acc_graph, '-r')
            self.ax2.plot(self.index_graph, self.val_acc_graph, '-xb')
            self.ax2.plot(self.index_graph, [self.acc_graph[0]]*len(self.index_graph), '-p')
            self.fig.canvas.draw()
            time.sleep(0.05)
        else:
            self.loss_graph[int(epoch/interval)] += loss
            self.val_loss_graph[int(epoch/interval)] += val_loss
            self.val_acc_graph[int(epoch/interval)] += val_acc
            self.acc_graph[int(epoch/interval)] += acc

VisualizeCallback = RealTimeVisualizer()
VisualizeCallback.interval = 2
VisualizeCallback.title = "plot"

# %%
def is_desired_letter(char):
    return ord(char) >= 97 and ord(char) < 123 or ord(char) >= 48 and ord(char) < 58 or ord(char) == ord(" ")


# return even number of 0 and 1 if is_even_result is True
def get_train_data(train_portion, wv_model, is_even_test_data=True, is_neg_1_as_0=False, is_second_round_data=False, normalize_portion=0.45):
    np.random.seed(7)
    # load the dataset but only keep the top n words, zero the rest
    train_data = pd.read_csv("../input/kickstarter_train.csv")
    train_data = train_data.sample(frac=1).reset_index(drop=True)
    # do preliminary preprocessing:remove all symbols and split to words lists
    train_data["desc"] = [[char for char in str(text).lower() if is_desired_letter(char)] for
                          text in train_data["desc"]]
    train_data["desc"] = [''.join(text).split() for text in train_data["desc"]]
    # remove words that cannot be expressed
    train_data["desc"] = [[word for word in text if word in wv_model] for text in train_data["desc"]]
    # word 2 vector
    train_data["desc"] = [np.array(list(map(wv_model.word_vec, text))) for text in train_data["desc"]]
    # remove too short desc
    drop_index = []
    for i in range(len(train_data)):
        if train_data.iloc[i, 2].shape[0] <= 2:
            drop_index.append(i)
    train_data = train_data.drop(train_data.index[drop_index])
    
    # tokenize all countries
    # load dictionary or genrate one online
    try:
        country_dict = Dictionary.load("../num_model/num_data/country_dict.pkl")
        print("loading country dictionary successful from disk")
    except:
        print("No country dictionary available, generating from data")
        country_dict = Dictionary([train_data.iloc[:, 6]])
        country_dict.save("../num_model/num_data/country_dict.pkl")
        print("new dictionary saved to num_data")
    # start tokenization
    try:
        train_data.iloc[:, 6] = np.array(list(map(country_dict.token2id.get, train_data.iloc[:, 6]))) # map gives extra speed~
    except:
        print("Warning!!! A country does not exist in current dictionary!!!")
    
    # count zeros and ones and get weights for each sample
    counter = train_data.iloc[:, -1].value_counts().to_dict()
    zeros = float(counter[0])
    ones = float(counter[1])
    max_result = max(zeros, ones)
    weights = [ones / max_result, zeros / max_result]
    
    # get goal normalization para
    normalize_split_point = int(normalize_portion * len(train_data))
    temp_train_goals = np.array(train_data.iloc[:normalize_split_point, 3])
    goal_mean = temp_train_goals.mean()
    goal_std = temp_train_goals.std()
    
    # get backer normalization para
    temp_train_backers = np.array(train_data.iloc[:normalize_split_point, -2])
    backer_mean = temp_train_backers.mean()
    backer_std = temp_train_backers.std()
    
    # seperate train and test data
    if is_second_round_data == False:
        split_point = int(train_portion * len(train_data))
        test_data = train_data.iloc[split_point:, :]
        train_data = train_data.iloc[:split_point, :]
    else:
        split_point = int(train_portion * len(train_data))
        split_point_2 = int(train_portion * len(train_data) * 2)
        test_data = train_data.iloc[split_point_2:, :]
        train_data = train_data.iloc[split_point:split_point_2, :]
        
    # even test data
    # for test data count 0 and drop some until sample of 1 = sample of 0
    if is_even_test_data:
        print("even test data")
        status_count = test_data.iloc[:, -1].value_counts().to_dict()
        drop_zero_num = status_count[0] - status_count[1]
        drop_zero_p = drop_zero_num / float(status_count[0])
        drop_index = []
        for i in range(len(test_data)):
            if test_data.iloc[i, -1] == 0:
                if np.random.uniform(low=0, high=1) < drop_zero_p:
                    drop_index.append(i)
        test_data = test_data.drop(test_data.index[drop_index])
        status_count = test_data.iloc[:, -1].value_counts().to_dict()
        print(float(status_count[0]) / float(status_count[1]))
        # shuffle the whole data
        test_data = test_data.sample(frac=1).reset_index(drop=True)
    else:
        print("do not even test data")

    # get descriptions data
    train_texts = np.array(train_data.iloc[:, 2])
    test_texts = np.array(test_data.iloc[:, 2])
    # get goal data
    train_goals = (np.array(train_data.iloc[:, 3]) - goal_mean) / goal_std
    test_goals = (np.array(test_data.iloc[:, 3]) - goal_mean) / goal_std
    # get backer data
    # train_backers = (np.array(train_data.iloc[:, -2]) - backer_mean) / backer_std
    # test_backers = (np.array(test_data.iloc[:, -2]) - backer_mean) / backer_std
    train_backers = np.array(train_data.iloc[:, -2])
    test_backers = np.array(test_data.iloc[:, -2])
    # get country data
    train_countries = np.array(train_data.iloc[:, 6])
    test_countries = np.array(train_data.iloc[:, 6])
    # get result data
    train_results_double = np.array([[1, 0] if item == 1 else [0, 1] for item in train_data.iloc[:, -1]])
    train_results_single = np.array(train_data.iloc[:, -1])
    train_weights = np.array([weights[i] for i in train_data.iloc[:, -1]])
    test_results_double = np.array([[1, 0] if item == 1 else [0, 1] for item in test_data.iloc[:, -1]])
    test_results_single = np.array(test_data.iloc[:, -1])
    # test_weights = np.array([weights[i] for i in test_data.iloc[:, -1]])
    # convert 1, 0 results to 1, -1
    if is_neg_1_as_0:
        train_results_single = np.array([1 if item == 1 else -1 for item in train_results_single])
        test_results_single = np.array([1 if item == 1 else -1 for item in test_results_single])
        train_results_double = np.array([[1, -1] if item[0] == 1 else [-1, 1] for item in train_results_double])
        test_results_double = np.array([[1, -1] if item[0] == 1 else [-1, 1] for item in test_results_double])

    
    return {"texts": train_texts, "countries": train_countries, "goals": train_goals, "backers": train_backers,
            "results_double": train_results_double, "results_single": train_results_single, 
            "result_class_weight": train_weights}, \
           {"texts": test_texts, "countries": test_countries, "goals": test_goals, "backers": test_backers,
            "results_double": test_results_double, "results_single": test_results_single},

# %%
# get training testing data from disk
train_portion = 0.45
train_data, test_data = get_train_data(train_portion, wv_model=wv_model, is_even_test_data=False)
print("data grabbed")
# Out:
# loading country dictionary successful from disk
# 1.0001060670343658
# data grabbed

# %%
# truncate and pad input sequences
max_desc_length = 35
train_data["texts"] = pad_vector_sequence(train_data["texts"], max_len=max_desc_length)
test_data["texts"] = pad_vector_sequence(test_data["texts"], max_len=max_desc_length)
print("padding finished")
# Out:
# padding finished

# %% [markdown]
# # Now use LSTM with forking (and residue to lstm output)
# __seemingly using forked_sigmoid classifier is easier to converge than forked_softmax classifier__
#
# __using SVM leads to a faster convergence rate yet similar (~0.61) test accuracy__
#
# __using selu (of course with alpha dropout and custom weight initialization) leads to a faster convergence rate of test accuracy, and after some fine-tuning (with batch size 256), the test accuracy has reached it's historical best:0.638__

# %%
def MultiLayerLSTMCell(sequence_input, dropout_level=0.2, layer_num=1, layer_width=32):
    this_input = sequence_input
    for i in range(layer_num):
        if i == layer_num - 1:
            is_return_sequence = False
        else:
            is_return_sequence = True
        x = LSTM(units=layer_width, dropout=dropout_level, name="Recurrent_" + str(i), 
                 return_sequences=is_return_sequence)(this_input)
        this_input = BatchNormalization()(x)
    return this_input

def DenseNetCell(dense_in, dropout_level=0.25, res_num=1, activation_name="tanh", l2_para=0.001):
    this_input = dense_in
    for i in range(res_num):
        if activation_name != 'selu':
            x = Dense(int(fork_in.shape[1]), activity_regularizer=l2(l2_para))(this_input)
            x = BatchNormalization()(x)
            x = Activation(activation_name)(x) 
            x = Dropout(dropout_level)(x)
            x = add(inputs=[this_input, x])
            x = BatchNormalization()(res_out)
            x = Dropout(dropout_level)(x)
            this_input = Activation(activation_name)(x)
        else:
            x = Dense(int(this_input.shape[1]), kernel_initializer=
                        VarianceScaling(scale=1.0, mode='fan_in', distribution='normal'), 
                        activity_regularizer=l2(l2_para))(this_input)
            x = Activation(activation_name)(x)
            x = AlphaDropout(dropout_level)(x)
            x = add(inputs=[this_input, x])
            x = AlphaDropout(dropout_level)(x)
            this_input = Activation(activation_name)(x)
    dense_out = Dense(1)(this_input)
    return dense_out


# generate model for descriptions + country
desc_rnn_input = Input(shape=(35, word_vector_len))
x = MultiLayerLSTMCell(desc_rnn_input, dropout_level=0.2, layer_num=1, layer_width=64)
x = BatchNormalization()(x)
fork_in = Dropout(0.2)(x)
# fork network for isolately decide is 1 or is 0
x = concatenate(inputs=[DenseNetCell(fork_in, dropout_level=0.2, res_num=2, activation_name="selu", l2_para=0.0001), 
                               DenseNetCell(fork_in, dropout_level=0.2, res_num=2, activation_name="selu", l2_para=0.0001)])
x = Activation("selu")(x)
x = Activation("softmax")(x)
desc_rnn_model = Model(inputs=[desc_rnn_input], outputs=[x])

print("model building finished\n", desc_rnn_model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 35, 300)      0
# __________________________________________________________________________________________________
# Recurrent_0 (LSTM)              (None, 64)           93440       input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64)           256         Recurrent_0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64)           256         batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 64)           4160        dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 64)           4160        dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64)           0           dense_17[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64)           0           dense_20[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_21 (AlphaDropout) (None, 64)           0           activation_27[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_25 (AlphaDropout) (None, 64)           0           activation_31[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64)           0           dropout_4[0][0]
#                                                                  alpha_dropout_21[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64)           0           dropout_4[0][0]
#                                                                  alpha_dropout_25[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_22 (AlphaDropout) (None, 64)           0           add_11[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_26 (AlphaDropout) (None, 64)           0           add_13[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64)           0           alpha_dropout_22[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 64)           0           alpha_dropout_26[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 64)           4160        activation_28[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 64)           4160        activation_32[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64)           0           dense_18[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 64)           0           dense_21[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_23 (AlphaDropout) (None, 64)           0           activation_29[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_27 (AlphaDropout) (None, 64)           0           activation_33[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64)           0           activation_28[0][0]
#                                                                  alpha_dropout_23[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64)           0           activation_32[0][0]
#                                                                  alpha_dropout_27[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_24 (AlphaDropout) (None, 64)           0           add_12[0][0]
# __________________________________________________________________________________________________
# alpha_dropout_28 (AlphaDropout) (None, 64)           0           add_14[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64)           0           alpha_dropout_24[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64)           0           alpha_dropout_28[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            65          activation_30[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1)            65          activation_34[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2)            0           dense_19[0][0]
#                                                                  dense_22[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 2)            0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 2)            0           activation_35[0][0]
# ==================================================================================================
# Total params: 110,722
# Trainable params: 110,466
# Non-trainable params: 256
# __________________________________________________________________________________________________
# model building finished
#  None

# %%
# configurate model training
desc_rnn_model.compile(loss='binary_crossentropy', optimizer="adam", metrics=["accuracy"])

# do training
VisualizeCallback.interval = 2
VisualizeCallback.title = "wv300_LSTM64_DO.2_DenseFork_D*1_selu_l2.0001_DO.2"
desc_rnn_model.fit(train_data['texts'], train_data['results_double'], epochs=1000, batch_size=256, shuffle=True,
                  verbose=0, validation_data=[test_data["texts"], test_data['results_double']], 
                  callbacks=[ReduceLROnPlateau(patience=10, min_lr=0.00001, cooldown=30), VisualizeCallback],
                   sample_weight=train_data['result_class_weight'])

desc_rnn_model.save("desc_data/desc_rnn_model_" + VisualizeCallback.title + ".hdf5")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e6dda1de7fd8> in <module>()
#       8                   verbose=0, validation_data=[test_data["texts"], test_data['results_double']],
#       9                   callbacks=[ReduceLROnPlateau(patience=10, min_lr=0.00001, cooldown=30), VisualizeCallback],
# ---> 10                    sample_weight=train_data['result_class_weight'])
#      11
#      12 desc_rnn_model.save("desc_data/desc_rnn_model_" + VisualizeCallback.title + ".hdf5")
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1629                               initial_epoch=initial_epoch,
#    1630                               steps_per_epoch=steps_per_epoch,
# -> 1631                               validation_steps=validation_steps)
#    1632
#    1633     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1225                             val_outs = self._test_loop(val_f, val_ins,
#    1226                                                        batch_size=batch_size,
# -> 1227                                                        verbose=0)
#    1228                             if not isinstance(val_outs, list):
#    1229                                 val_outs = [val_outs]
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/engine/training.py in _test_loop(self, f, ins, batch_size, verbose, steps)
#    1368                     ins_batch = _slice_arrays(ins, batch_ids)
#    1369
# -> 1370                 batch_outs = f(ins_batch)
#    1371                 if isinstance(batch_outs, list):
#    1372                     if batch_index == 0:
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
scores = desc_rnn_model.evaluate(x=[test_data['texts']], y=[test_data['results_double']])
print(scores)
desc_rnn_model.save("desc_data/desc_rnn_model_" + VisualizeCallback.title + " acc: " + str(scores[1]) + ".hdf5")
# Out:
# 37714/37714 [==============================] - 8s 206us/step
# [0.70384151002992446, 0.63241766982134939]

# %% [markdown]
# # investigating the statistics of prediction
# * for random guesses, correct prediction rate for 1 should equal to the frequency of 1 in data set, vice versa

# %%
zeros = 0.0
ones = 0.0
for i in test_data['results_double']:
    if i[0] == 0:
        zeros += 1
    else:
        ones += 1
print("frequency of zero is: ", zeros/(ones+zeros))

# get predictions
desc_model = desc_rnn_vanilla_model
try:
    result = [1 if item[0] > item[1] else 0 for item in desc_model.predict_on_batch(test_data['texts'])]
    # get predicted statistics
    pred_zeros = float(len([1 for item in result if item == 0]))
    pred_ones = float(len(result) - pred_zeros)
    print("predicted frequency of zero is: ", pred_zeros/len(result))

    # get right statistics
    right_ones = float(len([1 for i in range(len(result)) if test_data['results_single'][i] == result[i] and result[i] == 1]))
    right_zeros = float(len([0 for i in range(len(result)) if test_data['results_single'][i] == result[i] and result[i] == 0]))
    print("correct rate for 1 predictions: ",   right_ones / pred_ones)
    print("proportion of correct 1 predictions: ", right_ones / ones)
    print("correct rate for 0 predictions: ",   right_zeros / pred_zeros)
    print("proportion of correct 0 predictions: ", right_zeros / zeros)

    print("overall accuracy is: ", (right_zeros + right_ones) / len(result))
except:
    result = [1 if item > 0.5 else 0 for item in desc_model.predict_on_batch([test_data['texts'], test_data['goals']])]
    # get predicted statistics
    pred_zeros = float(len([1 for item in result if item == 0]))
    pred_ones = float(len(result) - pred_zeros)
    print("predicted frequency of zero is: ", pred_zeros/len(result))

    # get right statistics
    right_ones = float(len([1 for i in range(len(result)) if test_data['results_single'][i] == result[i] and result[i] == 1]))
    right_zeros = float(len([0 for i in range(len(result)) if test_data['results_single'][i] == result[i] and result[i] == 0]))
    print("correct rate for 1 predictions: ",   right_ones / pred_ones)
    print("proportion of correct 1 predictions: ", right_ones / ones)
    print("correct rate for 0 predictions: ",   right_zeros / pred_zeros)
    print("proportion of correct 0 predictions: ", right_zeros / zeros)

    print("overall accuracy is: ", (right_zeros + right_ones) / len(result))
# Out:
# frequency of zero is:  0.5000265153523891
# predicted frequency of zero is:  0.5611178872567216
# correct rate for 1 predictions:  0.639258095698405
# proportion of correct 1 predictions:  0.561147645311837
# correct rate for 0 predictions:  0.6089689065305737
# proportion of correct 0 predictions:  0.6833704528582034
# overall accuracy is:  0.6222622898658323

# %%
func = K.function(inputs=[desc_model.input, K.learning_phase()], outputs=[desc_model.layers[-2].output])
second_last_layer_output = func([test_data['texts'], 0])

# %%
[item for item in second_last_layer_output[0]]
# Out:
# [array([ 1.17666662,  1.91166806], dtype=float32),
#  array([-0.33087325,  0.61778414], dtype=float32),
#  array([-1.06526256, -0.8415361 ], dtype=float32),
#  array([-1.07294571, -1.6218971 ], dtype=float32),
#  array([ 0.09263682,  0.0226647 ], dtype=float32),
#  array([ 0.11063059, -1.08550906], dtype=float32),
#  array([ 0.69241846,  2.10820842], dtype=float32),
#  array([-0.68021482,  0.1506452 ], dtype=float32),
#  array([-1.09966195,  0.3515954 ], dtype=float32),
#  array([-0.96627849, -1.55823994], dtype=float32),
#  array([ 0.7631017 ,  0.62607723], dtype=float32),
#  array([-1.45100439, -1.16533792], dtype=float32),
#  array([-0.48573354, -0.02216338], dtype=float32),
#  array([-1.31567502, -1.21677089], dtype=float32),
#  array([-0.94593751, -0.30448586], dtype=float32),
#  array([ 1.67814779,  0.07919337], dtype=float32),
#  array([ 0.07376346,  0.19657829], dtype=float32),
#  array([-0.41954654, -0.02781548], dtype=float32),
#  array([ 0.80225134,  1.17598164], dtype=float32),
#  array([-1.24695337, -1.0315851 ], dtype=float32),
#  array([-1.14441204, -1.69647539], dtype=float32),
#  array([ 0.28377032,  2.05806518], dtype=float32),
#  array([ 0.32882175,  0.81694877], dtype=float32),
#  array([-1.15286171, -1.31345689], dtype=float32),
#  array([-0.14443307, -0.63803613], dtype=float32),
#  array([-0.28471684,  1.1646024 ], dtype=float32),
#  array([ 0.96551883,  0.75327164], dtype=float32),
#  array([ 1.09402132,  1.1629312 ], dtype=float32),
#  array([-0.3259311 , -0.83864015], dtype=float32),
#  array([ 0.24796702,  0.16643241], dtype=float32),
#  array([-0.99178207, -0.55097258], dtype=float32),
#  array([ 1.35149407,  2.62092185], dtype=float32),
#  array([ 0.69535196,  2.58853078], dtype=float32),
#  array([-1.0361979 , -0.53134143], dtype=float32),
#  array([ 0.78260803,  2.58198881], dtype=float32),
#  array([-0.942541  , -1.15960705], dtype=float32),
#  array([ 0.34228593, -0.47556442], dtype=float32),
#  array([-0.93504751, -0.07745241], dtype=float32),
#  array([-1.34471703, -1.02248704], dtype=float32),
#  array([-1.26172936, -1.11298275], dtype=float32),
#  array([ 3.35846448,  0.83084893], dtype=float32),
#  array([-0.10231614, -0.17055178], dtype=float32),
#  array([-1.36983275, -1.21890914], dtype=float32),
#  array([-1.49832356, -1.50632441], dtype=float32),
#  array([ 0.07986217,  1.57727551], dtype=float32),
#  array([-1.06518221, -1.45411098], dtype=float32),
#  array([ 0.58697498,  2.30416059], dtype=float32),
#  array([ 0.9899081 ,  1.51901221], dtype=float32),
#  array([-1.06137824, -1.11357391], dtype=float32),
#  array([-0.31820425,  0.15412542], dtype=float32),
#  array([-0.75076044,  0.60784876], dtype=float32),
#  array([ 0.34306741,  0.4950614 ], dtype=float32),
#  array([ 0.40551475,  2.21739864], dtype=float32),
#  array([ 0.49448469,  2.65725207], dtype=float32),
#  array([-0.11546206, -1.44054687], dtype=float32),
#  array([ 1.2006048 ,  1.96783185], dtype=float32),
#  array([-0.93744719, -1.58751202], dtype=float32),
#  array([-1.27360618, -1.40286231], dtype=float32),
#  array([ 0.01679482, -0.33166337], dtype=float32),
#  array([-1.03405821, -1.01692295], dtype=float32),
#  array([ 0.61436534,  1.10216463], dtype=float32),
#  array([ 0.43211588,  1.50895429], dtype=float32),
#  array([ 1.01739049,  1.92642736], dtype=float32),
#  array([-0.75640386, -0.63003182], dtype=float32),
#  array([-1.46850586, -1.41379774], dtype=float32),
#  array([-1.12796521, -1.17744184], dtype=float32),
#  array([-0.90497643, -0.22783478], dtype=float32),
#  array([-0.42557129,  0.67173404], dtype=float32),
#  array([-0.57705551, -1.38553393], dtype=float32),
#  array([ 0.85656202,  1.94032848], dtype=float32),
#  array([ 0.86162478,  0.22495589], dtype=float32),
#  array([-0.84166753, -0.6932143 ], dtype=float32),
#  array([ 1.86094558,  1.44285905], dtype=float32),
#  array([-0.06079014,  1.38403308], dtype=float32),
#  array([ 0.21569788,  0.26613101], dtype=float32),
#  array([-0.6588015 ,  0.31120321], dtype=float32),
#  array([-1.04592955, -1.62833679], dtype=float32),
#  array([-1.42244172, -0.56250691], dtype=float32),
#  array([-1.0106312 , -1.05286038], dtype=float32),
#  array([-1.05917883,  0.21255167], dtype=float32),
#  array([-1.31860745, -0.84993947], dtype=float32),
#  array([-1.18524969, -1.05127513], dtype=float32),
#  array([-0.86419356, -0.52480787], dtype=float32),
#  array([ 0.08502483, -0.06045428], dtype=float32),
#  array([ 0.55168217, -0.41193664], dtype=float32),
#  array([-0.61085582, -1.14882672], dtype=float32),
#  array([-0.83909678, -0.39799127], dtype=float32),
#  array([-1.25004315, -1.34554255], dtype=float32),
#  array([ 0.84661633, -0.38063258], dtype=float32),
#  array([-1.43499422, -0.93012249], dtype=float32),
#  array([ 1.83238161,  0.68095714], dtype=float32),
#  array([-0.82727832, -0.06016642], dtype=float32),
#  array([ 0.2185626 , -0.15271804], dtype=float32),
#  array([-0.67603964,  0.75116771], dtype=float32),
#  array([-1.09177744,  0.18324   ], dtype=float32),
#  array([ 0.39788845,  2.06774855], dtype=float32),
#  array([ 0.16927356,  0.46360528], dtype=float32),
#  array([ 2.20292783,  0.11744392], dtype=float32),
#  array([-1.00397682,  0.25087911], dtype=float32),
#  array([ 1.46924281,  1.05527377], dtype=float32),
#  array([-0.88792932, -1.34383368], dtype=float32),
#  array([-1.04469979, -1.54826236], dtype=float32),
#  array([-1.51870906, -0.75355303], dtype=float32),
#  array([-0.96855497,  0.49664137], dtype=float32),
#  array([ 0.4060376 ,  2.15198779], dtype=float32),
#  array([ 0.27856624,  1.5697546 ], dtype=float32),
#  array([-0.92231929, -0.34349132], dtype=float32),
#  array([-1.19805861, -1.46739829], dtype=float32),
#  array([ 0.05400838,  0.90208358], dtype=float32),
#  array([-0.9384709 , -0.30141106], dtype=float32),
#  array([-1.32289255, -1.57541847], dtype=float32),
#  array([-1.10851181, -1.11770606], dtype=float32),
#  array([-0.96058762, -1.71371198], dtype=float32),
#  array([ 0.43450153,  1.37365937], dtype=float32),
#  array([-1.52876055, -1.55945814], dtype=float32),
#  array([ 0.643143  ,  2.60010123], dtype=float32),
#  array([ 0.25925615, -0.39447784], dtype=float32),
#  array([-1.10433698,  0.84876263], dtype=float32),
#  array([ 0.5136196 ,  2.78660679], dtype=float32),
#  array([-0.85364056,  0.25860959], dtype=float32),
#  array([ 0.71071345,  0.18001093], dtype=float32),
#  array([-0.04547128, -0.14088087], dtype=float32),
#  array([-0.86646962, -1.19036853], dtype=float32),
#  array([-1.08439302, -1.4695971 ], dtype=float32),
#  array([ 2.79453087,  1.40228486], dtype=float32),
#  array([ 0.05167883,  1.05455065], dtype=float32),
#  array([-1.26465201, -1.55715418], dtype=float32),
#  array([-0.01799962,  1.66959572], dtype=float32),
#  array([-0.05862149, -0.05269514], dtype=float32),
#  array([-1.42834413, -1.262447  ], dtype=float32),
#  array([ 0.55875236,  0.12573798], dtype=float32),
#  array([-1.34880447, -1.58333528], dtype=float32),
#  array([ 0.59357381,  0.19075447], dtype=float32),
#  array([ 0.20485173,  0.92397022], dtype=float32),
#  array([-1.1324904 , -1.30729735], dtype=float32),
#  array([-1.38771689, -0.25481728], dtype=float32),
#  array([-0.22522371,  0.11805064], dtype=float32),
#  array([-1.40596056, -1.08632684], dtype=float32),
#  array([-0.24713694,  1.19956553], dtype=float32),
#  array([-0.10096885, -0.68828076], dtype=float32),
#  array([ 1.68140364,  0.95361817], dtype=float32),
#  array([ 0.61587971,  1.62390959], dtype=float32),
#  array([-0.4998253 , -0.23856683], dtype=float32),
#  array([-1.3765496, -1.5131228], dtype=float32),
#  array([ 0.23778205,  0.81178981], dtype=float32),
#  array([ 0.66985697, -0.02395352], dtype=float32),
#  array([ 0.8341943 , -0.22548778], dtype=float32),
#  array([ 1.83426011,  0.42244172], dtype=float32),
#  array([-1.03262031, -0.59105903], dtype=float32),
#  array([ 0.60232013, -0.67395103], dtype=float32),
#  array([ 0.03081152,  0.75931054], dtype=float32),
#  array([ 0.66591096,  1.8026526 ], dtype=float32),
#  array([-1.2045114 , -1.58436155], dtype=float32),
#  array([ 0.33572853,  1.48145819], dtype=float32),
#  array([-0.9284364 , -1.57723773], dtype=float32),
#  array([-0.90922123, -0.75190878], dtype=float32),
#  array([-0.62506753,  0.62692577], dtype=float32),
#  array([-0.36641884,  1.05969453], dtype=float32),
#  array([ 0.54525924,  0.97405237], dtype=float32),
#  array([-0.74586427,  0.5878762 ], dtype=float32),
#  array([ 0.01266958,  1.0695498 ], dtype=float32),
#  array([-1.31303275, -1.12337744], dtype=float32),
#  array([ 0.84562796, -0.51736224], dtype=float32),
#  array([ 0.14706975, -0.24068183], dtype=float32),
#  array([ 1.2248584 ,  0.19570805], dtype=float32),
#  array([-0.95744669, -0.99539459], dtype=float32),
#  array([-0.56736219, -1.31415415], dtype=float32),
#  array([-0.24003945,  1.47939897], dtype=float32),
#  array([-1.14382803, -1.09000802], dtype=float32),
#  array([-0.5871973 ,  1.21834552], dtype=float32),
#  array([ 0.5942654 ,  1.13991392], dtype=float32),
#  array([ 1.08143711,  1.03917849], dtype=float32),
#  array([-0.29223812,  1.11155617], dtype=float32),
#  array([ 0.59073377,  1.59049892], dtype=float32),
#  array([ 0.77365959,  1.52926338], dtype=float32),
#  array([-1.33468688, -1.3252306 ], dtype=float32),
#  array([-1.14275408, -0.10954808], dtype=float32),
#  array([-1.27825797, -1.30957544], dtype=float32),
#  array([-0.4278788 ,  0.80671835], dtype=float32),
#  array([ 0.17582975,  0.94868821], dtype=float32),
#  array([-0.29864156, -0.60354406], dtype=float32),
#  array([-0.78103584, -0.41740391], dtype=float32),
#  array([ 0.13167085, -0.2816709 ], dtype=float32),
#  array([-1.50352883, -1.43868303], dtype=float32),
#  array([ 0.57804334, -0.5807206 ], dtype=float32),
#  array([-0.97393423,  0.31632936], dtype=float32),
#  array([-0.2991569 ,  0.19320056], dtype=float32),
#  array([ 0.63453382,  0.1885208 ], dtype=float32),
#  array([-0.62626946, -0.61527658], dtype=float32),
#  array([ 1.67965364,  2.42199945], dtype=float32),
#  array([ 0.99844056,  0.281582  ], dtype=float32),
#  array([-0.99983335,  0.23048137], dtype=float32),
#  array([-0.84904546, -0.47196537], dtype=float32),
#  array([ 0.19194397,  1.46015191], dtype=float32),
#  array([ 0.78855181,  3.367028  ], dtype=float32),
#  array([-0.29481134, -0.53411704], dtype=float32),
#  array([-1.44171751, -1.4447149 ], dtype=float32),
#  array([-1.20599008, -1.29332757], dtype=float32),
#  array([-0.75458437,  0.83149356], dtype=float32),
#  array([-0.73865867,  0.11448498], dtype=float32),
#  array([ 0.08945288,  0.99118906], dtype=float32),
#  array([-1.20461011,  0.08834569], dtype=float32),
#  array([ 0.76764685,  1.6674552 ], dtype=float32),
#  array([ 0.03971259, -0.78907835], dtype=float32),
#  array([ 0.35841948, -0.15366526], dtype=float32),
#  array([ 0.06427076,  2.60926747], dtype=float32),
#  array([ 0.60074931, -0.60397732], dtype=float32),
#  array([-1.16360915,  0.06866492], dtype=float32),
#  array([-1.44158924, -1.49074662], dtype=float32),
#  array([ 0.25014171,  1.36617434], dtype=float32),
#  array([-0.86956537, -1.32350361], dtype=float32),
#  array([-1.05490303, -0.81947392], dtype=float32),
#  array([-1.25361145, -1.21629977], dtype=float32),
#  array([-1.41631782, -1.50727034], dtype=float32),
#  array([ 0.95785141,  0.88046181], dtype=float32),
#  array([-1.22789192, -1.37228322], dtype=float32),
#  array([ 2.14477682,  0.99535358], dtype=float32),
#  array([-1.2823658, -1.4034816], dtype=float32),
#  array([ 0.65906465,  3.05828762], dtype=float32),
#  array([-0.39178839, -0.07797898], dtype=float32),
#  array([ 0.36868352,  2.10757017], dtype=float32),
#  array([-1.43974924, -1.09217942], dtype=float32),
#  array([-0.11381622, -1.06644642], dtype=float32),
#  array([-1.37464154, -1.43632853], dtype=float32),
#  array([ 0.04734277,  1.28932536], dtype=float32),
#  array([-1.29992247, -1.55579078], dtype=float32),
#  array([-1.61621177, -1.66694295], dtype=float32),
#  array([ 0.24212493,  1.3189975 ], dtype=float32),
#  array([-1.22663283, -1.50850165], dtype=float32),
#  array([-0.13378181,  0.32245263], dtype=float32),
#  array([ 0.23851945,  0.35721928], dtype=float32),
#  array([-1.11490035, -1.52038407], dtype=float32),
#  array([ 1.13937771,  0.1432894 ], dtype=float32),
#  array([ 1.31056404,  0.64020044], dtype=float32),
#  array([-1.39028645, -1.46582055], dtype=float32),
#  array([-0.5153535 ,  0.39197648], dtype=float32),
#  array([ 0.31953171,  1.19630408], dtype=float32),
#  array([-0.41822544,  0.37593457], dtype=float32),
#  array([-0.70553666,  0.11008699], dtype=float32),
#  array([-1.28523016, -1.40981567], dtype=float32),
#  array([-1.20761609, -1.44832361], dtype=float32),
#  array([-0.50130832,  1.2230022 ], dtype=float32),
#  array([-1.32959497, -1.64901137], dtype=float32),
#  array([ 1.84089589,  0.58383781], dtype=float32),
#  array([-0.38936752, -0.55151737], dtype=float32),
#  array([ 0.2962229 ,  1.55315101], dtype=float32),
#  array([ 0.82094616, -0.6685369 ], dtype=float32),
#  array([ 0.29297614, -0.18452951], dtype=float32),
#  array([-0.8686316 , -0.18133895], dtype=float32),
#  array([-0.34902596,  0.6984449 ], dtype=float32),
#  array([ 0.29801539,  0.1743744 ], dtype=float32),
#  array([ 0.36433849,  1.09395695], dtype=float32),
#  array([ 0.1262624, -0.7567035], dtype=float32),
#  array([-0.82606488, -0.20509872], dtype=float32),
#  array([-0.56831765, -0.85219502], dtype=float32),
#  array([ 0.05840183,  0.71684361], dtype=float32),
#  array([-0.86599535, -0.91898257], dtype=float32),
#  array([-0.47627962,  0.41659388], dtype=float32),
#  array([-1.4366554 , -1.27440476], dtype=float32),
#  array([ 0.05520079,  1.16682374], dtype=float32),
#  array([-0.58763307, -1.49666011], dtype=float32),
#  array([-1.13678873,  0.12035587], dtype=float32),
#  array([ 1.01501036,  0.50262707], dtype=float32),
#  array([-0.81846178, -1.34500372], dtype=float32),
#  array([-0.09098972, -0.96784067], dtype=float32),
#  array([ 0.15470535,  3.18563032], dtype=float32),
#  array([ 0.85921091, -0.0739853 ], dtype=float32),
#  array([ 1.26486647,  0.55491441], dtype=float32),
#  array([ 0.2346328 , -0.60303235], dtype=float32),
#  array([-1.36700797, -1.50431693], dtype=float32),
#  array([-1.13679099, -1.53872836], dtype=float32),
#  array([-1.25633442, -1.59818316], dtype=float32),
#  array([-0.98359895, -1.27448928], dtype=float32),
#  array([ 0.66297948,  0.29065451], dtype=float32),
#  array([-1.32831907, -0.29494295], dtype=float32),
#  array([ 0.29094252,  0.15899695], dtype=float32),
#  array([-0.69305235,  0.07173964], dtype=float32),
#  array([ 1.16700673,  1.05379999], dtype=float32),
#  array([ 1.86521053,  2.26369739], dtype=float32),
#  array([-1.37754607, -1.06763339], dtype=float32),
#  array([-0.97943825,  0.12776457], dtype=float32),
#  array([-1.40336072, -1.07231843], dtype=float32),
#  array([ 0.35032606, -0.15213919], dtype=float32),
#  array([ 0.18798208,  0.529513  ], dtype=float32),
#  array([-1.2021699, -0.8122111], dtype=float32),
#  array([ 1.95607364,  0.06975897], dtype=float32),
#  array([ 0.75575137,  0.44910076], dtype=float32),
#  array([-0.81318784, -1.04807425], dtype=float32),
#  array([ 0.06130241,  0.73093468], dtype=float32),
#  array([-0.32672131, -0.94051313], dtype=float32),
#  array([-0.09882262, -1.19696689], dtype=float32),
#  array([-0.01859473,  1.12354386], dtype=float32),
#  array([-0.95079219, -0.64667797], dtype=float32),
#  array([-0.23010695, -0.17186837], dtype=float32),
#  array([ 0.70496053,  1.80046391], dtype=float32),
#  array([ 1.55444729,  2.51049352], dtype=float32),
#  array([-1.09889698, -0.54259545], dtype=float32),
#  array([-0.19944483,  0.04370383], dtype=float32),
#  array([ 0.03840845,  1.59872389], dtype=float32),
#  array([ 0.2143521 ,  1.26626062], dtype=float32),
#  array([ 0.05387602, -0.49653736], dtype=float32),
#  array([-1.17422831, -1.52020335], dtype=float32),
#  array([-0.81949604, -0.91940373], dtype=float32),
#  array([ 0.85045427,  1.76471758], dtype=float32),
#  array([-0.85938203,  0.35474005], dtype=float32),
#  array([ 0.0454113 , -0.40543815], dtype=float32),
#  array([-1.11263764, -0.90518147], dtype=float32),
#  array([ 0.08064203,  0.15018907], dtype=float32),
#  array([-0.77440423,  0.01715387], dtype=float32),
#  array([-0.33238611,  1.74373102], dtype=float32),
#  array([-1.51633024, -1.43071711], dtype=float32),
#  array([-0.94463217,  0.24547167], dtype=float32),
#  array([-1.16929066, -0.38799706], dtype=float32),
#  array([-0.58771694,  0.65350878], dtype=float32),
#  array([-1.52250421, -1.52197015], dtype=float32),
#  array([-0.89514649,  0.98660529], dtype=float32),
#  array([-1.57611477, -1.539976  ], dtype=float32),
#  array([ 1.60043561,  0.72338831], dtype=float32),
#  array([ 0.1027266 ,  2.02468586], dtype=float32),
#  array([-0.93629128, -1.24585164], dtype=float32),
#  array([-1.25281751, -1.34281445], dtype=float32),
#  array([ 1.50301754,  0.83846426], dtype=float32),
#  array([ 0.62853026,  2.03427386], dtype=float32),
#  array([ 0.7800566, -0.5559513], dtype=float32),
#  array([-1.5198679, -1.2864604], dtype=float32),
#  array([-1.13245571, -0.05792159], dtype=float32),
#  array([ 0.47593796,  1.43068409], dtype=float32),
#  array([ 0.17623523,  0.5539614 ], dtype=float32),
#  array([-0.38189098,  0.97717482], dtype=float32),
#  array([-1.24155009, -1.15598595], dtype=float32),
#  array([-1.00303292,  0.001197  ], dtype=float32),
#  array([-0.96620536, -1.16973734], dtype=float32),
#  array([-1.14686441, -1.01341486], dtype=float32),
#  array([ 0.19114113,  1.42819536], dtype=float32),
#  array([-1.05365276, -0.62224191], dtype=float32),
#  array([-0.90933591, -1.49472582], dtype=float32),
#  array([ 0.00676235,  2.15630221], dtype=float32),
#  array([ 1.18344057,  2.74632955], dtype=float32),
#  array([-1.20790529, -1.54364347], dtype=float32),
#  array([-1.53945601, -1.17600274], dtype=float32),
#  array([ 1.34609103,  0.23512167], dtype=float32),
#  array([-1.42703664, -1.54029012], dtype=float32),
#  array([-1.10868919, -1.30332875], dtype=float32),
#  array([-0.9652794, -0.3029885], dtype=float32),
#  array([ 0.50595212,  0.61881697], dtype=float32),
#  array([ 1.00808108,  2.15933967], dtype=float32),
#  array([ 0.9190377 ,  0.85827333], dtype=float32),
#  array([ 1.08836651,  0.63665611], dtype=float32),
#  array([ 0.96975809,  0.69413012], dtype=float32),
#  array([-0.96585488, -1.2525146 ], dtype=float32),
#  array([ 0.20554057,  1.12288392], dtype=float32),
#  array([ 0.75319427,  0.01616058], dtype=float32),
#  array([ 2.53831673,  1.08511794], dtype=float32),
#  array([-1.42780244, -0.88410163], dtype=float32),
#  array([-0.71249026, -0.51887774], dtype=float32),
#  array([-0.71746713, -0.24863796], dtype=float32),
#  array([-1.34967756, -1.44406009], dtype=float32),
#  array([-1.36356056, -1.49198818], dtype=float32),
#  array([ 0.03601668,  1.50705671], dtype=float32),
#  array([ 1.04037857,  2.68443012], dtype=float32),
#  array([-0.3027834,  1.1993885], dtype=float32),
#  array([-0.84426582, -0.82328802], dtype=float32),
#  array([-1.30281198, -0.6295495 ], dtype=float32),
#  array([-1.42017722, -1.64026582], dtype=float32),
#  array([ 0.47586739,  2.01997542], dtype=float32),
#  array([-0.06979953,  3.33249664], dtype=float32),
#  array([ 2.3659575 ,  1.09186387], dtype=float32),
#  array([-1.12855554,  0.82693779], dtype=float32),
#  array([-0.49739602, -0.76194704], dtype=float32),
#  array([ 0.20936713,  0.8379783 ], dtype=float32),
#  array([-0.73659295,  0.87838376], dtype=float32),
#  array([ 0.96039283,  0.71220154], dtype=float32),
#  array([ 0.74694812,  1.32622302], dtype=float32),
#  array([-1.13219655, -1.54615736], dtype=float32),
#  array([ 0.8399868 ,  3.10581517], dtype=float32),
#  array([ 0.85564822,  0.05821662], dtype=float32),
#  array([ 0.06487304,  1.37309635], dtype=float32),
#  array([-1.20623302, -1.34107137], dtype=float32),
#  array([ 0.33775821,  0.2473588 ], dtype=float32),
#  array([ 0.6377213 ,  0.47294092], dtype=float32),
#  array([-0.91588932, -0.02231595], dtype=float32),
#  array([ 1.85465991,  0.0064885 ], dtype=float32),
#  array([ 0.57802218,  0.24668562], dtype=float32),
#  array([-0.98986578, -0.15849224], dtype=float32),
#  array([ 0.57906377,  1.53668439], dtype=float32),
#  array([-1.46495533, -1.69775045], dtype=float32),
#  array([-0.48119891,  0.39285341], dtype=float32),
#  array([ 2.85334516, -0.09942392], dtype=float32),
#  array([ 0.06880834, -0.46341905], dtype=float32),
#  array([-1.40903544, -0.99685276], dtype=float32),
#  array([-0.48460421,  1.65735173], dtype=float32),
#  array([-1.33208191, -0.85756022], dtype=float32),
#  array([ 0.11777388,  0.1617807 ], dtype=float32),
#  array([ 0.43634808, -0.55007046], dtype=float32),
#  array([ 0.24273559,  0.95685887], dtype=float32),
#  array([-1.25872278, -1.58918297], dtype=float32),
#  array([ 0.9368031 , -0.46166044], dtype=float32),
#  array([-1.43375444, -1.32487571], dtype=float32),
#  array([-1.04693341, -0.1879258 ], dtype=float32),
#  array([-0.20678848,  1.62698901], dtype=float32),
#  array([-1.01157379, -1.604509  ], dtype=float32),
#  array([-0.69666713,  0.00728198], dtype=float32),
#  array([ 0.07322656,  1.10874319], dtype=float32),
#  array([ 0.31448901,  1.01019537], dtype=float32),
#  array([-0.50792331,  0.1146737 ], dtype=float32),
#  array([-0.78550392, -0.64296466], dtype=float32),
#  array([-0.58022547,  0.58494174], dtype=float32),
#  array([-1.29612756, -1.2669791 ], dtype=float32),
#  array([-1.07941341,  0.07147373], dtype=float32),
#  array([ 0.51574332,  0.66983831], dtype=float32),
#  array([-0.72045851,  0.55736518], dtype=float32),
#  array([-1.56739163, -1.28595316], dtype=float32),
#  array([ 1.30634189,  1.45449722], dtype=float32),
#  array([-1.05519331,  0.30443582], dtype=float32),
#  array([-1.15957475, -1.3604418 ], dtype=float32),
#  array([-0.01467272,  0.40394548], dtype=float32),
#  array([-1.09171736, -0.85287273], dtype=float32),
#  array([ 0.04829589,  0.7645371 ], dtype=float32),
#  array([-1.40214789, -0.63434887], dtype=float32),
#  array([-0.61489046, -0.85639608], dtype=float32),
#  array([-1.20498276,  0.23392293], dtype=float32),
#  array([-1.31851852, -1.27960002], dtype=float32),
#  array([ 1.0924753 , -0.04430716], dtype=float32),
#  array([ 0.80019909,  1.22412312], dtype=float32),
#  array([-0.98458266, -0.70579094], dtype=float32),
#  array([ 3.58040833,  0.72995633], dtype=float32),
#  array([-1.52701223, -1.31844473], dtype=float32),
#  array([-0.32980561, -0.20768245], dtype=float32),
#  array([-0.89006042,  0.72403526], dtype=float32),
#  array([-0.23954315,  0.45149982], dtype=float32),
#  array([-1.22322035,  0.3088811 ], dtype=float32),
#  array([ 0.75140059,  4.35382175], dtype=float32),
#  array([-1.14510119,  0.80214763], dtype=float32),
#  array([-0.82228118,  0.45705432], dtype=float32),
#  array([-1.29439867, -1.35096872], dtype=float32),
#  array([-0.38816914, -0.64025241], dtype=float32),
#  array([ 0.94253516,  1.4218719 ], dtype=float32),
#  array([ 1.05681467,  0.49715319], dtype=float32),
#  array([ 3.16650748, -0.21592434], dtype=float32),
#  array([-0.06802218,  0.54287273], dtype=float32),
#  array([-0.20961647,  0.61159617], dtype=float32),
#  array([ 0.88461983, -0.12384753], dtype=float32),
#  array([ 0.11061596,  0.38929984], dtype=float32),
#  array([ 0.59765357,  1.84501827], dtype=float32),
#  array([ 0.30702153, -0.18710624], dtype=float32),
#  array([-0.9731999 , -0.81107277], dtype=float32),
#  array([ 1.85695684,  0.18771811], dtype=float32),
#  array([-1.54659152, -1.6440202 ], dtype=float32),
#  array([ 1.30346739,  0.74194098], dtype=float32),
#  array([-1.4286828 , -1.04963827], dtype=float32),
#  array([ 0.63938892,  1.00035048], dtype=float32),
#  array([-1.41176844, -1.43485093], dtype=float32),
#  array([-1.11051357, -0.88789767], dtype=float32),
#  array([-0.98733515,  0.6320805 ], dtype=float32),
#  array([ 0.79126853,  0.27357298], dtype=float32),
#  array([-1.36867225, -1.54213035], dtype=float32),
#  array([ 0.49610224,  1.2895453 ], dtype=float32),
#  array([-0.90234464, -1.17057621], dtype=float32),
#  array([ 0.34884155,  3.03249073], dtype=float32),
#  array([-0.09118401,  2.48137259], dtype=float32),
#  array([-0.71163952,  0.51574135], dtype=float32),
#  array([-0.95548427,  0.02590363], dtype=float32),
#  array([ 0.70233405,  0.85171634], dtype=float32),
#  array([-0.98451728, -1.65205622], dtype=float32),
#  array([-1.14752662, -0.70878041], dtype=float32),
#  array([ 0.11560101,  0.62049031], dtype=float32),
#  array([ 1.27000201,  0.9855594 ], dtype=float32),
#  array([ 1.22815335,  2.81012535], dtype=float32),
#  array([-0.98968363, -1.37033534], dtype=float32),
#  array([-0.9133113, -1.148821 ], dtype=float32),
#  array([ 0.58934659,  0.15393037], dtype=float32),
#  array([-0.83412582, -0.52393025], dtype=float32),
#  array([-0.71414548,  0.42163467], dtype=float32),
#  array([-0.9861365 , -1.67741179], dtype=float32),
#  array([ 0.49254507, -0.92783761], dtype=float32),
#  array([-0.97766602,  1.46131146], dtype=float32),
#  array([-1.07121503,  0.03339257], dtype=float32),
#  array([-1.1395787 , -0.17280583], dtype=float32),
#  array([-0.83973014, -0.9815309 ], dtype=float32),
#  array([-1.50446689, -1.4889853 ], dtype=float32),
#  array([ 0.37948936,  2.23957849], dtype=float32),
#  array([ 0.42187116,  1.10694575], dtype=float32),
#  array([-1.15629959, -0.9991082 ], dtype=float32),
#  array([-1.1483022 , -0.69959885], dtype=float32),
#  array([ 0.31975213,  0.32655835], dtype=float32),
#  array([-0.46776187,  1.15477359], dtype=float32),
#  array([ 1.58031142,  1.76107228], dtype=float32),
#  array([-0.08955535,  0.66661823], dtype=float32),
#  array([ 0.58527923,  0.47106272], dtype=float32),
#  array([-1.03546178,  0.42337695], dtype=float32),
#  array([ 1.18223381,  1.30973387], dtype=float32),
#  array([ 1.15686452,  1.85473382], dtype=float32),
#  array([-1.4834131 , -1.33305812], dtype=float32),
#  array([-0.78717113,  1.40643394], dtype=float32),
#  array([-0.03298168, -1.15464199], dtype=float32),
#  array([ 0.02786482,  0.38010454], dtype=float32),
#  array([ 0.93445826,  2.28908515], dtype=float32),
#  array([-1.19208276, -0.69646031], dtype=float32),
#  array([-1.37502038, -1.42206514], dtype=float32),
#  array([-0.25767848,  0.91608924], dtype=float32),
#  array([-0.21337228, -0.90071142], dtype=float32),
#  array([ 0.68093115,  0.34459525], dtype=float32),
#  array([ 0.37052694,  0.94349408], dtype=float32),
#  array([-1.16982245, -1.69355023], dtype=float32),
#  array([ 0.44044596,  2.09265041], dtype=float32),
#  array([ 0.25172836,  1.64411104], dtype=float32),
#  array([-0.21754757,  0.3377443 ], dtype=float32),
#  array([ 0.35149685,  0.02980721], dtype=float32),
#  array([ 0.16994657,  1.04687834], dtype=float32),
#  array([ 0.06197371,  1.96433985], dtype=float32),
#  array([-0.83221042, -0.50399828], dtype=float32),
#  array([-1.34035146, -1.58705568], dtype=float32),
#  array([ 0.42767042,  0.06323142], dtype=float32),
#  array([-0.83057302, -0.28944838], dtype=float32),
#  array([-1.17932248, -1.17165411], dtype=float32),
#  array([-0.81032574, -0.8599754 ], dtype=float32),
#  array([-0.93857533,  0.93971908], dtype=float32),
#  array([ 0.28791052,  0.51335603], dtype=float32),
#  array([ 0.20197514,  2.00930572], dtype=float32),
#  array([-0.717709  ,  0.42278087], dtype=float32),
#  array([-1.30852723, -1.39859354], dtype=float32),
#  array([ 1.35734951, -0.48802552], dtype=float32),
#  array([-0.22905579,  0.54232472], dtype=float32),
#  array([ 1.4660455 ,  0.97561419], dtype=float32),
#  array([ 0.76074016,  1.27155757], dtype=float32),
#  array([-1.20146084, -0.26544151], dtype=float32),
#  array([-0.8942278 , -0.31840742], dtype=float32),
#  array([-1.57132471, -1.31002092], dtype=float32),
#  array([-0.33225825, -1.11864579], dtype=float32),
#  array([-1.37663078, -1.41361868], dtype=float32),
#  array([ 1.15751398,  1.96742177], dtype=float32),
#  array([-0.33497244,  0.85534132], dtype=float32),
#  array([ 0.92802072,  0.0052967 ], dtype=float32),
#  array([-0.00156065, -0.63573867], dtype=float32),
#  array([ 0.51744539,  2.5581944 ], dtype=float32),
#  array([-0.54844135, -0.7745983 ], dtype=float32),
#  array([ 1.09332669,  0.36259833], dtype=float32),
#  array([ 0.56474763,  3.76059604], dtype=float32),
#  array([ 0.3506172 ,  1.62886322], dtype=float32),
#  array([-0.12486284,  0.5587942 ], dtype=float32),
#  array([ 0.7374776 ,  4.63507414], dtype=float32),
#  array([ 1.42973828,  0.86101413], dtype=float32),
#  array([ 1.04260814,  2.9450078 ], dtype=float32),
#  array([ 0.31541064,  2.68181205], dtype=float32),
#  array([ 0.98659813,  0.94149953], dtype=float32),
#  array([-1.37470126, -1.56357682], dtype=float32),
#  array([-0.30895999,  0.25306427], dtype=float32),
#  array([-1.10971379, -0.98446649], dtype=float32),
#  array([ 0.16540229,  0.76201171], dtype=float32),
#  array([-0.6823656 ,  0.92000163], dtype=float32),
#  array([ 1.81197238,  0.31709778], dtype=float32),
#  array([-1.35937142, -1.42647171], dtype=float32),
#  array([ 0.24924687,  2.07330966], dtype=float32),
#  array([-1.29804873, -0.90666384], dtype=float32),
#  array([-1.25036585, -1.22311318], dtype=float32),
#  array([ 0.88515186,  2.10515857], dtype=float32),
#  array([-1.39721584, -1.10619915], dtype=float32),
#  array([ 0.84157789,  0.31800401], dtype=float32),
#  array([ 0.52302051,  0.70718211], dtype=float32),
#  array([ 0.93991852, -0.45182353], dtype=float32),
#  array([-1.18900597, -1.42906284], dtype=float32),
#  array([ 2.14502668,  1.50274003], dtype=float32),
#  array([ 0.98913407,  0.66033834], dtype=float32),
#  array([-1.05428076, -0.54100937], dtype=float32),
#  array([-1.17906737, -1.14982891], dtype=float32),
#  array([ 0.52018601,  1.45138431], dtype=float32),
#  array([-0.50675654,  1.32521069], dtype=float32),
#  array([-1.20402801, -0.36784306], dtype=float32),
#  array([ 0.607077  ,  1.89346504], dtype=float32),
#  array([-0.73045576,  0.16384564], dtype=float32),
#  array([ 0.18487526,  1.00252736], dtype=float32),
#  array([ 1.16620743,  2.6774137 ], dtype=float32),
#  array([-0.99540907,  0.19604139], dtype=float32),
#  array([ 0.61541754,  0.58132708], dtype=float32),
#  array([-0.96253443, -1.27481866], dtype=float32),
#  array([-1.06332004, -1.30259871], dtype=float32),
#  array([ 0.50152105,  0.5877142 ], dtype=float32),
#  array([-1.14042306, -0.63714957], dtype=float32),
#  array([-1.36687875,  0.05664393], dtype=float32),
#  array([-0.85481989, -0.03693858], dtype=float32),
#  array([ 0.52419001,  1.23687756], dtype=float32),
#  array([ 0.35951269, -0.66629732], dtype=float32),
#  array([-0.76859689, -1.39358854], dtype=float32),
#  array([ 0.78184801,  1.12605178], dtype=float32),
#  array([-1.49810886, -1.28180432], dtype=float32),
#  array([-1.32834101, -0.63590956], dtype=float32),
#  array([-0.29724586,  0.1385764 ], dtype=float32),
#  array([ 1.38119793,  0.98042393], dtype=float32),
#  array([ 0.83087116,  0.66821784], dtype=float32),
#  array([-0.19226319,  0.40909678], dtype=float32),
#  array([-1.4506042 , -1.46607685], dtype=float32),
#  array([ 0.7083413 ,  2.68792295], dtype=float32),
#  array([ 0.27466917,  0.01033231], dtype=float32),
#  array([ 0.76787996,  1.5563736 ], dtype=float32),
#  array([ 0.42242867,  2.19461656], dtype=float32),
#  array([ 0.15956664,  1.69417906], dtype=float32),
#  array([ 0.298935  ,  0.05600905], dtype=float32),
#  array([-1.05308843, -0.72515619], dtype=float32),
#  array([-1.22627985, -0.43578902], dtype=float32),
#  array([ 0.26701751,  1.48055363], dtype=float32),
#  array([ 0.80910534,  0.83825094], dtype=float32),
#  array([ 0.73670161,  2.62439632], dtype=float32),
#  array([ 0.14944145, -0.72488922], dtype=float32),
#  array([ 1.00043476,  0.65033656], dtype=float32),
#  array([-1.30457437, -1.3748728 ], dtype=float32),
#  array([ 0.29443187,  2.18096209], dtype=float32),
#  array([-0.15902856,  0.06690638], dtype=float32),
#  array([-0.42119786, -0.24978355], dtype=float32),
#  array([-1.24965322, -1.07229221], dtype=float32),
#  array([-1.4715606 , -1.09411037], dtype=float32),
#  array([-0.94096994, -1.10046792], dtype=float32),
#  array([ 0.89881653,  2.55027699], dtype=float32),
#  array([-0.9361729 , -0.81095678], dtype=float32),
#  array([-1.26730478, -0.58557284], dtype=float32),
#  array([ 0.65519458,  0.27909103], dtype=float32),
#  array([ 0.19332607, -0.17979717], dtype=float32),
#  array([-1.45269227, -1.52252543], dtype=float32),
#  array([ 0.28371766,  1.85053587], dtype=float32),
#  array([ 0.12343291,  1.60630786], dtype=float32),
#  array([-1.21999443, -1.49298167], dtype=float32),
#  array([ 0.57254934,  0.99835467], dtype=float32),
#  array([-0.38861534, -1.24817848], dtype=float32),
#  array([-0.08822512, -0.02379015], dtype=float32),
#  array([ 0.14625773, -0.15875232], dtype=float32),
#  array([ 0.5775786 ,  0.78934407], dtype=float32),
#  array([ 0.40445039,  0.9265219 ], dtype=float32),
#  array([-0.99804354,  0.07627459], dtype=float32),
#  array([-1.27946687, -1.63082862], dtype=float32),
#  array([ 1.15882945,  1.04008424], dtype=float32),
#  array([-0.46372461,  0.18270679], dtype=float32),
#  array([ 2.7653327 ,  0.36219031], dtype=float32),
#  array([ 1.73726177,  1.01807821], dtype=float32),
#  array([-0.45946583, -1.09892774], dtype=float32),
#  array([-0.56652814, -0.35787389], dtype=float32),
#  array([-1.39839721, -0.9621461 ], dtype=float32),
#  array([ 1.46770394,  0.48011917], dtype=float32),
#  array([-0.95057929, -0.72320026], dtype=float32),
#  array([-1.11733615,  0.70424813], dtype=float32),
#  array([-0.42423174,  0.81591237], dtype=float32),
#  array([ 1.13912868,  2.91003156], dtype=float32),
#  array([ 0.48367757,  0.90316284], dtype=float32),
#  array([-1.43535626, -0.31674576], dtype=float32),
#  array([ 1.10238028,  1.33703363], dtype=float32),
#  array([-1.35400856, -0.30547863], dtype=float32),
#  array([-0.14330532,  1.63850355], dtype=float32),
#  array([ 2.61525083,  1.16724718], dtype=float32),
#  array([-0.95092058, -1.40791953], dtype=float32),
#  array([ 0.06118724,  1.55236626], dtype=float32),
#  array([ 0.15336657,  2.45202518], dtype=float32),
#  array([-1.29020917, -0.74004048], dtype=float32),
#  array([ 0.78110111, -0.52360433], dtype=float32),
#  array([ 0.26634225,  0.96839577], dtype=float32),
#  array([ 3.91671443,  0.97821593], dtype=float32),
#  array([ 0.36503887, -0.73577571], dtype=float32),
#  array([-1.04552126,  0.01163991], dtype=float32),
#  array([-0.37098795,  0.76289421], dtype=float32),
#  array([-1.03453529, -0.15904312], dtype=float32),
#  array([ 0.10314181,  2.50358224], dtype=float32),
#  array([ 1.10255194,  1.48191762], dtype=float32),
#  array([ 0.35754466,  2.53536916], dtype=float32),
#  array([-1.1216644 , -0.36543736], dtype=float32),
#  array([-1.19775641, -0.26659191], dtype=float32),
#  array([-0.99573267, -0.44598582], dtype=float32),
#  array([-0.94505614, -0.01287094], dtype=float32),
#  array([-0.31043348, -1.31725442], dtype=float32),
#  array([-0.90812999, -1.58783162], dtype=float32),
#  array([-1.23665905, -1.60576916], dtype=float32),
#  array([ 0.14491035,  1.53713429], dtype=float32),
#  array([ 0.43779254,  0.05031339], dtype=float32),
#  array([-1.3159585 ,  0.51529747], dtype=float32),
#  array([-0.63365239, -1.53021681], dtype=float32),
#  array([-1.29013705, -1.36202955], dtype=float32),
#  array([-1.03630972,  0.03689344], dtype=float32),
#  array([-0.30357718, -0.69133085], dtype=float32),
#  array([ 1.47453511,  0.90256226], dtype=float32),
#  array([-0.86507779,  0.20915163], dtype=float32),
#  array([-1.3856132 , -1.47716415], dtype=float32),
#  array([ 1.43824863,  4.73262262], dtype=float32),
#  array([-1.13532782, -0.68169427], dtype=float32),
#  array([ 0.65113133,  1.22295058], dtype=float32),
#  array([-0.27050361, -0.47073221], dtype=float32),
#  array([ 0.88665801,  0.58853948], dtype=float32),
#  array([-0.9536137 ,  0.59411216], dtype=float32),
#  array([-0.86179018, -1.33076286], dtype=float32),
#  array([-1.24191117, -1.45004427], dtype=float32),
#  array([ 0.27624831,  0.8186869 ], dtype=float32),
#  array([ 2.90833759,  0.63984495], dtype=float32),
#  array([-0.05293952, -0.62114942], dtype=float32),
#  array([-0.78155082,  1.15008307], dtype=float32),
#  array([ 0.4268792,  1.3547076], dtype=float32),
#  array([ 0.07323808,  0.37788501], dtype=float32),
#  array([-0.31345806,  1.56896091], dtype=float32),
#  array([ 0.61050558,  2.37039113], dtype=float32),
#  array([-0.91350186, -0.84455365], dtype=float32),
#  array([-1.03262496, -0.42949119], dtype=float32),
#  array([-1.03308475, -0.9315322 ], dtype=float32),
#  array([ 0.13583852,  0.85723096], dtype=float32),
#  array([-0.84548175,  0.35673764], dtype=float32),
#  array([ 1.00142455,  0.88602245], dtype=float32),
#  array([-0.81259286, -1.48224568], dtype=float32),
#  array([ 0.51695126,  0.80205464], dtype=float32),
#  array([-1.35340345, -0.7744208 ], dtype=float32),
#  array([ 0.48211667,  1.09561539], dtype=float32),
#  array([-0.52951384,  0.594136  ], dtype=float32),
#  array([ 3.20137477,  1.69815755], dtype=float32),
#  array([ 0.45904419,  0.14284487], dtype=float32),
#  array([ 0.75212103,  1.57774222], dtype=float32),
#  array([-1.02879632, -0.26327127], dtype=float32),
#  array([-0.45493391,  0.92888021], dtype=float32),
#  array([-0.73008704, -0.76160973], dtype=float32),
#  array([ 1.41166008,  0.42372456], dtype=float32),
#  array([-0.35353637,  0.5216409 ], dtype=float32),
#  array([-1.41822755, -1.36740434], dtype=float32),
#  array([ 0.24203654, -0.43793288], dtype=float32),
#  array([-0.94427615, -1.12000144], dtype=float32),
#  array([-1.27670813, -0.99028617], dtype=float32),
#  array([ 0.42467818,  3.49382854], dtype=float32),
#  array([-0.51998079, -0.85207993], dtype=float32),
#  array([-1.39873195, -0.8420561 ], dtype=float32),
#  array([-0.84916681, -0.59285969], dtype=float32),
#  array([-1.28176498, -1.42062712], dtype=float32),
#  array([ 1.05711353,  1.27613187], dtype=float32),
#  array([-0.98144233, -0.20065799], dtype=float32),
#  array([-1.32451999, -1.66709447], dtype=float32),
#  array([ 1.02082527,  1.25448167], dtype=float32),
#  array([ 0.50527167,  0.72892547], dtype=float32),
#  array([-1.28408957, -1.03068256], dtype=float32),
#  array([ 0.42690158,  2.35821915], dtype=float32),
#  array([ 1.26856685,  0.51420325], dtype=float32),
#  array([-1.08356082, -0.73942441], dtype=float32),
#  array([-1.52473569, -1.23742509], dtype=float32),
#  array([-1.08325124, -1.252087  ], dtype=float32),
#  array([-0.87208569, -1.14368498], dtype=float32),
#  array([-0.24345794, -0.78267229], dtype=float32),
#  array([-0.36552015,  0.78351992], dtype=float32),
#  array([-0.52388245, -0.48750201], dtype=float32),
#  array([ 0.90087754,  1.16945744], dtype=float32),
#  array([ 0.68768936,  2.8041327 ], dtype=float32),
#  array([-1.23754752,  0.13801882], dtype=float32),
#  array([ 0.54019558, -0.19612306], dtype=float32),
#  array([-1.08369172, -1.6766187 ], dtype=float32),
#  array([-0.34542021,  0.55819708], dtype=float32),
#  array([ 0.32339078, -0.30550042], dtype=float32),
#  array([-0.01750354,  0.03462705], dtype=float32),
#  array([-0.7864942 ,  0.72594601], dtype=float32),
#  array([ 0.95846516,  3.78807425], dtype=float32),
#  array([-1.54475808, -1.44316328], dtype=float32),
#  array([-1.44163871, -1.3088994 ], dtype=float32),
#  array([ 0.46734419,  1.2673924 ], dtype=float32),
#  array([-0.83651525, -0.6581766 ], dtype=float32),
#  array([-1.36546266, -1.41521227], dtype=float32),
#  array([ 0.00357976,  0.85516328], dtype=float32),
#  array([-0.49864075,  0.1607208 ], dtype=float32),
#  array([-1.43914306, -1.15426826], dtype=float32),
#  array([ 0.05623338,  0.36245754], dtype=float32),
#  array([ 0.35465947,  0.09821265], dtype=float32),
#  array([-0.63071561,  0.69381267], dtype=float32),
#  array([-0.70867592,  0.19249351], dtype=float32),
#  array([-0.60940784, -1.10570228], dtype=float32),
#  array([-0.17614572, -0.6157468 ], dtype=float32),
#  array([ 1.0080601 ,  0.92755932], dtype=float32),
#  array([-1.12910485, -1.56688738], dtype=float32),
#  array([ 1.6394645 ,  4.52299547], dtype=float32),
#  array([ 0.45139667,  1.17673016], dtype=float32),
#  array([-1.33925986, -1.32944846], dtype=float32),
#  array([-0.23468433,  0.54342449], dtype=float32),
#  array([ 0.26552549,  2.74470115], dtype=float32),
#  array([ 0.44722816,  0.64715487], dtype=float32),
#  array([ 0.36707863,  1.77908063], dtype=float32),
#  array([-0.29924172,  2.18576407], dtype=float32),
#  array([-1.18172812, -0.72613847], dtype=float32),
#  array([-1.21275938, -1.62918973], dtype=float32),
#  array([-1.19483387, -1.48323464], dtype=float32),
#  array([-1.53344762, -1.36252296], dtype=float32),
#  array([-0.11564565,  0.64276636], dtype=float32),
#  array([-1.1269865 , -1.65253448], dtype=float32),
#  array([ 1.1486007 ,  0.97673982], dtype=float32),
#  array([-0.03833618,  1.50511503], dtype=float32),
#  array([-0.34997725,  0.96006739], dtype=float32),
#  array([-0.5035795 , -0.50038296], dtype=float32),
#  array([ 1.21327436,  0.31957954], dtype=float32),
#  array([-1.34839129, -1.42757356], dtype=float32),
#  array([-0.71303993, -0.81834978], dtype=float32),
#  array([-0.21439628,  1.42875969], dtype=float32),
#  array([-1.28440273, -1.04362714], dtype=float32),
#  array([ 1.08726382,  0.23294978], dtype=float32),
#  array([-0.20181687,  1.73789966], dtype=float32),
#  array([-1.17467499, -0.19239125], dtype=float32),
#  array([ 1.1337744 ,  0.39863271], dtype=float32),
#  array([-0.67314017, -1.13952589], dtype=float32),
#  array([ 1.19821465,  0.37648001], dtype=float32),
#  array([-0.30659205,  0.65640479], dtype=float32),
#  array([-0.19533545,  0.18509473], dtype=float32),
#  array([-0.83215487,  0.48078787], dtype=float32),
#  array([ 1.19675267,  1.75192273], dtype=float32),
#  array([ 1.50284922,  0.14664288], dtype=float32),
#  array([-0.74347311, -1.53317165], dtype=float32),
#  array([-0.62298799, -0.35208249], dtype=float32),
#  array([-1.6207732 , -1.03199816], dtype=float32),
#  array([-1.05859065, -1.27520072], dtype=float32),
#  array([-0.62104458, -0.02947967], dtype=float32),
#  array([-0.40431949, -1.19099319], dtype=float32),
#  array([-1.36469781, -1.54635608], dtype=float32),
#  array([-1.3174026 , -1.63184965], dtype=float32),
#  array([ 1.90139842,  0.79878175], dtype=float32),
#  array([-1.14852595, -1.6557703 ], dtype=float32),
#  array([-0.98765266, -1.43342876], dtype=float32),
#  array([-0.82663518, -0.18000591], dtype=float32),
#  array([-0.58445179, -0.3650445 ], dtype=float32),
#  array([ 0.12529284,  0.79153848], dtype=float32),
#  array([-0.47445887, -0.69230121], dtype=float32),
#  array([-0.48984963,  1.30597305], dtype=float32),
#  array([-0.25199881, -1.36540449], dtype=float32),
#  array([-0.7923637 , -0.00158528], dtype=float32),
#  array([-1.14671361, -0.99922055], dtype=float32),
#  array([ 0.15882304,  0.17674527], dtype=float32),
#  array([ 0.76708484,  2.37603784], dtype=float32),
#  array([-0.55312222,  1.21075106], dtype=float32),
#  array([-1.32493985, -1.28430831], dtype=float32),
#  array([ 0.0163536 , -0.77705395], dtype=float32),
#  array([-1.34311891, -1.14259839], dtype=float32),
#  array([-0.03851023,  0.633497  ], dtype=float32),
#  array([ 0.32764778,  0.44144675], dtype=float32),
#  array([-0.55247968,  0.96290231], dtype=float32),
#  array([-1.08780992, -0.76422465], dtype=float32),
#  array([ 0.32559788, -0.25481433], dtype=float32),
#  array([ 2.77124071,  0.92837095], dtype=float32),
#  array([-1.19720411, -1.63621593], dtype=float32),
#  array([-0.45944422,  0.395327  ], dtype=float32),
#  array([-0.53044027, -0.39082903], dtype=float32),
#  array([ 0.58684498,  2.58338523], dtype=float32),
#  array([-1.12339175, -0.78101665], dtype=float32),
#  array([-1.05327487, -0.39937922], dtype=float32),
#  array([ 0.3495366 ,  1.31651676], dtype=float32),
#  array([ 0.82927692,  0.69652653], dtype=float32),
#  array([-1.08187437, -1.2738446 ], dtype=float32),
#  array([ 0.32025889,  1.76702106], dtype=float32),
#  array([-1.27584839, -1.61701453], dtype=float32),
#  array([ 0.63576013,  0.10874391], dtype=float32),
#  array([-1.40056026, -0.66595769], dtype=float32),
#  array([-1.04679012, -0.02869101], dtype=float32),
#  array([-0.38064721, -1.20666015], dtype=float32),
#  array([-1.27237785, -1.45414579], dtype=float32),
#  array([-0.68676913,  0.92681664], dtype=float32),
#  array([ 1.28312218,  0.31694248], dtype=float32),
#  array([ 0.4999119 , -0.37724343], dtype=float32),
#  array([-1.49481261, -1.32308328], dtype=float32),
#  array([-1.27752638, -0.58234578], dtype=float32),
#  array([-0.16729498, -0.44292572], dtype=float32),
#  array([ 0.06172116,  1.09170878], dtype=float32),
#  array([ 0.75945318,  0.42243883], dtype=float32),
#  array([-0.4081341,  1.3720175], dtype=float32),
#  array([-0.95468909,  0.24308699], dtype=float32),
#  array([-0.06960337,  0.83447385], dtype=float32),
#  array([-1.53540885, -1.46456015], dtype=float32),
#  array([-1.41330683, -0.81223524], dtype=float32),
#  array([ 1.74627554,  0.53277254], dtype=float32),
#  array([-0.7522344 ,  0.85519832], dtype=float32),
#  array([-0.98457009, -0.1366469 ], dtype=float32),
#  array([ 0.5045653 , -1.06916058], dtype=float32),
#  array([ 0.38355446,  2.84981966], dtype=float32),
#  array([ 0.17744355,  0.48357695], dtype=float32),
#  array([ 1.38179612, -0.26020625], dtype=float32),
#  array([-0.60973918, -1.03131008], dtype=float32),
#  array([-0.46500117,  0.83576828], dtype=float32),
#  array([-0.90226108, -1.67539263], dtype=float32),
#  array([-0.64438254, -1.33022726], dtype=float32),
#  array([ 0.04412123, -0.59510505], dtype=float32),
#  array([-1.41450548, -1.22985971], dtype=float32),
#  array([ 0.73260504, -0.52873039], dtype=float32),
#  array([ 1.49268854,  0.91321003], dtype=float32),
#  array([-1.08101964, -1.19637823], dtype=float32),
#  array([ 0.59310257,  2.38450861], dtype=float32),
#  array([-0.59165341, -0.1810578 ], dtype=float32),
#  array([ 1.4658227 ,  1.32866931], dtype=float32),
#  array([ 0.03115072,  0.7567845 ], dtype=float32),
#  array([ 0.62988901, -0.77497464], dtype=float32),
#  array([ 0.21760173,  2.35143852], dtype=float32),
#  array([-1.40143251, -1.42612171], dtype=float32),
#  array([ 0.30162638,  0.53082627], dtype=float32),
#  array([-1.2025274,  0.5930112], dtype=float32),
#  array([-1.10658097, -1.41698718], dtype=float32),
#  array([-1.16471493, -1.396981  ], dtype=float32),
#  array([-0.42658356,  0.32808176], dtype=float32),
#  array([-0.19485322,  2.20991755], dtype=float32),
#  array([ 1.18437839,  0.65916014], dtype=float32),
#  array([ 0.58709836,  1.77888882], dtype=float32),
#  array([ 0.02639578, -0.61048102], dtype=float32),
#  array([-1.15192282, -1.15361452], dtype=float32),
#  array([ 1.59765267,  4.01167011], dtype=float32),
#  array([-1.14824283, -0.95025551], dtype=float32),
#  array([ 0.63606822,  1.75940716], dtype=float32),
#  array([-0.77836955,  0.01111984], dtype=float32),
#  array([-0.6809448 , -0.13646184], dtype=float32),
#  array([-1.3072226 , -1.61030757], dtype=float32),
#  array([-1.42228079, -0.64678591], dtype=float32),
#  array([ 1.60361135,  0.1359687 ], dtype=float32),
#  array([-0.36416551, -0.4316237 ], dtype=float32),
#  array([ 0.43798935,  0.98698145], dtype=float32),
#  array([-0.38834548,  0.18917352], dtype=float32),
#  array([ 0.59901208, -0.32013562], dtype=float32),
#  array([-1.16204667, -0.63902295], dtype=float32),
#  array([-1.49152887, -1.01561797], dtype=float32),
#  array([-0.61005902, -0.53386647], dtype=float32),
#  array([-1.2284807 ,  0.35457641], dtype=float32),
#  array([ 0.30498284,  1.02741516], dtype=float32),
#  array([ 2.09989381,  2.7354753 ], dtype=float32),
#  array([ 0.14666809,  2.25111389], dtype=float32),
#  array([ 0.08109397,  0.91101354], dtype=float32),
#  array([ 0.31231213,  1.99429846], dtype=float32),
#  array([-0.69900048, -0.16874215], dtype=float32),
#  array([-1.03755558, -1.14013171], dtype=float32),
#  array([-1.23752522, -1.60077107], dtype=float32),
#  array([-1.07218647, -1.60490143], dtype=float32),
#  array([-0.98012716, -1.68894494], dtype=float32),
#  array([-1.31513822, -0.95506746], dtype=float32),
#  array([-1.42713594,  0.0438192 ], dtype=float32),
#  array([-0.30063313, -0.80940652], dtype=float32),
#  array([-0.83404905,  0.00923917], dtype=float32),
#  array([-1.32958841, -1.14953303], dtype=float32),
#  array([ 0.35130459,  1.46142757], dtype=float32),
#  array([-0.13703106,  0.84357762], dtype=float32),
#  array([ 0.60366577,  0.95682597], dtype=float32),
#  array([-1.07396829, -0.19708818], dtype=float32),
#  array([-0.16311812, -0.33399737], dtype=float32),
#  array([-1.37301254, -1.0281527 ], dtype=float32),
#  array([ 1.34328234,  0.60183859], dtype=float32),
#  array([-0.46277753, -0.59567791], dtype=float32),
#  array([-1.28451097, -1.69493663], dtype=float32),
#  array([-1.33245909, -1.53402936], dtype=float32),
#  array([-1.20142519, -1.10226643], dtype=float32),
#  array([-0.25280884,  1.78588128], dtype=float32),
#  array([ 0.64365816,  2.30500102], dtype=float32),
#  array([-1.3874141 , -1.09106898], dtype=float32),
#  array([-0.51680183, -0.18836696], dtype=float32),
#  array([ 0.84499168,  4.47022772], dtype=float32),
#  array([ 0.35088757,  2.42495394], dtype=float32),
#  array([-0.48550236, -0.20726317], dtype=float32),
#  array([-1.09823394, -1.1166234 ], dtype=float32),
#  array([ 0.08213076,  2.32867312], dtype=float32),
#  array([-1.39600635, -0.96751809], dtype=float32),
#  array([-0.07638135, -0.1410829 ], dtype=float32),
#  array([ 0.98945725, -0.83648741], dtype=float32),
#  array([-1.28679168, -1.13745236], dtype=float32),
#  array([ 0.14772961,  0.74777812], dtype=float32),
#  array([-1.42385924, -0.90410995], dtype=float32),
#  array([-0.89052534,  0.27383137], dtype=float32),
#  array([-0.94908404,  0.73439956], dtype=float32),
#  array([-1.39229655, -0.91674465], dtype=float32),
#  array([-0.33234397,  0.50936246], dtype=float32),
#  array([ 0.12825616, -0.01174287], dtype=float32),
#  array([-0.70267886, -1.1135633 ], dtype=float32),
#  array([-0.73141158,  0.77581167], dtype=float32),
#  array([-1.2610271, -0.603921 ], dtype=float32),
#  array([-1.1005373 , -0.81710798], dtype=float32),
#  array([ 1.03071904,  0.15631486], dtype=float32),
#  array([-0.93304336, -0.14255783], dtype=float32),
#  array([ 0.1395274 ,  1.39455545], dtype=float32),
#  array([-1.25782931, -1.02088308], dtype=float32),
#  array([-0.2781387 ,  0.23071364], dtype=float32),
#  array([ 0.26327825,  0.5140816 ], dtype=float32),
#  array([-1.1511482 ,  0.24065304], dtype=float32),
#  array([-1.53551865, -1.31603599], dtype=float32),
#  array([-1.49222517, -1.45802081], dtype=float32),
#  array([-1.04133677, -0.75933886], dtype=float32),
#  array([ 1.18004918, -0.2203308 ], dtype=float32),
#  array([ 0.05885612, -0.38993612], dtype=float32),
#  array([-0.89617145,  0.95070982], dtype=float32),
#  array([-1.1525116 , -1.39937103], dtype=float32),
#  array([-0.82569396, -0.98769355], dtype=float32),
#  array([-0.64099121, -1.17551506], dtype=float32),
#  array([ 1.61180091,  0.80731279], dtype=float32),
#  array([ 0.28735784,  1.2073518 ], dtype=float32),
#  array([-1.26567519,  0.00140256], dtype=float32),
#  array([ 0.73961967,  0.68821502], dtype=float32),
#  array([-1.46538079, -1.18914974], dtype=float32),
#  array([-0.58459085, -0.87501842], dtype=float32),
#  array([ 0.8250134 ,  2.19418621], dtype=float32),
#  array([ 0.63972318,  0.76229125], dtype=float32),
#  array([-0.51588649,  1.62802839], dtype=float32),
#  array([-1.26086593, -0.91122967], dtype=float32),
#  array([ 0.22518179,  1.40025127], dtype=float32),
#  array([-0.15011147,  1.08205485], dtype=float32),
#  array([-1.18936443,  0.03334424], dtype=float32),
#  array([-1.52099526, -1.47384846], dtype=float32),
#  array([ 0.89439094,  0.62874186], dtype=float32),
#  array([-1.34916174, -0.45893484], dtype=float32),
#  array([ 0.52800083,  1.49676847], dtype=float32),
#  array([ 0.49997139,  1.09285951], dtype=float32),
#  array([-0.54683506,  1.2861805 ], dtype=float32),
#  array([ 0.61958945,  0.49260858], dtype=float32),
#  array([ 0.46826741,  3.69871378], dtype=float32),
#  array([-1.35709202, -1.49825227], dtype=float32),
#  array([-1.18742621, -1.29742384], dtype=float32),
#  array([-0.98106986,  0.17101304], dtype=float32),
#  array([-0.08225739,  0.21269284], dtype=float32),
#  array([ 1.89925814,  0.58145911], dtype=float32),
#  array([-1.22732556, -0.06675819], dtype=float32),
#  array([-1.1789602 , -1.21284592], dtype=float32),
#  array([ 0.30214915,  0.04035036], dtype=float32),
#  ...]

# %%
probability_output = [list(item) for item in desc_model.predict_on_batch(test_data['texts'])]
list(zip(probability_output, test_data['results_double']))
# Out:
# [([0.24938218, 0.7506178], array([0, 1])),
#  ([0.30294791, 0.69705212], array([0, 1])),
#  ([0.52424896, 0.47575104], array([0, 1])),
#  ([0.68811399, 0.31188598], array([1, 0])),
#  ([0.59332556, 0.40667439], array([0, 1])),
#  ([0.72010189, 0.27989808], array([1, 0])),
#  ([0.10520472, 0.89479524], array([0, 1])),
#  ([0.51162875, 0.48837122], array([0, 1])),
#  ([0.29102322, 0.70897681], array([1, 0])),
#  ([0.60400593, 0.39599404], array([0, 1])),
#  ([0.69813949, 0.30186054], array([0, 1])),
#  ([0.45293349, 0.54706651], array([0, 1])),
#  ([0.45922989, 0.54077011], array([1, 0])),
#  ([0.61776698, 0.38223302], array([0, 1])),
#  ([0.59643346, 0.40356648], array([0, 1])),
#  ([0.82911164, 0.17088839], array([1, 0])),
#  ([0.61210048, 0.38789949], array([1, 0])),
#  ([0.58999467, 0.41000533], array([1, 0])),
#  ([0.56367797, 0.43632206], array([0, 1])),
#  ([0.54419845, 0.45580155], array([1, 0])),
#  ([0.57712507, 0.4228749], array([1, 0])),
#  ([0.23460397, 0.765396], array([0, 1])),
#  ([0.60835403, 0.39164594], array([1, 0])),
#  ([0.59542733, 0.40457264], array([0, 1])),
#  ([0.63089329, 0.36910668], array([1, 0])),
#  ([0.18832634, 0.81167364], array([0, 1])),
#  ([0.49107444, 0.50892556], array([1, 0])),
#  ([0.39639884, 0.6036011], array([0, 1])),
#  ([0.65820873, 0.3417913], array([1, 0])),
#  ([0.63468081, 0.36531922], array([1, 0])),
#  ([0.46873, 0.53126997], array([0, 1])),
#  ([0.26733756, 0.73266238], array([0, 1])),
#  ([0.4478434, 0.55215669], array([1, 0])),
#  ([0.39513609, 0.60486388], array([0, 1])),
#  ([0.18086217, 0.81913787], array([1, 0])),
#  ([0.69378477, 0.3062152], array([0, 1])),
#  ([0.67654437, 0.32345563], array([1, 0])),
#  ([0.48629043, 0.5137096], array([1, 0])),
#  ([0.44512829, 0.55487168], array([1, 0])),
#  ([0.4775877, 0.52241236], array([1, 0])),
#  ([0.86309946, 0.13690047], array([1, 0])),
#  ([0.62645519, 0.3735449], array([0, 1])),
#  ([0.35545352, 0.64454645], array([1, 0])),
#  ([0.52099079, 0.47900918], array([0, 1])),
#  ([0.2103008, 0.7896992], array([0, 1])),
#  ([0.648036, 0.351964], array([1, 0])),
#  ([0.21909374, 0.78090632], array([0, 1])),
#  ([0.58840638, 0.41159362], array([1, 0])),
#  ([0.53318459, 0.46681541], array([0, 1])),
#  ([0.41913733, 0.5808627], array([1, 0])),
#  ([0.44376934, 0.55623066], array([1, 0])),
#  ([0.63348323, 0.36651674], array([1, 0])),
#  ([0.032221116, 0.96777892], array([0, 1])),
#  ([0.075095452, 0.92490458], array([0, 1])),
#  ([0.60801512, 0.39198491], array([1, 0])),
#  ([0.40865248, 0.59134752], array([0, 1])),
#  ([0.6466921, 0.35330784], array([0, 1])),
#  ([0.63290876, 0.36709121], array([1, 0])),
#  ([0.6157735, 0.38422647], array([0, 1])),
#  ([0.56629318, 0.43370682], array([0, 1])),
#  ([0.40023836, 0.59976161], array([0, 1])),
#  ([0.36484042, 0.63515955], array([1, 0])),
#  ([0.53307194, 0.46692806], array([0, 1])),
#  ([0.46310964, 0.53689039], array([0, 1])),
#  ([0.57969272, 0.42030731], array([0, 1])),
#  ([0.64722109, 0.35277885], array([1, 0])),
#  ([0.39170909, 0.60829085], array([0, 1])),
#  ([0.53627908, 0.46372092], array([0, 1])),
#  ([0.59504843, 0.40495157], array([0, 1])),
#  ([0.43162617, 0.56837386], array([0, 1])),
#  ([0.71672761, 0.28327239], array([1, 0])),
#  ([0.48531321, 0.51468682], array([1, 0])),
#  ([0.42537224, 0.57462776], array([0, 1])),
#  ([0.13316111, 0.86683887], array([0, 1])),
#  ([0.68643284, 0.31356716], array([1, 0])),
#  ([0.50491792, 0.49508214], array([0, 1])),
#  ([0.67117119, 0.32882887], array([1, 0])),
#  ([0.51133817, 0.48866177], array([1, 0])),
#  ([0.5319258, 0.46807414], array([1, 0])),
#  ([0.24789178, 0.75210828], array([0, 1])),
#  ([0.46375766, 0.53624231], array([0, 1])),
#  ([0.49773744, 0.50226259], array([0, 1])),
#  ([0.37758908, 0.62241095], array([1, 0])),
#  ([0.52328932, 0.47671071], array([0, 1])),
#  ([0.64475346, 0.35524654], array([1, 0])),
#  ([0.7106868, 0.28931317], array([0, 1])),
#  ([0.49140748, 0.50859255], array([0, 1])),
#  ([0.47084552, 0.52915448], array([0, 1])),
#  ([0.65395445, 0.34604552], array([0, 1])),
#  ([0.44059724, 0.55940276], array([1, 0])),
#  ([0.6410349, 0.35896513], array([1, 0])),
#  ([0.39413679, 0.60586327], array([1, 0])),
#  ([0.68282688, 0.31717312], array([0, 1])),
#  ([0.2263343, 0.77366567], array([0, 1])),
#  ([0.34872335, 0.65127659], array([1, 0])),
#  ([0.19058548, 0.80941445], array([0, 1])),
#  ([0.51661402, 0.48338595], array([1, 0])),
#  ([0.8297962, 0.1702038], array([1, 0])),
#  ([0.49481794, 0.50518209], array([1, 0])),
#  ([0.54412925, 0.45587078], array([0, 1])),
#  ([0.67509753, 0.32490245], array([0, 1])),
#  ([0.67275953, 0.32724044], array([1, 0])),
#  ([0.39767018, 0.60232985], array([0, 1])),
#  ([0.22567137, 0.77432865], array([0, 1])),
#  ([0.11935012, 0.88064992], array([0, 1])),
#  ([0.25570595, 0.74429405], array([0, 1])),
#  ([0.38554028, 0.61445975], array([0, 1])),
#  ([0.63685167, 0.36314833], array([0, 1])),
#  ([0.29959983, 0.70040023], array([0, 1])),
#  ([0.29708514, 0.70291483], array([0, 1])),
#  ([0.54551291, 0.45448709], array([1, 0])),
#  ([0.68201476, 0.31798521], array([1, 0])),
#  ([0.65649348, 0.34350657], array([0, 1])),
#  ([0.24239703, 0.75760293], array([1, 0])),
#  ([0.47897834, 0.52102172], array([0, 1])),
#  ([0.18142046, 0.81857949], array([1, 0])),
#  ([0.64020014, 0.35979983], array([0, 1])),
#  ([0.12576377, 0.87423623], array([0, 1])),
#  ([0.094935626, 0.90506434], array([1, 0])),
#  ([0.42272505, 0.57727492], array([1, 0])),
#  ([0.65869051, 0.34130949], array([0, 1])),
#  ([0.54536629, 0.45463377], array([0, 1])),
#  ([0.66681433, 0.33318573], array([1, 0])),
#  ([0.62586296, 0.37413701], array([0, 1])),
#  ([0.76260453, 0.23739544], array([0, 1])),
#  ([0.23432292, 0.76567709], array([0, 1])),
#  ([0.6320405, 0.36795959], array([0, 1])),
#  ([0.2874386, 0.71256137], array([1, 0])),
#  ([0.60337138, 0.39662871], array([1, 0])),
#  ([0.53323412, 0.46676585], array([0, 1])),
#  ([0.64978456, 0.35021538], array([1, 0])),
#  ([0.57725459, 0.42274544], array([1, 0])),
#  ([0.67732656, 0.32267347], array([1, 0])),
#  ([0.45332685, 0.54667312], array([1, 0])),
#  ([0.51624829, 0.48375171], array([1, 0])),
#  ([0.12538959, 0.87461042], array([0, 1])),
#  ([0.58044088, 0.41955906], array([1, 0])),
#  ([0.54151255, 0.45848748], array([1, 0])),
#  ([0.25860628, 0.74139369], array([1, 0])),
#  ([0.64522195, 0.35477805], array([1, 0])),
#  ([0.68293047, 0.3170695], array([1, 0])),
#  ([0.31949154, 0.68050843], array([0, 1])),
#  ([0.3914409, 0.60855907], array([1, 0])),
#  ([0.61096281, 0.38903719], array([0, 1])),
#  ([0.44645476, 0.55354524], array([1, 0])),
#  ([0.64056456, 0.35943541], array([1, 0])),
#  ([0.67162484, 0.32837519], array([1, 0])),
#  ([0.7138024, 0.28619757], array([0, 1])),
#  ([0.41213873, 0.58786124], array([1, 0])),
#  ([0.66010708, 0.33989292], array([0, 1])),
#  ([0.48855591, 0.51144403], array([1, 0])),
#  ([0.4239935, 0.57600653], array([0, 1])),
#  ([0.63635689, 0.36364314], array([1, 0])),
#  ([0.30046132, 0.69953871], array([0, 1])),
#  ([0.69259566, 0.30740431], array([1, 0])),
#  ([0.55628228, 0.44371775], array([1, 0])),
#  ([0.34937319, 0.65062678], array([1, 0])),
#  ([0.34543172, 0.65456825], array([1, 0])),
#  ([0.58128214, 0.41871786], array([1, 0])),
#  ([0.25636634, 0.74363369], array([0, 1])),
#  ([0.28252414, 0.71747589], array([1, 0])),
#  ([0.23584531, 0.76415467], array([0, 1])),
#  ([0.71698165, 0.28301835], array([1, 0])),
#  ([0.70301974, 0.29698026], array([0, 1])),
#  ([0.69039869, 0.30960125], array([0, 1])),
#  ([0.57727033, 0.42272964], array([1, 0])),
#  ([0.7195915, 0.28040847], array([1, 0])),
#  ([0.152879, 0.847121], array([0, 1])),
#  ([0.614393, 0.385607], array([1, 0])),
#  ([0.1491161, 0.8508839], array([1, 0])),
#  ([0.35578099, 0.64421904], array([0, 1])),
#  ([0.51617444, 0.48382553], array([1, 0])),
#  ([0.29848942, 0.70151055], array([0, 1])),
#  ([0.32670721, 0.67329276], array([1, 0])),
#  ([0.36574614, 0.63425392], array([1, 0])),
#  ([0.56218302, 0.43781698], array([1, 0])),
#  ([0.32988662, 0.67011338], array([1, 0])),
#  ([0.6728285, 0.32717144], array([1, 0])),
#  ([0.30659774, 0.69340229], array([0, 1])),
#  ([0.33935103, 0.660649], array([1, 0])),
#  ([0.52456337, 0.47543666], array([1, 0])),
#  ([0.58284909, 0.41715094], array([1, 0])),
#  ([0.5690847, 0.43091527], array([0, 1])),
#  ([0.51332617, 0.48667389], array([1, 0])),
#  ([0.71021295, 0.28978702], array([1, 0])),
#  ([0.36692259, 0.63307744], array([1, 0])),
#  ([0.61621189, 0.38378808], array([1, 0])),
#  ([0.73393434, 0.26606566], array([0, 1])),
#  ([0.55801225, 0.44198769], array([0, 1])),
#  ([0.23737337, 0.76262665], array([1, 0])),
#  ([0.64585531, 0.35414472], array([1, 0])),
#  ([0.31320029, 0.68679971], array([0, 1])),
#  ([0.57961655, 0.42038342], array([1, 0])),
#  ([0.36206466, 0.6379354], array([1, 0])),
#  ([0.094332144, 0.90566784], array([0, 1])),
#  ([0.62862194, 0.37137803], array([1, 0])),
#  ([0.5798437, 0.4201563], array([1, 0])),
#  ([0.4230684, 0.57693154], array([0, 1])),
#  ([0.22720252, 0.77279747], array([0, 1])),
#  ([0.429901, 0.570099], array([0, 1])),
#  ([0.55187005, 0.44812992], array([1, 0])),
#  ([0.30085626, 0.69914371], array([0, 1])),
#  ([0.28877616, 0.71122384], array([0, 1])),
#  ([0.64105719, 0.35894281], array([1, 0])),
#  ([0.4541553, 0.54584467], array([0, 1])),
#  ([0.11441306, 0.88558692], array([1, 0])),
#  ([0.72061872, 0.2793813], array([1, 0])),
#  ([0.3214038, 0.6785962], array([0, 1])),
#  ([0.60244286, 0.3975572], array([1, 0])),
#  ([0.21265592, 0.7873441], array([0, 1])),
#  ([0.66655576, 0.33344427], array([1, 0])),
#  ([0.56414485, 0.43585518], array([0, 1])),
#  ([0.47528899, 0.52471095], array([0, 1])),
#  ([0.57018411, 0.42981586], array([1, 0])),
#  ([0.61224717, 0.38775286], array([1, 0])),
#  ([0.51926404, 0.4807359], array([0, 1])),
#  ([0.80159944, 0.19840062], array([1, 0])),
#  ([0.63038766, 0.36961231], array([0, 1])),
#  ([0.13471469, 0.86528534], array([0, 1])),
#  ([0.65935683, 0.34064317], array([1, 0])),
#  ([0.14169727, 0.85830271], array([0, 1])),
#  ([0.53980851, 0.46019149], array([0, 1])),
#  ([0.69267035, 0.3073296], array([1, 0])),
#  ([0.55503803, 0.44496194], array([0, 1])),
#  ([0.2564016, 0.7435984], array([0, 1])),
#  ([0.60868949, 0.39131051], array([1, 0])),
#  ([0.35829318, 0.64170676], array([1, 0])),
#  ([0.4373031, 0.56269693], array([0, 1])),
#  ([0.69233423, 0.30766582], array([1, 0])),
#  ([0.54724616, 0.45275381], array([1, 0])),
#  ([0.6429522, 0.35704783], array([0, 1])),
#  ([0.65916765, 0.34083235], array([1, 0])),
#  ([0.72008789, 0.27991202], array([1, 0])),
#  ([0.63593769, 0.36406237], array([1, 0])),
#  ([0.59462452, 0.40537545], array([1, 0])),
#  ([0.40893617, 0.5910638], array([0, 1])),
#  ([0.38038296, 0.61961699], array([1, 0])),
#  ([0.42911702, 0.57088304], array([1, 0])),
#  ([0.4852964, 0.51470363], array([0, 1])),
#  ([0.46948832, 0.53051168], array([0, 1])),
#  ([0.44132754, 0.55867249], array([0, 1])),
#  ([0.14922956, 0.85077047], array([1, 0])),
#  ([0.52449697, 0.47550309], array([0, 1])),
#  ([0.77816367, 0.22183636], array([1, 0])),
#  ([0.26942217, 0.73057777], array([1, 0])),
#  ([0.13547301, 0.86452699], array([1, 0])),
#  ([0.81637758, 0.18362243], array([1, 0])),
#  ([0.53195399, 0.46804598], array([0, 1])),
#  ([0.52572501, 0.47427499], array([1, 0])),
#  ([0.33785358, 0.66214645], array([0, 1])),
#  ([0.58008879, 0.41991124], array([0, 1])),
#  ([0.43980545, 0.56019449], array([1, 0])),
#  ([0.86191851, 0.13808155], array([0, 1])),
#  ([0.32941067, 0.67058927], array([1, 0])),
#  ([0.61489099, 0.38510901], array([1, 0])),
#  ([0.42198464, 0.57801539], array([0, 1])),
#  ([0.64689285, 0.35310718], array([0, 1])),
#  ([0.28559893, 0.71440113], array([0, 1])),
#  ([0.57150531, 0.42849469], array([0, 1])),
#  ([0.20347382, 0.79652625], array([0, 1])),
#  ([0.72483015, 0.27516985], array([0, 1])),
#  ([0.20690379, 0.79309618], array([1, 0])),
#  ([0.68619162, 0.31380841], array([1, 0])),
#  ([0.66492397, 0.33507606], array([0, 1])),
#  ([0.66403699, 0.33596298], array([0, 1])),
#  ([0.12065025, 0.87934977], array([0, 1])),
#  ([0.63204157, 0.36795843], array([0, 1])),
#  ([0.63971841, 0.36028159], array([1, 0])),
#  ([0.64782256, 0.35217747], array([0, 1])),
#  ([0.56441164, 0.43558836], array([1, 0])),
#  ([0.4167363, 0.5832637], array([0, 1])),
#  ([0.62486589, 0.37513414], array([1, 0])),
#  ([0.62835109, 0.37164894], array([1, 0])),
#  ([0.81580245, 0.1841975], array([1, 0])),
#  ([0.26450577, 0.7354942], array([1, 0])),
#  ([0.6516782, 0.34832174], array([1, 0])),
#  ([0.51919281, 0.48080716], array([0, 1])),
#  ([0.69027263, 0.30972737], array([1, 0])),
#  ([0.57958525, 0.42041475], array([1, 0])),
#  ([0.35277572, 0.64722431], array([0, 1])),
#  ([0.40321437, 0.59678566], array([0, 1])),
#  ([0.60747749, 0.39252251], array([0, 1])),
#  ([0.5919584, 0.40804163], array([0, 1])),
#  ([0.32280749, 0.67719245], array([0, 1])),
#  ([0.45579949, 0.5442006], array([1, 0])),
#  ([0.77925539, 0.22074459], array([1, 0])),
#  ([0.53871638, 0.46128362], array([1, 0])),
#  ([0.37952036, 0.62047964], array([0, 1])),
#  ([0.35019979, 0.64980024], array([1, 0])),
#  ([0.63177389, 0.36822608], array([1, 0])),
#  ([0.69113511, 0.30886489], array([0, 1])),
#  ([0.3366318, 0.66336823], array([0, 1])),
#  ([0.56056708, 0.43943295], array([0, 1])),
#  ([0.65710288, 0.34289712], array([0, 1])),
#  ([0.42760444, 0.57239556], array([1, 0])),
#  ([0.127681, 0.87231892], array([0, 1])),
#  ([0.48040825, 0.51959181], array([1, 0])),
#  ([0.36017528, 0.63982469], array([0, 1])),
#  ([0.3168309, 0.68316907], array([0, 1])),
#  ([0.26300511, 0.73699486], array([1, 0])),
#  ([0.59620923, 0.40379071], array([0, 1])),
#  ([0.64341253, 0.35658747], array([1, 0])),
#  ([0.51527381, 0.48472616], array([1, 0])),
#  ([0.37312022, 0.62687975], array([0, 1])),
#  ([0.032769162, 0.9672308], array([0, 1])),
#  ([0.4423815, 0.55761844], array([1, 0])),
#  ([0.49657899, 0.50342101], array([0, 1])),
#  ([0.54606396, 0.45393604], array([1, 0])),
#  ([0.17215584, 0.8278442], array([0, 1])),
#  ([0.2666536, 0.7333464], array([0, 1])),
#  ([0.6051029, 0.3948971], array([1, 0])),
#  ([0.293313, 0.70668703], array([1, 0])),
#  ([0.36321825, 0.63678175], array([1, 0])),
#  ([0.56337929, 0.43662068], array([1, 0])),
#  ([0.48503554, 0.51496452], array([1, 0])),
#  ([0.18984309, 0.81015694], array([0, 1])),
#  ([0.51514137, 0.48485872], array([0, 1])),
#  ([0.67105055, 0.32894939], array([1, 0])),
#  ([0.028980028, 0.97102004], array([0, 1])),
#  ([0.78429401, 0.21570596], array([1, 0])),
#  ([0.5948329, 0.40516713], array([0, 1])),
#  ([0.77958882, 0.22041118], array([1, 0])),
#  ([0.049194541, 0.95080549], array([0, 1])),
#  ([0.58966142, 0.41033855], array([1, 0])),
#  ([0.66043121, 0.33956879], array([1, 0])),
#  ([0.26925004, 0.73074991], array([0, 1])),
#  ([0.43202537, 0.56797463], array([1, 0])),
#  ([0.4597145, 0.54028553], array([0, 1])),
#  ([0.2246695, 0.77533054], array([1, 0])),
#  ([0.58799434, 0.41200569], array([0, 1])),
#  ([0.43483558, 0.56516439], array([0, 1])),
#  ([0.62711608, 0.37288392], array([0, 1])),
#  ([0.48169264, 0.51830739], array([0, 1])),
#  ([0.22194082, 0.77805918], array([0, 1])),
#  ([0.44830099, 0.55169898], array([0, 1])),
#  ([0.69339424, 0.30660576], array([0, 1])),
#  ([0.121245, 0.87875503], array([0, 1])),
#  ([0.29189041, 0.70810962], array([0, 1])),
#  ([0.68476152, 0.31523848], array([1, 0])),
#  ([0.32727548, 0.67272449], array([1, 0])),
#  ([0.70050102, 0.29949901], array([1, 0])),
#  ([0.5552519, 0.4447481], array([1, 0])),
#  ([0.63799965, 0.36200035], array([1, 0])),
#  ([0.48453945, 0.51546055], array([1, 0])),
#  ([0.36117387, 0.63882607], array([1, 0])),
#  ([0.37250569, 0.62749428], array([0, 1])),
#  ([0.48220003, 0.51779997], array([1, 0])),
#  ([0.67794836, 0.32205167], array([0, 1])),
#  ([0.54620945, 0.45379061], array([1, 0])),
#  ([0.6222176, 0.37778243], array([1, 0])),
#  ([0.40944278, 0.59055722], array([1, 0])),
#  ([0.46943894, 0.53056103], array([0, 1])),
#  ([0.73657382, 0.26342613], array([1, 0])),
#  ([0.48925319, 0.51074678], array([1, 0])),
#  ([0.6659199, 0.33408013], array([1, 0])),
#  ([0.47026366, 0.52973628], array([0, 1])),
#  ([0.62824982, 0.37175015], array([1, 0])),
#  ([0.72851515, 0.27148485], array([1, 0])),
#  ([0.23777173, 0.76222825], array([0, 1])),
#  ([0.10677215, 0.89322782], array([0, 1])),
#  ([0.13513084, 0.86486912], array([0, 1])),
#  ([0.39222839, 0.60777169], array([0, 1])),
#  ([0.24797608, 0.75202394], array([1, 0])),
#  ([0.65410137, 0.34589863], array([1, 0])),
#  ([0.13725081, 0.86274922], array([0, 1])),
#  ([0.042890754, 0.95710927], array([0, 1])),
#  ([0.70820874, 0.29179123], array([1, 0])),
#  ([0.1251415, 0.8748585], array([0, 1])),
#  ([0.63696539, 0.36303461], array([1, 0])),
#  ([0.44845769, 0.55154234], array([1, 0])),
#  ([0.25066197, 0.74933797], array([0, 1])),
#  ([0.50385696, 0.49614307], array([0, 1])),
#  ([0.46375224, 0.53624773], array([1, 0])),
#  ([0.71034843, 0.28965157], array([1, 0])),
#  ([0.1882636, 0.8117364], array([0, 1])),
#  ([0.67207891, 0.32792109], array([1, 0])),
#  ([0.30594915, 0.69405085], array([0, 1])),
#  ([0.57836425, 0.42163572], array([0, 1])),
#  ([0.49020249, 0.50979751], array([1, 0])),
#  ([0.60797954, 0.39202046], array([0, 1])),
#  ([0.38231739, 0.61768264], array([0, 1])),
#  ([0.81731826, 0.18268177], array([0, 1])),
#  ([0.72883487, 0.2711651], array([1, 0])),
#  ([0.36404628, 0.63595378], array([0, 1])),
#  ([0.34661639, 0.65338361], array([0, 1])),
#  ([0.5951978, 0.40480217], array([1, 0])),
#  ([0.45525149, 0.54474854], array([1, 0])),
#  ([0.93674159, 0.063258454], array([1, 0])),
#  ([0.42265642, 0.57734358], array([0, 1])),
#  ([0.21440279, 0.78559721], array([1, 0])),
#  ([0.14203846, 0.85796154], array([0, 1])),
#  ([0.55652618, 0.44347379], array([1, 0])),
#  ([0.61679053, 0.38320944], array([1, 0])),
#  ([0.70397371, 0.29602629], array([1, 0])),
#  ([0.53702956, 0.46297044], array([0, 1])),
#  ([0.52611798, 0.47388199], array([0, 1])),
#  ([0.86803699, 0.13196303], array([1, 0])),
#  ([0.45212585, 0.54787415], array([1, 0])),
#  ([0.54806334, 0.45193666], array([1, 0])),
#  ([0.18350407, 0.8164959], array([0, 1])),
#  ([0.65243721, 0.34756276], array([1, 0])),
#  ([0.60662657, 0.39337346], array([0, 1])),
#  ([0.34869239, 0.65130764], array([0, 1])),
#  ([0.50825959, 0.49174041], array([1, 0])),
#  ([0.37070516, 0.62929487], array([0, 1])),
#  ([0.58535618, 0.41464388], array([1, 0])),
#  ([0.52952856, 0.47047147], array([0, 1])),
#  ([0.4555032, 0.54449677], array([1, 0])),
#  ([0.4046514, 0.5953486], array([0, 1])),
#  ([0.60393322, 0.39606681], array([1, 0])),
#  ([0.27775285, 0.72224718], array([0, 1])),
#  ([0.48249763, 0.51750237], array([1, 0])),
#  ([0.67307431, 0.32692567], array([1, 0])),
#  ([0.40489483, 0.59510511], array([0, 1])),
#  ([0.63375431, 0.36624572], array([1, 0])),
#  ([0.48331374, 0.51668626], array([0, 1])),
#  ([0.53588843, 0.46411154], array([1, 0])),
#  ([0.31951505, 0.68048501], array([0, 1])),
#  ([0.36419821, 0.63580179], array([1, 0])),
#  ([0.61360753, 0.3863925], array([0, 1])),
#  ([0.49047473, 0.5095253], array([1, 0])),
#  ([0.55969429, 0.44030571], array([1, 0])),
#  ([0.73627645, 0.26372352], array([1, 0])),
#  ([0.51785582, 0.48214412], array([1, 0])),
#  ([0.34237042, 0.65762955], array([0, 1])),
#  ([0.88526088, 0.11473914], array([1, 0])),
#  ([0.53684503, 0.46315497], array([0, 1])),
#  ([0.58671099, 0.41328898], array([0, 1])),
#  ([0.47867751, 0.52132255], array([1, 0])),
#  ([0.50638163, 0.4936184], array([0, 1])),
#  ([0.54734826, 0.45265174], array([0, 1])),
#  ([0.032903776, 0.96709621], array([0, 1])),
#  ([0.18986534, 0.81013465], array([0, 1])),
#  ([0.50666654, 0.49333346], array([0, 1])),
#  ([0.54342806, 0.45657194], array([0, 1])),
#  ([0.59657454, 0.40342543], array([1, 0])),
#  ([0.54089999, 0.45909995], array([0, 1])),
#  ([0.67308313, 0.3269169], array([1, 0])),
#  ([0.94224179, 0.057758275], array([1, 0])),
#  ([0.4748551, 0.52514499], array([0, 1])),
#  ([0.21668479, 0.78331524], array([1, 0])),
#  ([0.60140759, 0.39859241], array([1, 0])),
#  ([0.45377481, 0.54622525], array([0, 1])),
#  ([0.38159135, 0.61840862], array([0, 1])),
#  ([0.63624191, 0.36375806], array([1, 0])),
#  ([0.57240081, 0.42759922], array([1, 0])),
#  ([0.82171094, 0.17828901], array([1, 0])),
#  ([0.52915603, 0.47084403], array([0, 1])),
#  ([0.66519457, 0.3348054], array([1, 0])),
#  ([0.39930543, 0.6006946], array([0, 1])),
#  ([0.47827038, 0.52172965], array([0, 1])),
#  ([0.61506438, 0.38493559], array([0, 1])),
#  ([0.41240135, 0.58759868], array([1, 0])),
#  ([0.24261671, 0.75738323], array([0, 1])),
#  ([0.70336765, 0.29663238], array([1, 0])),
#  ([0.62701738, 0.37298259], array([1, 0])),
#  ([0.36284778, 0.63715219], array([0, 1])),
#  ([0.63812321, 0.36187679], array([1, 0])),
#  ([0.13634518, 0.86365485], array([1, 0])),
#  ([0.2271928, 0.77280718], array([0, 1])),
#  ([0.30737129, 0.69262874], array([0, 1])),
#  ([0.55283767, 0.44716239], array([1, 0])),
#  ([0.57710081, 0.42289922], array([0, 1])),
#  ([0.77627057, 0.2237294], array([1, 0])),
#  ([0.60223192, 0.39776805], array([1, 0])),
#  ([0.48493922, 0.51506084], array([1, 0])),
#  ([0.49206731, 0.5079326], array([0, 1])),
#  ([0.26825613, 0.73174387], array([0, 1])),
#  ([0.65098095, 0.34901905], array([1, 0])),
#  ([0.61066204, 0.38933799], array([1, 0])),
#  ([0.68337935, 0.31662062], array([1, 0])),
#  ([0.61438936, 0.38561067], array([1, 0])),
#  ([0.16120812, 0.83879185], array([0, 1])),
#  ([0.72637081, 0.27362925], array([1, 0])),
#  ([0.85528612, 0.14471382], array([1, 0])),
#  ([0.10467066, 0.8953293], array([0, 1])),
#  ([0.38561627, 0.61438376], array([0, 1])),
#  ([0.42541906, 0.57458103], array([1, 0])),
#  ([0.54292601, 0.45707396], array([1, 0])),
#  ([0.54698753, 0.45301247], array([1, 0])),
#  ([0.1769443, 0.82305568], array([1, 0])),
#  ([0.37242553, 0.62757444], array([0, 1])),
#  ([0.48472863, 0.51527131], array([1, 0])),
#  ([0.35847732, 0.64152265], array([1, 0])),
#  ([0.68274415, 0.31725588], array([1, 0])),
#  ([0.34243187, 0.6575681], array([1, 0])),
#  ([0.36527282, 0.63472718], array([0, 1])),
#  ([0.35902655, 0.64097345], array([0, 1])),
#  ([0.5239265, 0.47607353], array([0, 1])),
#  ([0.386632, 0.61336803], array([0, 1])),
#  ([0.41969538, 0.58030462], array([1, 0])),
#  ([0.35666114, 0.64333886], array([1, 0])),
#  ([0.60885417, 0.3911458], array([1, 0])),
#  ([0.34764093, 0.65235907], array([1, 0])),
#  ([0.71629351, 0.28370652], array([1, 0])),
#  ([0.4344371, 0.5655629], array([0, 1])),
#  ([0.2072385, 0.79276156], array([1, 0])),
#  ([0.56159043, 0.43840957], array([1, 0])),
#  ([0.46266007, 0.53733993], array([1, 0])),
#  ([0.24907027, 0.75092971], array([1, 0])),
#  ([0.650172, 0.34982803], array([0, 1])),
#  ([0.64046067, 0.35953927], array([0, 1])),
#  ([0.36840931, 0.63159066], array([0, 1])),
#  ([0.68094802, 0.31905198], array([1, 0])),
#  ([0.22533853, 0.77466148], array([0, 1])),
#  ([0.20449921, 0.79550076], array([0, 1])),
#  ([0.29286361, 0.70713633], array([1, 0])),
#  ([0.6806922, 0.31930783], array([1, 0])),
#  ([0.2704269, 0.72957307], array([1, 0])),
#  ([0.31513217, 0.68486786], array([0, 1])),
#  ([0.32036453, 0.67963552], array([1, 0])),
#  ([0.63194466, 0.36805528], array([1, 0])),
#  ([0.6600129, 0.33998713], array([1, 0])),
#  ([0.45185956, 0.54814047], array([0, 1])),
#  ([0.60972244, 0.3902775], array([0, 1])),
#  ([0.65248317, 0.34751683], array([1, 0])),
#  ([0.13881849, 0.8611815], array([1, 0])),
#  ([0.38287202, 0.61712807], array([0, 1])),
#  ([0.20788901, 0.79211104], array([0, 1])),
#  ([0.40560684, 0.59439307], array([1, 0])),
#  ([0.51016015, 0.48983985], array([1, 0])),
#  ([0.87905359, 0.12094636], array([1, 0])),
#  ([0.63316882, 0.36683118], array([0, 1])),
#  ([0.67953545, 0.32046461], array([1, 0])),
#  ([0.43102175, 0.56897819], array([0, 1])),
#  ([0.28623489, 0.71376508], array([0, 1])),
#  ([0.60632414, 0.39367583], array([1, 0])),
#  ([0.51947469, 0.48052529], array([0, 1])),
#  ([0.67577183, 0.32422814], array([1, 0])),
#  ([0.543778, 0.45622197], array([0, 1])),
#  ([0.53814065, 0.46185929], array([0, 1])),
#  ([0.47359046, 0.52640951], array([0, 1])),
#  ([0.67142111, 0.32857889], array([1, 0])),
#  ([0.78342694, 0.21657309], array([1, 0])),
#  ([0.13469726, 0.86530274], array([0, 1])),
#  ([0.603266, 0.396734], array([1, 0])),
#  ([0.63665199, 0.36334807], array([1, 0])),
#  ([0.10697289, 0.89302707], array([0, 1])),
#  ([0.25561219, 0.74438781], array([1, 0])),
#  ([0.47970569, 0.52029431], array([1, 0])),
#  ([0.012851113, 0.98714894], array([0, 1])),
#  ([0.69538277, 0.30461723], array([1, 0])),
#  ([0.29345387, 0.70654613], array([0, 1])),
#  ([0.11776194, 0.88223809], array([0, 1])),
#  ([0.6247068, 0.37529317], array([0, 1])),
#  ([0.63158536, 0.3684147], array([1, 0])),
#  ([0.53794944, 0.46205053], array([0, 1])),
#  ([0.55655187, 0.44344813], array([1, 0])),
#  ([0.36235145, 0.63764858], array([1, 0])),
#  ([0.21591482, 0.78408521], array([0, 1])),
#  ([0.73547739, 0.26452258], array([0, 1])),
#  ([0.48864344, 0.51135665], array([1, 0])),
#  ([0.12172815, 0.87827182], array([0, 1])),
#  ([0.49806616, 0.50193381], array([1, 0])),
#  ([0.56947303, 0.430527], array([0, 1])),
#  ([0.23950332, 0.76049662], array([0, 1])),
#  ([0.53203738, 0.46796256], array([0, 1])),
#  ([0.50227737, 0.49772266], array([0, 1])),
#  ([0.61893356, 0.38106641], array([0, 1])),
#  ([0.71516711, 0.28483295], array([1, 0])),
#  ([0.58361244, 0.41638762], array([1, 0])),
#  ([0.64866042, 0.35133961], array([1, 0])),
#  ([0.61403954, 0.38596043], array([0, 1])),
#  ([0.44154492, 0.55845505], array([0, 1])),
#  ([0.54793268, 0.45206738], array([1, 0])),
#  ([0.24701072, 0.75298929], array([0, 1])),
#  ([0.29333791, 0.70666206], array([0, 1])),
#  ([0.40165135, 0.59834862], array([1, 0])),
#  ([0.32147485, 0.67852515], array([0, 1])),
#  ([0.34320012, 0.65679985], array([0, 1])),
#  ([0.40387452, 0.59612548], array([1, 0])),
#  ([0.24207686, 0.75792319], array([0, 1])),
#  ([0.30698612, 0.69301391], array([0, 1])),
#  ([0.6166383, 0.38336167], array([0, 1])),
#  ([0.62702727, 0.37297267], array([0, 1])),
#  ([0.55096757, 0.4490324], array([1, 0])),
#  ([0.61152166, 0.38847837], array([1, 0])),
#  ([0.42204851, 0.57795143], array([0, 1])),
#  ([0.46804258, 0.53195745], array([0, 1])),
#  ([0.37109622, 0.62890381], array([1, 0])),
#  ([0.38842389, 0.61157614], array([1, 0])),
#  ([0.6617071, 0.33829284], array([1, 0])),
#  ([0.65670699, 0.34329307], array([1, 0])),
#  ([0.50191468, 0.49808535], array([1, 0])),
#  ([0.44552496, 0.55447501], array([0, 1])),
#  ([0.48487753, 0.51512247], array([0, 1])),
#  ([0.42415226, 0.57584774], array([0, 1])),
#  ([0.63295275, 0.36704728], array([0, 1])),
#  ([0.54748315, 0.45251685], array([1, 0])),
#  ([0.50201249, 0.49798748], array([0, 1])),
#  ([0.62161267, 0.37838733], array([1, 0])),
#  ([0.22398451, 0.77601552], array([0, 1])),
#  ([0.59166545, 0.40833458], array([1, 0])),
#  ([0.39309043, 0.60690957], array([1, 0])),
#  ([0.16289905, 0.83710098], array([0, 1])),
#  ([0.19165678, 0.80834317], array([0, 1])),
#  ([0.48363349, 0.51636648], array([0, 1])),
#  ([0.43148434, 0.56851566], array([0, 1])),
#  ([0.37685099, 0.62314892], array([0, 1])),
#  ([0.38418978, 0.61581022], array([0, 1])),
#  ([0.57096052, 0.42903948], array([1, 0])),
#  ([0.10178434, 0.89821559], array([0, 1])),
#  ([0.65364665, 0.34635341], array([1, 0])),
#  ([0.65652442, 0.34347564], array([0, 1])),
#  ([0.49983102, 0.50016898], array([0, 1])),
#  ([0.2029679, 0.79703206], array([0, 1])),
#  ([0.49029541, 0.50970453], array([1, 0])),
#  ([0.51048428, 0.48951581], array([0, 1])),
#  ([0.4205105, 0.57948947], array([0, 1])),
#  ([0.32247388, 0.67752612], array([0, 1])),
#  ([0.56125128, 0.43874875], array([1, 0])),
#  ([0.21902065, 0.78097939], array([1, 0])),
#  ([0.57438195, 0.42561805], array([1, 0])),
#  ([0.41714394, 0.58285606], array([0, 1])),
#  ([0.47380325, 0.52619672], array([1, 0])),
#  ([0.53957069, 0.46042928], array([0, 1])),
#  ([0.44841343, 0.55158651], array([0, 1])),
#  ([0.12733065, 0.87266934], array([0, 1])),
#  ([0.1887107, 0.81128931], array([0, 1])),
#  ([0.62971807, 0.37028188], array([1, 0])),
#  ([0.26865679, 0.73134327], array([1, 0])),
#  ([0.6511749, 0.34882513], array([1, 0])),
#  ([0.46952415, 0.53047585], array([0, 1])),
#  ([0.39204356, 0.60795647], array([1, 0])),
#  ([0.3787455, 0.62125456], array([0, 1])),
#  ([0.39037037, 0.60962963], array([1, 0])),
#  ([0.57493395, 0.42506602], array([0, 1])),
#  ([0.63543767, 0.3645623], array([1, 0])),
#  ([0.59375787, 0.40624204], array([1, 0])),
#  ([0.48223466, 0.5177654], array([0, 1])),
#  ([0.87312084, 0.12687911], array([1, 0])),
#  ([0.70283747, 0.29716262], array([1, 0])),
#  ([0.66135216, 0.33864781], array([0, 1])),
#  ([0.56806642, 0.43193355], array([1, 0])),
#  ([0.5360952, 0.46390477], array([1, 0])),
#  ([0.67746848, 0.32253152], array([0, 1])),
#  ([0.46344039, 0.53655958], array([1, 0])),
#  ([0.34141386, 0.65858614], array([0, 1])),
#  ([0.29551131, 0.70448875], array([1, 0])),
#  ([0.43079063, 0.56920934], array([0, 1])),
#  ([0.6391679, 0.3608321], array([0, 1])),
#  ([0.19106331, 0.80893672], array([0, 1])),
#  ([0.6800136, 0.31998649], array([1, 0])),
#  ([0.17605366, 0.82394636], array([1, 0])),
#  ([0.25589341, 0.74410659], array([1, 0])),
#  ([0.72362232, 0.27637762], array([1, 0])),
#  ([0.55156046, 0.44843957], array([1, 0])),
#  ([0.31224525, 0.68775475], array([1, 0])),
#  ([0.1338587, 0.86614132], array([0, 1])),
#  ([0.42896429, 0.57103568], array([1, 0])),
#  ([0.69507933, 0.30492067], array([0, 1])),
#  ([0.51078963, 0.48921034], array([1, 0])),
#  ([0.91145271, 0.088547289], array([1, 0])),
#  ([0.63158339, 0.36841661], array([1, 0])),
#  ([0.39715546, 0.60284454], array([0, 1])),
#  ([0.38937244, 0.61062759], array([0, 1])),
#  ([0.4774842, 0.52251577], array([0, 1])),
#  ([0.081784509, 0.91821545], array([0, 1])),
#  ([0.47950819, 0.52049178], array([1, 0])),
#  ([0.077463903, 0.92253613], array([0, 1])),
#  ([0.51757711, 0.48242289], array([1, 0])),
#  ([0.21351048, 0.78648955], array([0, 1])),
#  ([0.61660665, 0.38339338], array([0, 1])),
#  ([0.53554291, 0.46445709], array([1, 0])),
#  ([0.74989641, 0.25010365], array([1, 0])),
#  ([0.58845437, 0.4115456], array([1, 0])),
#  ([0.65810776, 0.34189224], array([0, 1])),
#  ([0.13006356, 0.86993641], array([0, 1])),
#  ([0.6123538, 0.3876462], array([0, 1])),
#  ([0.11365299, 0.886347], array([1, 0])),
#  ([0.70802236, 0.29197767], array([1, 0])),
#  ([0.59638727, 0.4036127], array([0, 1])),
#  ([0.49468216, 0.50531781], array([0, 1])),
#  ([0.6385774, 0.36142263], array([0, 1])),
#  ([0.6295709, 0.3704291], array([1, 0])),
#  ([0.46839207, 0.53160793], array([1, 0])),
#  ([0.40431556, 0.59568441], array([0, 1])),
#  ([0.025892079, 0.97410786], array([0, 1])),
#  ([0.37941137, 0.6205886], array([0, 1])),
#  ([0.36775607, 0.63224393], array([0, 1])),
#  ([0.48016104, 0.51983893], array([1, 0])),
#  ([0.49219638, 0.50780356], array([1, 0])),
#  ([0.21914031, 0.78085971], array([0, 1])),
#  ([0.68855196, 0.31144807], array([1, 0])),
#  ([0.66548449, 0.33451542], array([0, 1])),
#  ([0.55003351, 0.44996652], array([1, 0])),
#  ([0.92487115, 0.075128898], array([0, 1])),
#  ([0.58097404, 0.41902596], array([1, 0])),
#  ([0.11401257, 0.88598746], array([0, 1])),
#  ([0.39819145, 0.60180861], array([0, 1])),
#  ([0.46474737, 0.53525257], array([1, 0])),
#  ([0.20140511, 0.79859495], array([1, 0])),
#  ([0.23402616, 0.76597381], array([0, 1])),
#  ([0.49776062, 0.50223947], array([0, 1])),
#  ([0.55662793, 0.44337204], array([0, 1])),
#  ([0.63205522, 0.36794481], array([1, 0])),
#  ([0.34547409, 0.65452588], array([1, 0])),
#  ([0.3392216, 0.6607784], array([0, 1])),
#  ([0.57257015, 0.42742983], array([1, 0])),
#  ([0.60979778, 0.39020222], array([1, 0])),
#  ([0.63661826, 0.36338174], array([1, 0])),
#  ([0.36452711, 0.63547295], array([1, 0])),
#  ([0.30959362, 0.69040644], array([1, 0])),
#  ([0.42081657, 0.57918346], array([1, 0])),
#  ([0.7332266, 0.26677343], array([1, 0])),
#  ([0.66397572, 0.33602425], array([1, 0])),
#  ([0.28462917, 0.71537077], array([0, 1])),
#  ([0.56341016, 0.43658981], array([0, 1])),
#  ([0.35510916, 0.64489079], array([0, 1])),
#  ([0.56847066, 0.43152937], array([1, 0])),
#  ([0.68264765, 0.31735232], array([1, 0])),
#  ([0.47305647, 0.5269435], array([0, 1])),
#  ([0.53240401, 0.46759599], array([1, 0])),
#  ([0.49568605, 0.50431395], array([0, 1])),
#  ([0.61905813, 0.38094181], array([0, 1])),
#  ([0.44532317, 0.55467689], array([0, 1])),
#  ([0.053020284, 0.94697976], array([0, 1])),
#  ([0.62928528, 0.37071472], array([1, 0])),
#  ([0.54741299, 0.45258704], array([0, 1])),
#  ([0.60909772, 0.39090234], array([0, 1])),
#  ([0.62022167, 0.37977833], array([1, 0])),
#  ([0.38369918, 0.61630076], array([1, 0])),
#  ([0.48223412, 0.51776582], array([0, 1])),
#  ([0.5406543, 0.45934576], array([1, 0])),
#  ([0.57078719, 0.42921284], array([0, 1])),
#  ([0.41074938, 0.58925062], array([1, 0])),
#  ([0.60089022, 0.39910975], array([0, 1])),
#  ([0.1951586, 0.80484134], array([0, 1])),
#  ([0.63659948, 0.36340055], array([1, 0])),
#  ([0.42622653, 0.5737735], array([0, 1])),
#  ([0.58515626, 0.41484371], array([0, 1])),
#  ([0.51501656, 0.48498347], array([1, 0])),
#  ([0.60594589, 0.39405411], array([1, 0])),
#  ([0.67848462, 0.32151541], array([0, 1])),
#  ([0.33644241, 0.66355765], array([0, 1])),
#  ([0.41079512, 0.58920491], array([1, 0])),
#  ([0.4456816, 0.55431843], array([0, 1])),
#  ([0.116826, 0.88317406], array([0, 1])),
#  ([0.31814995, 0.68185002], array([0, 1])),
#  ([0.66418099, 0.33581901], array([1, 0])),
#  ([0.66026318, 0.33973679], array([0, 1])),
#  ([0.22802314, 0.77197689], array([1, 0])),
#  ([0.53456879, 0.4654313], array([1, 0])),
#  ([0.55684257, 0.4431574], array([1, 0])),
#  ([0.25125629, 0.74874365], array([0, 1])),
#  ([0.098299384, 0.90170056], array([0, 1])),
#  ([0.63114369, 0.36885625], array([1, 0])),
#  ([0.49466753, 0.50533253], array([1, 0])),
#  ([0.57959616, 0.42040378], array([1, 0])),
#  ([0.58455294, 0.41544703], array([1, 0])),
#  ([0.5205763, 0.47942364], array([1, 0])),
#  ([0.3093611, 0.6906389], array([0, 1])),
#  ([0.56122959, 0.43877038], array([0, 1])),
#  ([0.508286, 0.49171397], array([0, 1])),
#  ([0.51285726, 0.48714274], array([1, 0])),
#  ([0.63770807, 0.36229202], array([1, 0])),
#  ([0.35226318, 0.64773685], array([1, 0])),
#  ([0.46897027, 0.53102976], array([0, 1])),
#  ([0.69793493, 0.3020651], array([1, 0])),
#  ([0.52437794, 0.47562203], array([1, 0])),
#  ([0.57786649, 0.42213354], array([0, 1])),
#  ([0.5601297, 0.43987027], array([0, 1])),
#  ([0.031532928, 0.96846706], array([0, 1])),
#  ([0.38847968, 0.61152029], array([1, 0])),
#  ([0.59240961, 0.40759039], array([0, 1])),
#  ([0.46313226, 0.53686774], array([1, 0])),
#  ([0.10878207, 0.89121789], array([0, 1])),
#  ([0.58291656, 0.41708347], array([1, 0])),
#  ([0.14735864, 0.85264134], array([0, 1])),
#  ([0.15573667, 0.84426332], array([0, 1])),
#  ([0.4261362, 0.5738638], array([0, 1])),
#  ([0.68989044, 0.31010956], array([1, 0])),
#  ([0.62181383, 0.37818614], array([0, 1])),
#  ([0.43175352, 0.56824648], array([0, 1])),
#  ([0.51537269, 0.48462734], array([1, 0])),
#  ([0.63684785, 0.36315212], array([1, 0])),
#  ([0.71329731, 0.28670272], array([0, 1])),
#  ([0.097107388, 0.90289259], array([0, 1])),
#  ([0.42046392, 0.57953614], array([0, 1])),
#  ([0.57611132, 0.42388865], array([1, 0])),
#  ([0.69161558, 0.30838442], array([1, 0])),
#  ([0.49666792, 0.50333208], array([1, 0])),
#  ([0.54976118, 0.45023879], array([0, 1])),
#  ([0.22041915, 0.77958083], array([0, 1])),
#  ([0.38572961, 0.61427039], array([0, 1])),
#  ([0.71435714, 0.28564286], array([1, 0])),
#  ([0.2145627, 0.78543723], array([0, 1])),
#  ([0.49696863, 0.50303131], array([0, 1])),
#  ([0.70908511, 0.29091489], array([1, 0])),
#  ([0.68303353, 0.31696647], array([0, 1])),
#  ([0.67974854, 0.32025149], array([1, 0])),
#  ([0.51880443, 0.48119557], array([1, 0])),
#  ([0.56816792, 0.43183208], array([1, 0])),
#  ([0.29839277, 0.70160723], array([0, 1])),
#  ([0.23339257, 0.76660746], array([0, 1])),
#  ([0.69475359, 0.30524647], array([1, 0])),
#  ([0.66882086, 0.33117914], array([1, 0])),
#  ([0.38083792, 0.61916202], array([0, 1])),
#  ([0.33290383, 0.6670962], array([1, 0])),
#  ([0.5818969, 0.41810313], array([1, 0])),
#  ([0.55989653, 0.4401035], array([1, 0])),
#  ([0.71506584, 0.28493422], array([1, 0])),
#  ([0.55779988, 0.44220009], array([1, 0])),
#  ([0.56855476, 0.43144518], array([0, 1])),
#  ([0.73357159, 0.26642844], array([1, 0])),
#  ([0.7096262, 0.2903738], array([1, 0])),
#  ([0.60196066, 0.39803934], array([0, 1])),
#  ([0.61027861, 0.38972139], array([1, 0])),
#  ([0.48882297, 0.511177], array([0, 1])),
#  ([0.50574464, 0.49425539], array([1, 0])),
#  ([0.44343504, 0.55656493], array([1, 0])),
#  ([0.20456561, 0.79543436], array([0, 1])),
#  ([0.65677214, 0.34322786], array([1, 0])),
#  ([0.42411196, 0.57588804], array([1, 0])),
#  ([0.57327133, 0.42672876], array([1, 0])),
#  ([0.55473119, 0.44526887], array([0, 1])),
#  ([0.26561394, 0.73438603], array([0, 1])),
#  ([0.19979155, 0.80020839], array([0, 1])),
#  ([0.66188043, 0.33811957], array([1, 0])),
#  ([0.67082548, 0.32917458], array([1, 0])),
#  ([0.58756, 0.41244003], array([1, 0])),
#  ([0.53159082, 0.46840915], array([1, 0])),
#  ([0.65809232, 0.34190765], array([1, 0])),
#  ([0.31767747, 0.68232256], array([0, 1])),
#  ([0.4849197, 0.51508027], array([0, 1])),
#  ([0.65637839, 0.34362161], array([1, 0])),
#  ([0.73452955, 0.2654705], array([0, 1])),
#  ([0.57169455, 0.42830548], array([1, 0])),
#  ([0.4739733, 0.52602673], array([0, 1])),
#  ([0.43084884, 0.56915116], array([1, 0])),
#  ([0.17569011, 0.82430995], array([0, 1])),
#  ([0.49024293, 0.5097571], array([1, 0])),
#  ([0.4594743, 0.54052567], array([0, 1])),
#  ([0.55439889, 0.44560111], array([1, 0])),
#  ([0.41552353, 0.58447641], array([0, 1])),
#  ([0.61988771, 0.38011235], array([1, 0])),
#  ([0.21540719, 0.78459281], array([0, 1])),
#  ([0.55726773, 0.44273227], array([0, 1])),
#  ([0.62977898, 0.37022105], array([0, 1])),
#  ([0.26991561, 0.73008436], array([1, 0])),
#  ([0.5583688, 0.44163117], array([1, 0])),
#  ([0.68628901, 0.31371105], array([0, 1])),
#  ([0.60126173, 0.39873827], array([0, 1])),
#  ([0.25815013, 0.7418499], array([0, 1])),
#  ([0.68952894, 0.310471], array([1, 0])),
#  ([0.59440148, 0.40559852], array([1, 0])),
#  ([0.51014853, 0.48985153], array([1, 0])),
#  ([0.37562606, 0.62437397], array([0, 1])),
#  ([0.58572316, 0.41427687], array([0, 1])),
#  ([0.23799212, 0.76200789], array([0, 1])),
#  ([0.64975882, 0.35024118], array([0, 1])),
#  ([0.18171978, 0.81828022], array([1, 0])),
#  ([0.394788, 0.60521197], array([1, 0])),
#  ([0.40386775, 0.59613228], array([1, 0])),
#  ([0.53657204, 0.46342799], array([1, 0])),
#  ([0.46286851, 0.53713149], array([0, 1])),
#  ([0.84911823, 0.15088181], array([1, 0])),
#  ([0.29234418, 0.70765591], array([1, 0])),
#  ([0.57029825, 0.42970172], array([1, 0])),
#  ([0.63989806, 0.36010197], array([1, 0])),
#  ([0.11250456, 0.88749546], array([0, 1])),
#  ([0.4300631, 0.56993687], array([1, 0])),
#  ([0.89693934, 0.1030607], array([1, 0])),
#  ([0.65451974, 0.34548029], array([1, 0])),
#  ([0.28297395, 0.71702605], array([1, 0])),
#  ([0.65386224, 0.3461377], array([1, 0])),
#  ([0.66559869, 0.33440134], array([0, 1])),
#  ([0.48898396, 0.51101607], array([1, 0])),
#  ([0.53249294, 0.46750709], array([1, 0])),
#  ([0.74366516, 0.25633484], array([1, 0])),
#  ([0.60005742, 0.39994258], array([1, 0])),
#  ([0.59743911, 0.40256083], array([0, 1])),
#  ([0.19544329, 0.80455667], array([0, 1])),
#  ([0.36047444, 0.63952553], array([0, 1])),
#  ([0.67714542, 0.32285461], array([1, 0])),
#  ([0.36898288, 0.63101715], array([0, 1])),
#  ([0.61075771, 0.38924235], array([0, 1])),
#  ([0.26523218, 0.73476785], array([0, 1])),
#  ([0.45374948, 0.54625052], array([1, 0])),
#  ([0.63817495, 0.36182505], array([0, 1])),
#  ([0.35759738, 0.64240265], array([0, 1])),
#  ([0.65052772, 0.34947234], array([1, 0])),
#  ([0.60591692, 0.39408305], array([1, 0])),
#  ([0.496672, 0.50332803], array([0, 1])),
#  ([0.094631359, 0.90536863], array([1, 0])),
#  ([0.65824163, 0.34175837], array([0, 1])),
#  ([0.28468561, 0.71531439], array([1, 0])),
#  ([0.67976147, 0.32023853], array([0, 1])),
#  ([0.47388002, 0.52611995], array([0, 1])),
#  ([0.18041027, 0.81958979], array([1, 0])),
#  ([0.38849097, 0.61150903], array([0, 1])),
#  ([0.24404964, 0.75595033], array([1, 0])),
#  ([0.54370362, 0.45629638], array([0, 1])),
#  ([0.35233051, 0.64766955], array([1, 0])),
#  ([0.6065464, 0.39345366], array([0, 1])),
#  ([0.51675594, 0.483244], array([0, 1])),
#  ([0.62079549, 0.37920448], array([0, 1])),
#  ([0.4583689, 0.5416311], array([1, 0])),
#  ([0.55087119, 0.44912884], array([0, 1])),
#  ([0.43641284, 0.56358713], array([1, 0])),
#  ([0.70166528, 0.29833463], array([1, 0])),
#  ([0.54218388, 0.45781615], array([1, 0])),
#  ([0.4400551, 0.55994493], array([0, 1])),
#  ([0.48957989, 0.51042014], array([0, 1])),
#  ([0.32941395, 0.67058605], array([0, 1])),
#  ([0.5258888, 0.4741112], array([1, 0])),
#  ([0.38370121, 0.61629879], array([1, 0])),
#  ([0.20434703, 0.79565305], array([0, 1])),
#  ([0.23118109, 0.76881891], array([1, 0])),
#  ([0.29191768, 0.70808232], array([0, 1])),
#  ([0.48160201, 0.51839799], array([0, 1])),
#  ([0.65650403, 0.34349588], array([0, 1])),
#  ([0.63524652, 0.36475345], array([1, 0])),
#  ([0.65492028, 0.34507969], array([1, 0])),
#  ([0.77891761, 0.22108237], array([1, 0])),
#  ([0.45653442, 0.54346555], array([1, 0])),
#  ([0.1004564, 0.89954358], array([1, 0])),
#  ([0.46831691, 0.53168309], array([1, 0])),
#  ([0.48413327, 0.51586676], array([1, 0])),
#  ([0.5314551, 0.4685449], array([1, 0])),
#  ([0.19451012, 0.80548984], array([0, 1])),
#  ([0.31708878, 0.68291122], array([1, 0])),
#  ([0.43225262, 0.56774735], array([0, 1])),
#  ([0.28669649, 0.71330351], array([0, 1])),
#  ([0.5523082, 0.44769183], array([0, 1])),
#  ([0.40166613, 0.5983339], array([1, 0])),
#  ([0.6743505, 0.32564953], array([1, 0])),
#  ([0.67063564, 0.32936439], array([0, 1])),
#  ([0.72240043, 0.27759948], array([1, 0])),
#  ([0.58754039, 0.41245961], array([0, 1])),
#  ([0.61829233, 0.3817077], array([1, 0])),
#  ([0.1349664, 0.86503363], array([1, 0])),
#  ([0.18613191, 0.81386805], array([1, 0])),
#  ([0.43092227, 0.56907779], array([0, 1])),
#  ([0.55729556, 0.4427045], array([0, 1])),
#  ([0.059245031, 0.94075501], array([0, 1])),
#  ([0.14760652, 0.85239351], array([0, 1])),
#  ([0.52066791, 0.47933206], array([1, 0])),
#  ([0.54084504, 0.45915502], array([0, 1])),
#  ([0.095676459, 0.90432352], array([0, 1])),
#  ([0.47589359, 0.52410644], array([0, 1])),
#  ([0.46831197, 0.53168809], array([0, 1])),
#  ([0.90471393, 0.095286034], array([1, 0])),
#  ([0.40695509, 0.59304494], array([1, 0])),
#  ([0.27011025, 0.72988981], array([0, 1])),
#  ([0.45040062, 0.54959941], array([1, 0])),
#  ([0.37819523, 0.62180477], array([0, 1])),
#  ([0.21374772, 0.78625226], array([1, 0])),
#  ([0.42404175, 0.57595819], array([1, 0])),
#  ([0.44792458, 0.55207551], array([0, 1])),
#  ([0.70139468, 0.29860532], array([1, 0])),
#  ([0.61529869, 0.38470131], array([0, 1])),
#  ([0.18176943, 0.81823057], array([0, 1])),
#  ([0.427829, 0.57217097], array([1, 0])),
#  ([0.56233209, 0.43766794], array([1, 0])),
#  ([0.70453835, 0.2954616], array([1, 0])),
#  ([0.40414587, 0.59585416], array([1, 0])),
#  ([0.21269803, 0.78730196], array([0, 1])),
#  ([0.52468127, 0.4753187], array([0, 1])),
#  ([0.59876841, 0.40123153], array([1, 0])),
#  ([0.55724311, 0.44275689], array([1, 0])),
#  ([0.25114155, 0.74885851], array([0, 1])),
#  ([0.54333764, 0.45666236], array([1, 0])),
#  ([0.54410303, 0.45589697], array([0, 1])),
#  ([0.57632583, 0.42367417], array([0, 1])),
#  ([0.72473192, 0.27526808], array([1, 0])),
#  ([0.49954361, 0.50045633], array([1, 0])),
#  ([0.22399054, 0.77600944], array([0, 1])),
#  ([0.62154919, 0.37845081], array([0, 1])),
#  ([0.54545116, 0.45454887], array([0, 1])),
#  ([0.69737095, 0.30262902], array([1, 0])),
#  ([0.65491444, 0.34508553], array([0, 1])),
#  ([0.38034007, 0.61965996], array([1, 0])),
#  ([0.38983044, 0.61016959], array([1, 0])),
#  ([0.6698758, 0.33012426], array([0, 1])),
#  ([0.38428995, 0.61571008], array([1, 0])),
#  ([0.59321356, 0.40678644], array([1, 0])),
#  ([0.38634437, 0.61365557], array([1, 0])),
#  ([0.64341897, 0.35658106], array([0, 1])),
#  ([0.15426211, 0.84573781], array([0, 1])),
#  ([0.37592214, 0.62407792], array([1, 0])),
#  ([0.32394782, 0.67605215], array([1, 0])),
#  ([0.31345204, 0.68654799], array([1, 0])),
#  ([0.38156104, 0.6184389], array([0, 1])),
#  ([0.47131699, 0.52868307], array([1, 0])),
#  ([0.81702316, 0.18297681], array([1, 0])),
#  ([0.45125359, 0.54874647], array([0, 1])),
#  ([0.25581729, 0.74418277], array([0, 1])),
#  ([0.38997766, 0.61002237], array([1, 0])),
#  ([0.1626194, 0.83738065], array([0, 1])),
#  ([0.56071925, 0.43928072], array([1, 0])),
#  ([0.08169423, 0.91830581], array([0, 1])),
#  ([0.61351353, 0.38648647], array([0, 1])),
#  ([0.54639161, 0.45360845], array([0, 1])),
#  ([0.32787418, 0.67212582], array([0, 1])),
#  ([0.5883711, 0.4116289], array([0, 1])),
#  ([0.72507674, 0.27492324], array([0, 1])),
#  ([0.40039065, 0.59960938], array([1, 0])),
#  ([0.16301887, 0.83698112], array([0, 1])),
#  ([0.66350406, 0.33649597], array([0, 1])),
#  ...]
